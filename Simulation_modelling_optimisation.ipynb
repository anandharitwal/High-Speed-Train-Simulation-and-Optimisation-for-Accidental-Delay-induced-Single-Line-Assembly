# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Loading-libraries" data-toc-modified-id="Loading-libraries-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Loading libraries</a></span></li><li><span><a href="#Setting-seed-to-reproduce-the-results" data-toc-modified-id="Setting-seed-to-reproduce-the-results-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Setting seed to reproduce the results</a></span></li><li><span><a href="#time-spend-in-block" data-toc-modified-id="time-spend-in-block-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>time spend in block</a></span></li><li><span><a href="#Creating-train-object" data-toc-modified-id="Creating-train-object-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Creating train object</a></span></li><li><span><a href="#creating-track-object" data-toc-modified-id="creating-track-object-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>creating track object</a></span></li><li><span><a href="#Creating-Simulation-object-including-trains-and-signals" data-toc-modified-id="Creating-Simulation-object-including-trains-and-signals-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Creating Simulation object including trains and signals</a></span></li><li><span><a href="#Optimisation-of-travel-time" data-toc-modified-id="Optimisation-of-travel-time-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Optimisation of travel time</a></span></li><li><span><a href="#creating-3D-visulatisation" data-toc-modified-id="creating-3D-visulatisation-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>creating 3D visulatisation</a></span></li><li><span><a href="#greedy-hill-optimisation" data-toc-modified-id="greedy-hill-optimisation-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>greedy hill optimisation</a></span></li><li><span><a href="#Random-Walk-optimisation" data-toc-modified-id="Random-Walk-optimisation-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Random Walk optimisation</a></span></li><li><span><a href="#Monte-carlo-optimisation" data-toc-modified-id="Monte-carlo-optimisation-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Monte carlo optimisation</a></span></li><li><span><a href="#result-of-optimisation" data-toc-modified-id="result-of-optimisation-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>result of optimisation</a></span></li><li><span><a href="#Half-an-hour-delay-at-9-am" data-toc-modified-id="Half-an-hour-delay-at-9-am-13"><span class="toc-item-num">13&nbsp;&nbsp;</span>Half an hour delay at 9 am</a></span></li><li><span><a href="#Creating-network-class" data-toc-modified-id="Creating-network-class-14"><span class="toc-item-num">14&nbsp;&nbsp;</span>Creating network class</a></span></li><li><span><a href="#Delay-distribution" data-toc-modified-id="Delay-distribution-15"><span class="toc-item-num">15&nbsp;&nbsp;</span>Delay distribution</a></span></li></ul></div>

# %% [markdown]
# # Loading libraries

# %%
import numpy as np
import math
import random
import simpy
import pandas as pd
import scipy.stats as stats
import string
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
import pandasql as ps
import plotly.graph_objects as go
import plotly

# %% [markdown]
# # Setting seed to reproduce the results

# %%
random.seed(1234)

# %% [markdown]
# Block function

# %%
def Block_Location(k):
    Bl_Loc = np.linspace(0, 145, k + 1)
    return (Bl_Loc)

# %% [markdown]
# Time spend at top speed

# %%
def TS_time(TS_Dist):  # The time spent at top speed
    Time = TS_Dist / 310
    return (Time)

# %%
def Dec_Time_Exit_Speed(Dec_Dist):  # The Exit Speed
    Out_Dict = {}
    Out_Dict['Exit_Speed'] = math.sqrt(max(310 ** 2 - 2 * 4878.0* Dec_Dist, 0))
    Out_Dict['Time'] = 2 * Dec_Dist / (310 + Out_Dict['Exit_Speed'])
    return (Out_Dict)

# %%
def Acc_Time(Entry_Speed):  # The Acc Time
    Output = {}
    Output['Time'] = ((310 / 3600 - Entry_Speed / 3600) / 0.72) / 3.6
    Output['Dist'] = ((Entry_Speed / 3600) * (Output['Time'] * 360) + 0.5 * 0.72 * (Output['Time'] * 360) ** 2) / 10
    return (Output)

# %% [markdown]
# # time spend in block

# %%
def Time_In_Block(i, Block_Loc, slow_down_ind, Entry_Speed):
    dist = Block_Loc[i] - Block_Loc[i - 1]
    #takes 15k for train to reach full speed and then decelerate
    Pre_Sig_Dist = 9.751
    TS_Dist = dist - Acc_Time(Entry_Speed)['Dist'] - slow_down_ind * Pre_Sig_Dist
    time = Acc_Time(Entry_Speed)['Time'] + TS_time(TS_Dist) + slow_down_ind * Dec_Time_Exit_Speed(Pre_Sig_Dist)['Time']

    #Provide for weather etc.
    time_random = np.random.normal(time,time/10)
    return (time_random)

# %%
class wait_time:
    def __init__(self):
        self.wt = 0

    def London_Euston(self):
        self.wt = 0
        return (self.wt)

    def London_OOC(self):
        self.wt = (2 / 60) + np.random.exponential(1 / 60)
        return (self.wt)

    def Birmingham_Int(self):
        self.wt = (2 / 60) + np.random.exponential(1 / 60)
        return (self.wt)

    def Birmingham_Curzon(self):
        self.wt = 0
        return (self.wt)

# %% [markdown]
# # Creating train object

# %%
class Train(object):
    def __init__(self, env, sig_blocks, res, wait_class):
        self.sig_blocks=sig_blocks
        self.res = res
        self.wait_class = wait_class
        self.env=env


    def Execute_Train(self ,ID):
        wc = self.wait_class
        row = {}
        row['No_Blocks'] = len(self.sig_blocks) - 1 # London and two birmingham blocks dont add to the total
        row['Train_No'] = ID

        yield (self.env.timeout(wc.London_Euston()))

        lon = self.res['London'].request()
        yield (lon)
        #print('Train {} leaves London Euston at {}'.format(ID, self.env.now))
        row['Departure_Time'] = self.env.now

        yield (self.env.timeout(5 / 60))  # 5 minute wait
        #print('Train {} arrives in London Old Oak Common at {}'.format(ID, self.env.now))
        yield (self.env.timeout(wc.London_OOC()))  # wait for mandatory two mins with an extra delay of an average of one minute
        #print('Train {} leaves London Old Oak Common at {}'.format(ID, self.env.now))

        req_list = []
        req_list.append(self.res['Straight'][0].request())
        yield (req_list[0])
        yield(self.res['London'].release(lon))
        # Enter the long straight between London and brimingham
        SD_Ind = False
        Entry_speed = 0
        for i in range(1, len(self.sig_blocks)):
            #print('Train {} enters signalling block {} at {}'.format(ID, i, self.env.now))
            if i == len(self.sig_blocks) - 1:
                SD_Ind = True
            elif self.res['Straight'][i].count > 0:
                SD_Ind = True
                Entry_speed = 0
            elif i != 1:
                SD_Ind = False
                Entry_speed = 300

            Tib = Time_In_Block(i, self.sig_blocks, SD_Ind, Entry_speed)
            yield (self.env.timeout(Tib))


            # When we arrive at birmingham
            if i == len(self.sig_blocks) - 1:
                #print('Train {} arrives in Birmingham Interchange at {}'.format(ID , self.env.now))
                yield (self.env.timeout(wc.Birmingham_Int()))  # wait for mandatory two mins with an extra delay of an average of one minute
                bir1 = self.res['Birmingham'][0].request()
                yield (bir1)

            else:
                #print('Train {} reaches end of signalling block {} at {}'.format(ID ,i , self.env.now))
                req_list.append(self.res['Straight'][i].request())
                yield (req_list[i])

            self.res['Straight'][i - 1].release(req_list[i - 1])

        #print('Train {} leaves Birmingham Interchange at {}'.format(ID, self.env.now))
        yield (self.env.timeout(4.5 / 60))  # 4.5 Min journey
        #print('Train {} is at Birmingham Signalling Block {}'.format(ID, self.env.now))
        bir2 = self.res['Birmingham'][1].request()
        yield (bir2)
        self.res['Birmingham'][0].release(bir1)
        yield (self.env.timeout(4.5 / 60))  # 4.5 Min journey
        row['Arrival_Time'] = self.env.now
        self.res['Birmingham'][1].release(bir2)
        #print('Train {} arrives in Birmingham Curzon Street Common at {}'.format(ID, self.env.now))

        #append to output data frame
        global df_out
        df_out = df_out.append(row, ignore_index=True)

# %% [markdown]
# # creating track object

# %%
class London_2_Birmingham(object):
    def __init__(self, env, k, Times, Day_Num, wait_class):
        self.env = env
        self.k = k
        self.Times = Times
        self.Day_Num = Day_Num
        self.wait_class = wait_class
        self.df = pd.DataFrame(
            {'No_Blocks': [], 'Train_No': [], 'Departure_Time': [], 'Arrival_Time': [], 'Journey_Time': [], 'Day': [],
             'Trains_PH': []})
        self.action = env.process(self.run(self.k, self.Times))


    # The overall process
    def run(self, k, Times):
        sig_blocks = Block_Location(k)

        # create resources
        avail = {}
        avail['Straight'] = self.Resources(k)  # A vector of train locations, True indcates presence of train
        avail['London'] = simpy.Resource(self.env, capacity=1)
        avail['Birmingham'] = self.Resources(2)

        global df_out
        df_out = pd.DataFrame(
            {'No_Blocks': [], 'Train_No': [], 'Departure_Time': [], 'Arrival_Time': [], 'Journey_Time': [], 'Day': [],
             'Trains_PH': []})

        Train_obj = Train(self.env, sig_blocks, avail, self.wait_class())

        x = 1  # Train ID
        self.env.process(Train_obj.Execute_Train(x))
        #self.df = self.df.append(row_vect, ignore_index=True)

        while True:
            yield (self.env.timeout(1 / Times))  # Times per hour
            x = x + 1
            self.env.process(Train_obj.Execute_Train(x))
            #self.df = self.df.append(row_vect, ignore_index=True)

    def Resources(self, k):
        out_l = []
        for i in range(k):
            out_l.append(simpy.Resource(self.env, capacity=1))
        return (out_l)

    def Return_Df(self):
        self.df = df_out
        self.df['Journey_Time'] = self.df['Arrival_Time'] - self.df['Departure_Time']
        self.df['Day'] = self.Day_Num
        self.df['Trains_PH'] = self.Times
        return (self.df)

# %%
def daytime(t):
    t=int(t)
    return f"{t//3600:02d}:{(t%3600)//60:02d}:{t%60:02d}"
def now(env):
    return daytime(env.now)

# %% [markdown]
# # Creating Simulation object including trains and signals

# %% [markdown]
# Max a = 0.76 m/s2 giving time to accelerate maximum velocity of 86.1 m/s as time = v-u/a = 86.1/0.76 = 113.3 s and distance travelled till max speed is reached is given by s = u t + 0.5 a t2 since u or initial velocity is 0 equation becomes s = 0.5*a*t**2 = 0.5*0.76*113.3**2 = 4878 m
# •	Energy efficient deceleration time and distance covered
# Energy optimal deceleration time = 86.1/0.38 = 226.6 s and distance =86.1*226.6 – 0.5*0.38*226.6**2 = 9751 m
# •	Emergency deceleration time and distance covered
# Emergency deceleration time = 86.1/2.5 = 34.44 s and distance = 86.1*34.44 – 0.5*2.5*34.44**2 = 1483 m
# The above scenario indicates that we will have to design blocks atleast 9751*1.5 = 14626 m for safer and energy efficient stop between trains.
# The total distance is 145 km and needs equal distance between blocks limiting the choice for k= {1,2, 4, 5, 8, 10, 20, 25, 29, 40, 50…}. But minimum distance between 2 blocks are said to be 14000 m stating maximum block as {1,2,4,5,8,10}
# This limits the simulation as range of K is between 1 to 10.

# %% [markdown]
# Assuming maximum number of signal block installed in line that is 10
# The distance between each block comes to around 14500 meters so for a train to safely travel we need the first train to cross this block hence we can say that by the time the first train has crossed the first signal we cannot send the second train.
# Calculating the time required for the first train to cross the first block
# s= u*t + 0.5*a*t**2 since initial velocity is zero the equation becomes
# s=0.5*a*t**2
# 14500=0.5*0.76*t**2
# resolving the equation for t we get time taken for first train to cross the first block is 195 seconds and the delay in signal to turn green is 5 seconds making the total time to 200 seconds
# this indicates that the second train can only leave after 200 seconds which is nearly 3 mins making maximum number of train possible in 1 hour as 60/3 = 20 trains

# %%
Trains_PH = [1, 2, 3, 4, 5, 6, 8, 10, 12, 15, 20]
Sig_blocks = range(1, 11)

# %% [markdown]
# Creating simulation function with number of days to run the simulation

# %%
def Full_Simulation(n_days):  # few Variable Inputs, keep everything consistent

    Output_df = pd.DataFrame(
        {'No_Blocks': [], 'Train_No': [], 'Departure_Time': [], 'Arrival_Time': [], 'Journey_Time': [], 'Day': [],
         'Trains_PH': []})

    for Tr in Trains_PH:
        for sig in Sig_blocks:
            for day in range(1, n_days+1): 
                env = simpy.Environment()
                proc = London_2_Birmingham(env, sig, Tr, day, wait_time)
                env.run(until=18)  # Assume trains operate 6am to midnight 18 hours
                Output_df = Output_df.append(proc.Return_Df(), ignore_index=True)
    return (Output_df)

# %%
Sim_Data = Full_Simulation(1)

# %%
Sim_Data
# Out:
#       No_Blocks  Train_No  Departure_Time  Arrival_Time  Journey_Time  Day  \
# 0           1.0       1.0        0.000000      0.908358      0.908358  1.0
# 1           1.0       2.0        1.000000      1.906804      0.906804  1.0
# 2           1.0       3.0        2.000000      2.904839      0.904839  1.0
# 3           1.0       4.0        3.000000      3.823314      0.823314  1.0
# 4           1.0       5.0        4.000000      4.805883      0.805883  1.0
# ...         ...       ...             ...           ...           ...  ...
# 7675       10.0     117.0       15.674439     17.397565      1.723125  1.0
# 7676       10.0     118.0       15.791640     17.564624      1.772984  1.0
# 7677       10.0     119.0       15.989598     17.701446      1.711848  1.0
# 7678       10.0     120.0       16.120304     17.849603      1.729299  1.0
# 7679       10.0     121.0       16.245761     17.977854      1.732092  1.0
#
#       Trains_PH
# 0           1.0
# 1           1.0
# 2           1.0
# 3           1.0
# 4           1.0
# ...         ...
# 7675       20.0
# 7676       20.0
# 7677       20.0
# 7678       20.0
# 7679       20.0
#
# [7680 rows x 7 columns]

# %% [markdown]
# Confirming no collisions of train has occured

# %%
ps.sqldf('''
        select count(*) as num
        from Sim_Data as bse
        left join Sim_Data as alt 
            on bse.No_Blocks = alt.No_Blocks
            and bse.Day = alt.Day
            and bse.Trains_PH = alt.Trains_PH
            and alt.Train_No > bse.Train_No
        where alt.Arrival_Time < bse.Arrival_Time
        ''')
# Out:
#    num
# 0    0

# %% [markdown]
# # Optimisation of travel time

# %%
Sim_Data['Journey_Time1'] = Sim_Data['Journey_Time'] + 1/Sim_Data['Trains_PH']
Journey_Time = Sim_Data.groupby(['Trains_PH', 'No_Blocks']).agg(
        AVG_Journey_Time=pd.NamedAgg(column = 'Journey_Time1', aggfunc='mean'),
        STD_Journey_Time=pd.NamedAgg(column = 'Journey_Time1', aggfunc='std'))
Journey_Time = Journey_Time.reset_index(level=['Trains_PH', 'No_Blocks'])

# %% [markdown]
# # creating 3D visulatisation

# %%
def plot_3D(df,var):
    df_melt = df[['Trains_PH','No_Blocks',var]].pivot(columns='Trains_PH', index='No_Blocks')

    X = np.unique(df['Trains_PH'].values)
    Y = np.unique(df['No_Blocks'].values)
    Z = df_melt.values

    df_fig = go.Figure(data=[go.Surface(z=Z, x=X, y=Y
                                         , contours=dict(x=dict(show=True, start=1, end=20, size=1, color='white')
                                                         , y=dict(show=True, start=1, end=10, size=1, color='white'))
                                         # line = dict(smoothing=0))
                                         )])
    df_fig.update_layout(scene=dict(
        xaxis_title='Trains Per hour',
        yaxis_title='Number of Signalling Blocks',
        zaxis_title=var),
    )

    plotly.offline.plot(df_fig, filename='file.html')

# %%
plot_3D(Journey_Time, 'AVG_Journey_Time')
plot_3D(Journey_Time, 'STD_Journey_Time')

# %% [markdown]
# # function for optimisation

# %%
def Return_JT(n_Trains_PH, n_Sig_blocks):
    return (float(Journey_Time['AVG_Journey_Time'][Journey_Time['Trains_PH'] == n_Trains_PH][
                      Journey_Time['No_Blocks'] == n_Sig_blocks]))

def Return_JT_STD(n_Trains_PH, n_Sig_blocks):
    return (float(Journey_Time['STD_Journey_Time'][Journey_Time['Trains_PH'] == n_Trains_PH][
                      Journey_Time['No_Blocks'] == n_Sig_blocks]))

# %% [markdown]
# # greedy hill optimisation

# %%
def neighbours(x, y, xmin, xmax, ymin, ymax):
    return [(x + 1, y - 1) if x < xmax and 0 < y else None,
            (x + 1, y) if x < xmax else None,
            (x + 1, y + 1) if x < xmax and y < ymax else None,
            (x, y + 1) if y < ymax else None,
            (x - 1, y + 1) if 0 < x and y < ymax else None,
            (x - 1, y) if 0 < x else None,
            (x - 1, y - 1) if 0 < x and 0 < y else None,
            (x, y - 1) if 0 < y else None]


def Greedy_Hill_Climbing(f , df, var):
    Trains_PH_sort = sorted(Trains_PH)
    Sig_blocks_sort = sorted(Sig_blocks)

    Trains_PH_idx = range(len(Trains_PH_sort))
    Sig_blocks_idx = range(len(Sig_blocks_sort))

    x0 = random.choice(Trains_PH_idx)
    y0 = random.choice(Sig_blocks_idx)
    xp = [x0]
    yp = [y0]
    fmin = f(Trains_PH_sort[x0], Sig_blocks_sort[y0])

    xmin = 0
    ymin = 0
    xmax = len(Trains_PH_sort) - 1
    ymax = len(Sig_blocks_sort) - 1

    print(f"{' x'}{' y'}{'f(x, y)':>9s}")
    print(f"{x0:2d}{y0:2d}{fmin:9.3f}")

    while True:
        xi = xp[-1]
        yi = yp[-1]
        fi = fmin
        for xy in neighbours(xi, yi, xmin, xmax, ymin, ymax):
            if xy != None:
                x, y = xy
                ff = Return_JT(Trains_PH_sort[x], Sig_blocks_sort[y])
                if ff < fi:
                    xi = x
                    yi = y
                    fi = ff
        if fi == fmin:
            break

        xp += [xi]
        yp += [yi]
        fmin = fi
        print(f"{xi:2d}{yi:2d}{fi:9.3f}")
          
    df_melt = df[['Trains_PH','No_Blocks',var]].pivot(columns='Trains_PH', index='No_Blocks')

    fig, ax = plt.subplots(1, 1)
    fig.set_figwidth(6)
    fig.set_figheight(5)
    cs = ax.contourf(Trains_PH_sort, Sig_blocks_sort, df_melt.values, 100)
    fig.colorbar(cs, ax=ax)

    plt.plot([Trains_PH_sort[x] for x in xp], [Sig_blocks_sort[y] for y in yp], c='black', lw=1)
    return len(xp), Trains_PH_sort[xp[-1]], Trains_PH_sort[yp[-1]], f(Trains_PH_sort[xp[-1]],
                                                                              Sig_blocks_sort[yp[-1]])


Greedy_Hill_Climbing(Return_JT, Journey_Time, 'AVG_Journey_Time')
Greedy_Hill_Climbing(Return_JT, Journey_Time, 'STD_Journey_Time')
# Out:
#  x y  f(x, y)
#  7 1    1.236
#  8 1    1.197
#  9 1    1.193
# 10 2    1.160
#  x y  f(x, y)
#  0 1    1.860
#  1 2    1.342
#  2 3    1.205
#  2 4    1.183
#  3 5    1.144
#  3 6    1.106
#  3 7    1.104
#  4 8    1.096
#  4 9    1.095
# (9, 5, 15, 1.0948549940091983)

# %% [markdown]
# # Random Walk optimisation

# %%
def neighbours_Random(x, y, xmin, xmax, ymin, ymax):
    return ([(x + 1, y - 1)] if x < xmax and 0 < y else []
            ) + ([(x + 1, y)] if x < xmax else []
                 ) + ([(x + 1, y + 1)] if (x < xmax and y < ymax) else []
                      ) + ([(x, y + 1)] if (y < ymax) else []
                           ) + ([(x - 1, y + 1)] if (0 < x and y < ymax) else []
                                ) + ([(x - 1, y)] if (0 < x) else []
                                     ) + ([(x - 1, y - 1)] if (0 < x and 0 < y) else []
                                          ) + ([(x, y - 1)] if (0 < y) else [])


def Randomized_Hill_Climbing(f , df, var):
    Trains_PH_sort = sorted(Trains_PH)
    Sig_blocks_sort = sorted(Sig_blocks)

    Trains_PH_idx = range(len(Trains_PH_sort))
    Sig_blocks_idx = range(len(Sig_blocks_sort))

    x0 = random.choice(Trains_PH_idx)
    y0 = random.choice(Sig_blocks_idx)
    xp = [x0]
    yp = [y0]
    fmin = f(Trains_PH_sort[x0], Sig_blocks_sort[y0])

    xmin = 0
    ymin = 0
    xmax = len(Trains_PH_sort) - 1
    ymax = len(Sig_blocks_sort) - 1

    print(f"{' x'}{' y'}{'f(x, y)':>9s}")
    print(f"{x0:2d}{y0:2d}{fmin:9.3f}")

    while True:
        xi = xp[-1]
        yi = yp[-1]
        fi = fmin
        for xy in np.random.permutation(neighbours_Random(xi, yi, xmin, xmax, ymin, ymax)):
            x, y = xy
            ff = f(Trains_PH_sort[x], Sig_blocks_sort[y])
            if ff < fi:
                xi = x
                yi = y
                fi = ff
                break
        if fi == fmin:
            break

        xp += [xi]
        yp += [yi]
        fmin = fi
        print(f"{xi:2d}{yi:2d}{fi:9.3f}")
          
    df_melt = df[['Trains_PH','No_Blocks',var]].pivot(columns='Trains_PH', index='No_Blocks')

    fig, ax = plt.subplots(1, 1)
    fig.set_figwidth(6)
    fig.set_figheight(5)
    cs = ax.contourf(Trains_PH_sort, Sig_blocks_sort, df_melt.values, 100)
    fig.colorbar(cs, ax=ax)

    plt.plot([Trains_PH_sort[x] for x in xp], [Sig_blocks_sort[y] for y in yp], c='black', lw=1)
    return len(xp), Trains_PH_sort[xp[-1]], Trains_PH_sort[yp[-1]], f(Trains_PH_sort[xp[-1]],
                                                                              Sig_blocks_sort[yp[-1]])


Randomized_Hill_Climbing(Return_JT , Journey_Time, 'AVG_Journey_Time')
Randomized_Hill_Climbing(Return_JT , Journey_Time, 'STD_Journey_Time')
# Out:
#  x y  f(x, y)
#  9 0    1.349
# 10 1    1.199
#  9 1    1.193
# 10 2    1.160
#  x y  f(x, y)
# 10 1    1.199
# 10 2    1.160
# (2, 20, 3, 1.1598331437437275)

# %% [markdown]
# # Monte carlo optimisation

# %%
def Monte_Carlo(n, f, df, var):
    Trains_PH_sort = sorted(Trains_PH)
    Sig_blocks_sort = sorted(Sig_blocks)

    Trains_PH_idx = range(len(Trains_PH_sort))
    Sig_blocks_idx = range(len(Sig_blocks_sort))

    x = [random.choice(Trains_PH_idx) for i in range(n)]
    y = [random.choice(Sig_blocks_idx) for i in range(n)]
    xp = [x[0]]
    yp = [y[0]]
    fmin = f(Trains_PH_sort[xp[0]], Sig_blocks_sort[yp[0]])

    for i in range(1, len(x)):
        fi = f(Trains_PH_sort[x[i]], Sig_blocks_sort[y[i]])
        if fi < fmin:
            xp += [x[i]]
            yp += [y[i]]
            fmin = fi
            
    df_melt = df[['Trains_PH','No_Blocks',var]].pivot(columns='Trains_PH', index='No_Blocks')

    fig, ax = plt.subplots(1, 1)
    fig.set_figwidth(6)
    fig.set_figheight(5)
    cs = ax.contourf(Trains_PH_sort, Sig_blocks_sort, df_melt.values, 100)
    fig.colorbar(cs, ax=ax)

    plt.scatter([Trains_PH_sort[i] for i in x], [Sig_blocks_sort[i] for i in y], c='black', marker='.')

    plt.plot([Trains_PH_sort[i] for i in xp], [Sig_blocks_sort[i] for i in yp], c='black', lw=1)
    return len(xp), Trains_PH_sort[xp[-1]], Trains_PH_sort[yp[-1]], f(Trains_PH_sort[xp[-1]],
                                                                              Sig_blocks_sort[yp[-1]])


Monte_Carlo(60, Return_JT, Journey_Time, 'AVG_Journey_Time')
Monte_Carlo(60, Return_JT, Journey_Time, 'STD_Journey_Time')
# Out:
# (4, 6, 15, 1.097190355927192)

# %% [markdown]
# # result of optimisation
# Clearly the optimal solution to minimize journey time is to realease 5 trains per hour and use 10 signalling blocks. This is intuitive as the wait time for passengers is reasonable given the frequency of trains. The low frequency of trains means that disruption is infrequent along the stretch between London and Birmingham.
#
# Although this optimizes the journey time, it is below the economic requirement of 9 trains per hour. Assuming this as a constraint, the best option would be to use 20 Trains per hour and use two signalling blocks. The large frequency of trains means that wait times are very low and the small number of signalling blocks means that trains spend a lot of time at top speed.

# %% [markdown]
# # Half an hour delay at 9 am

# %%
no_of_blocks = 14
block_lenght = 10.36
avg_wait_time = 300
mean = 3.378
sigma = 0.751

# %%
acc_time = 113.3
maxV = 86.1
dist_covered = 4878
time_per_unit_distance = 0.023

# %%
def blocks(N):
    b1 = 1
    b3= 2
    b2=N-b1-b3
    return b1,b2,b3

# %%
def data(N):
    data = pd.DataFrame()
    for i in range(N): 
                data.at[i, 'From'] = 'S' + str(i+1)
                data.at[i, 'To'] = 'S' + str(i+2)
                data.at[i,'Direction'] = "LOOC_BI"
    
    return data

# %%
def structure_data(k):
    
    a,b,c = blocks(k)
    y = a+b+c+3
    
    dt = data(y)
            
    
    #Distance is splitted according to the number of blocks
    total_distance = 145000
    distance_split = total_distance / y
    
    dt['Distance'] = distance_split
    dt['Line'] = "HS2"
    dt['Running Time'] = ''
    dt['Dwell Time'] = np.random.lognormal(mean,sigma, size=y)
    
    
    dt['Max Acc.'] = 0.76
    dt['Max Vel.'] = 86.1
    
      
    return dt

# %%
random.seed(123)
dt = structure_data(10)
dt['Distance']=dt['Distance'].apply(lambda x: int(x))
dt['Dwell Time']=dt['Dwell Time'].apply(lambda x: int(x))
dt['From'] = dt['From'].replace(['S1'],'London Old Oak Common')
dt['To'] = dt['To'].replace(['S14'],'Birmingham Interchange')

# %%
def timeTo(a, maxV, d):
    # a       constant acceleration, m/s²
    # maxV    maximumum velocity, m/s
    # d       distance, km
    # return  time in seconds required to travel
    # 
    ta = maxV/a                       
    da = a*ta**2        # distance traveled during acceleration from 0 to maxV and back to 0
    if (d < da):        # train never reaches full speed?
        return np.sqrt(4.0*d/(a))     # time needed to accelerate to half-way point then decelerate to destination
    else:
        return (2*ta) + (d-da)/maxV   # time to accelerate to maxV plus travel at maxV plus decelerate to destination

# %%
dt['Drive Time'] = None
for i in range(len(dt)):
    dist = dt.at[i, 'Distance']
    a = dt.at[i, 'Max Acc.']
    v = dt.at[i, 'Max Vel.']
    dt.at[i, 'Drive Time']=int(timeTo(a, v, dist))

# %%
dt['Running Time'] = dt['Dwell Time'] + dt['Drive Time']

# %%
dt
# Out:
#                      From                      To Direction  Distance Line  \
# 0   London Old Oak Common                      S2   LOOC_BI     11153  HS2
# 1                      S2                      S3   LOOC_BI     11153  HS2
# 2                      S3                      S4   LOOC_BI     11153  HS2
# 3                      S4                      S5   LOOC_BI     11153  HS2
# 4                      S5                      S6   LOOC_BI     11153  HS2
# 5                      S6                      S7   LOOC_BI     11153  HS2
# 6                      S7                      S8   LOOC_BI     11153  HS2
# 7                      S8                      S9   LOOC_BI     11153  HS2
# 8                      S9                     S10   LOOC_BI     11153  HS2
# 9                     S10                     S11   LOOC_BI     11153  HS2
# 10                    S11                     S12   LOOC_BI     11153  HS2
# 11                    S12                     S13   LOOC_BI     11153  HS2
# 12                    S13  Birmingham Interchange   LOOC_BI     11153  HS2
#
#    Running Time  Dwell Time  Max Acc.  Max Vel. Drive Time
# 0           355         113      0.76      86.1        242
# 1           257          15      0.76      86.1        242
# 2           298          56      0.76      86.1        242
# 3           262          20      0.76      86.1        242
# 4           332          90      0.76      86.1        242
# 5           275          33      0.76      86.1        242
# 6           258          16      0.76      86.1        242
# 7           391         149      0.76      86.1        242
# 8           276          34      0.76      86.1        242
# 9           311          69      0.76      86.1        242
# 10          292          50      0.76      86.1        242
# 11          271          29      0.76      86.1        242
# 12          249           7      0.76      86.1        242

# %% [markdown]
# Creating plot function

# %%
def plot(data, xmin, xmax, pdf=None, bins=None, 
         μ=None, σ=None,
         
         title=None, xlabel=None, ylabel=None):
    
    fig = plt.figure()
    fig.set_figwidth(10)
    fig.set_figheight(5)
    ax = fig.gca()
    
    μ = np.mean(data)
    σ = np.std(data)  
    minx = min(data)
    maxx = max(data)
        
    ax.set_xlim(xmin, xmax)
    
    if title!=None:
        plt.title(title)
        
    plt.hist(data, bins=bins, density=True)
    
    # calculate parameter for text positioning
    dx=(xmax-xmin)*0.02
    ymin, ymax=plt.ylim()
    ypos=ymin+0.9*(ymax-ymin)
     
    # plot the probability density function if one is given
    if pdf!=None:
        X = list(np.linspace(xmin, xmax, 100))
        Y = [ pdf(x) for x in X]
        plt.plot(X, Y, lw=2, color='red')
 
    ax.axvline(x=μ, color='red', linestyle='dashed', lw=2)
    plt.text(μ+dx, ypos, f"μ={μ:3.2f}", color='red', fontsize=14)
    
    ax.axvline(x=minx, color='red', linestyle=':')
    ax.axvline(x=maxx, color='red', linestyle=':')

        
    plt.grid(True)

# %% [markdown]
# # Creating network class

# %%
class NetworkNode:
    
    def __init__(self, location, line):
        self.location=location
        self.line=line
        self.tracing=False
        self.incidents=[]

    # is only used in connection with tracing
    def setTrack(self, track):
        self.track=track
        
    def isTracing(self):
        return self.tracing and self.track.isTracing()
    
    def trace(self):
        self.tracing=True
        
    def trace_prefix(self, train):
        global max_line_name_length
        global max_direction_length
        return f"{now():s} " \
               f"{self.line:{max_line_name_length}s} " \
               f"[Train {train.getNo():2d} " \
               f"{train.getDirection():{max_direction_length}s}]"
    
    def arr(self, train):
        if self.isTracing() and train.isTracing():
            print(f"{self.trace_prefix(train):s} arr {self.loc():s}")        

    def dep(self, train, dest):
        if self.isTracing() and train.isTracing():
            print(f"{self.trace_prefix(train):s} dep {self.loc():s} for {dest.loc():s}")
        
    def loc(self):
        return self.location
    
    def __str__(self):
        return self.location
    

    def getResource(self):
        pass
    
    # NEW: Incident Handling
    # trace output for incident
    def inc(self, train):
        if self.isTracing() or train.isTracing():
            delay=self.incidentDelay()
            message=f"expected delay {daytime(delay):s}" if delay>0 else "incident cleared"
            print(f"{self.trace_prefix(train):s} inc {self.loc():s} {message:s}")        
            
    # registers an incident
    def registerIncident(self, incident):
        self.incidents+=[incident]
        
    # checks if there is currently an incident in progress
    # if yes, it returns True otherwise False
    def isIncident(self):
        for inc in self.incidents:
            if inc.active():
                return True
        return False
        
    # if there is currently an incident in progress it returns
    # the time the incident will probably continue, otherwise it returns 0
    def incidentDelay(self):
        stopTime=0
        for incident in self.incidents:
            if incident.active():
                stopTime=max(stopTime, incident.stopTime())
        return 0 if stopTime==0 else stopTime-env.now

# %%
class Depot(NetworkNode):
    def __init__(self, location, line, direction):
        super().__init__(location+" (DEPOT)", line)
        self.direction=direction
        
    def driveTime(self):
        return 20
    
    def dwellTime(self):
        return 10
    
    def dep(self, train, dest):
        train.setDirection(self.direction)
        super().dep(train, dest)
        
    def getResource(self):
        return None

# %%
class Station(NetworkNode):
    def __init__(self, location, line, direction):
        super().__init__(location, line)
        self.location=location
        self.line=line
        self.direction=direction
        self.resource=simpy.Resource(env, capacity=1)
        
        dd=dt[dt['Line']==self.line]
        dd=dd[dd['Direction']==self.direction]
        dd=dd[dd['From']==location]
        
        if len(dd)==0:
            # last node in a direction, the last passengers leave the train
            # and the train moves into the Cross-Over or the Depot
            self.drive_time=20
            self.dwell_time=60
        else:
            self.drive_time=dd.iloc[0].at['Drive Time']
            self.dwell_time=dd.iloc[0].at['Dwell Time']
            

    def driveTime(self):
        return self.drive_time
    
    def dwellTime(self):
        return self.dwell_time 
    
    def __str__(self):
        return self.location + " (" + self.direction[0] + ")"

    def getResource(self):
        return self.resource

# %%
class CrossOver(NetworkNode):
    def __init__(self, location, line, direction, capacity=2):
        super().__init__(location+" (X)", line)
        self.direction=direction
        self.resource=simpy.Resource(env, capacity=2)
        
    def driveTime(self):
        return 20
    
    def dwellTime(self):
        return 300
    
    def dep(self, train, dest):
        train.setDirection(self.direction)
        super().dep(train, dest)
        
    def getResource(self):
        return self.resource

# %%
class Track(object):
    def __init__(self, network, line, direction, depot, stations):
        self.network=network
        self.line=line
        self.direction=direction
        
        self.track=[depot]+stations+[depot]
        for s in self.track:
            s.setTrack(self)
            
        self.tracing=False
        self.tracingTrains=False
        self.tracingTrainNos=[]
    
    def isTracing(self):
        return self.tracing and self.network.isTracing()

    def isTracingTrains(self):
        return self.tracingTrains and self.network.isTracing()
    
    def trace(self, loc=None, train=None):
        self.tracing=True
        if loc is None:
            for s in self.track:
                s.trace()
            if train is not None:
                self.tracingTrains=True
                self.tracingTrainNos.append(train)
        else:
            for s in self.track:
                if s.loc()==loc:
                    s.trace()
            if train is not None:
                self.tracingTrains=True
                self.tracingTrainNos.append(train)

    def getNetwork(self):
        return self.network
    
    def getLine(self):
        return self.line
    
    def getStations(self):
        return self.track
    
    def setTiming(self, start, stop, timing):
        self.start=start*3600
        self.stop=stop*3600
        self.timing=timing
        
    def process(self):
        yield env.timeout(self.start-env.now) # the line starts operating at 6am
        for i in range(int((self.stop-self.start)/self.timing)):
            t=Train(i, self)
            if self.tracingTrains and i in self.tracingTrainNos:
                t.trace()
            env.process(t.process())
            yield env.timeout(self.timing)     
            
    def __str__(self):
        direction = "" if self.direction is None else " ("+self.direction+")"
        stations = " - ".join([ str(s) for s in self.track ])
        return self.line + direction + ": " + stations

# %%
def allStations(line, direction):
    dl=dt[dt['Line']==line]
    ds=dl[dl['Direction']==direction]
    stations=ds['From'].to_list()
    stations+=[ds['To'].to_list()[-1]]
    return [ Station(s, line, direction) for s in stations ]

# %%
def allTracks(network):
    lines=[]
    for line in dt['Line'].unique():
        directions=dt[dt['Line']==line]['Direction'].unique()
        stations=[ allStations(line, d) for d in directions]
    
        depot = Depot(stations[0][0].loc(), line, directions[0])
        #x = CrossOver(stations[0][-1].loc(), line, directions[1])
        l = Track(network, line, None, depot, stations[0])
        lines += [l]

    return lines

# %%
class Network(object):
    def __init__(self, start, stop, timing):
        self.tracks=allTracks(self)
        self.start=start
        self.stop=stop
        self.timing=timing
        
        self.tracing=False
        self.tracingStart=None
        self.tracingStop=None
        
    def isTracing(self):
        return self.tracing and \
                (self.tracingStart is None or self.tracingStart<=env.now) and \
                (self.tracingStop is None or env.now <= self.tracingStop)
    
    def trace(self, line=None, loc=None, train=None, start=None, stop=None):
        self.tracing = True
        self.tracingStart = parseTime(start)
        self.tracingStop = parseTime(stop)
        if line is None:
            for t in self.tracks:
                t.trace(loc=loc, train=train)
        else:
            for t in self.tracks:
                if t.getLine()==line:
                    t.trace(loc=loc, train=train)
    
    def registerIncident(self, start, stop, line=None, direction=None, loc=None):
        incident = Incident(start, stop)
        for t in self.tracks:
            if line is None or t.getLine()==line:
                for s in t.getStations():
                    if direction is None or s.getDirection()==direction:
                        if loc is None or s.loc()==loc:
                            s.registerIncident(incident)
    
    def process(self):
        for t in self.tracks:
            t.setTiming(self.start, self.stop, self.timing)
            yield env.timeout(self.start-env.now) # the line starts operating at 6am
            env.process(t.process())

# %%
class Train(object):  
    def __init__(self, i, track):
        self.no=i
        self.track = track

        self.direction = None
        self.tracing = False

    def setDirection(self, direction):
        self.direction=direction

    def getDirection(self):
        return self.direction
    
    def getNo(self):
        return self.no
    
    def isTracing(self):
        return self.track.isTracing() and \
                (not self.track.isTracingTrains() or self.tracing)
    
    def trace(self):
        self.tracing=True
            
    def traceOff(self):
        self.tracing=False
        
    def process(self):

        stations = self.track.getStations()
        
        here = stations[0]
        here_req = None
        
        for dest in stations[1:]:
            
  
            drivetime=here.driveTime()
            dwelltime=here.dwellTime()
            
            yield env.timeout(dwelltime)

            if here.isIncident():
                here.inc(self)
                yield env.timeout(here.incidentDelay())
                here.inc(self)
                
            if dest.getResource() is not None:
                dest_req = dest.getResource().request()
                yield dest_req
            else:
                dest_req = None
            
            # if the train doesn't get immediate access, it continues waiting 
            # in the current station ('here').
            # if the train got access the train departs from 'here'for 'dest'
            
            here.dep(self, dest)
            
            # Once the train has completely left the station, the train
            # will release the track of station ('here'). 
            # We assume that the train has left the station after 10 secs  
            delaytime=min(drivetime, 10)
            yield env.timeout(delaytime)
            if here_req is not None:
                here.getResource().release(here_req)

            # the train proceeds to drive to the next station ('dest')
            yield env.timeout(drivetime-delaytime)
            
            dest.arr(self)
            here = dest
            here_req=dest_req

# %%
class Incident:
    
    def __init__(self, start, stop):
        self.start = parseTime(start)
        self.stop = parseTime(stop)
        
    def active(self):
        return self.start <= env.now and env.now <= self.stop
    
    def startTime(self):
        return self.start
    
    def stopTime(self):
        return self.stop

# %%
max_line_name_length = max([len(line) for line in dt['Line'].unique()])
max_direction_length = max([len(line) for line in dt['Direction'].unique()])

# %%
def isPeakTime():
    now=env.now
    return (3600*7<=now and now<=3600*10) or \
           (3600*16<=now and now<=3600*19)

# %%
def daytime(t):
    t=int(t)
    return f"{t//3600:02d}:{(t%3600)//60:02d}:{t%60:02d}"
def now():
    return daytime(env.now)

def parseTime(s):
    if s is None:
        return None
    if isinstance(s, str):
        parts=s.split(':')
        if len(parts)>=2:
            hours=int(parts[0])
            minutes=int(parts[1])
            seconds=0 if len(parts)==2 else int(parts[2])
            return 3600*hours+60*minutes+seconds
    print("WARNING Parsing Error:", s)
    # any wrong formats will be passed through and may cause 
    # an error at a later stage
    return s

# %%
env = simpy.Environment()
network=Network(7, 22, 300)
network.trace(line='HS2', start="07:00", stop="22:00")
network.registerIncident(start="09:00", stop="09:35", 
                         line='HS2', loc="London Old Oak Common")
env.process(network.process())
env.run()
# Out:
# 07:00:10 HS2 [Train  0 LOOC_BI] dep London Old Oak Common (DEPOT) for London Old Oak Common
# 07:00:30 HS2 [Train  0 LOOC_BI] arr London Old Oak Common
# 07:02:23 HS2 [Train  0 LOOC_BI] dep London Old Oak Common for S2
# 07:05:10 HS2 [Train  1 LOOC_BI] dep London Old Oak Common (DEPOT) for London Old Oak Common
# 07:05:30 HS2 [Train  1 LOOC_BI] arr London Old Oak Common
# 07:06:25 HS2 [Train  0 LOOC_BI] arr S2
# 07:06:40 HS2 [Train  0 LOOC_BI] dep S2 for S3
# 07:07:23 HS2 [Train  1 LOOC_BI] dep London Old Oak Common for S2
# 07:10:10 HS2 [Train  2 LOOC_BI] dep London Old Oak Common (DEPOT) for London Old Oak Common
# 07:10:30 HS2 [Train  2 LOOC_BI] arr London Old Oak Common
# 07:10:42 HS2 [Train  0 LOOC_BI] arr S3
# 07:11:25 HS2 [Train  1 LOOC_BI] arr S2
# 07:11:38 HS2 [Train  0 LOOC_BI] dep S3 for S4
# 07:11:48 HS2 [Train  1 LOOC_BI] dep S2 for S3
# 07:12:23 HS2 [Train  2 LOOC_BI] dep London Old Oak Common for S2
# 07:15:10 HS2 [Train  3 LOOC_BI] dep London Old Oak Common (DEPOT) for London Old Oak Common
# 07:15:30 HS2 [Train  3 LOOC_BI] arr London Old Oak Common
# 07:15:40 HS2 [Train  0 LOOC_BI] arr S4
# 07:15:50 HS2 [Train  1 LOOC_BI] arr S3
# 07:16:00 HS2 [Train  0 LOOC_BI] dep S4 for S5
# 07:16:25 HS2 [Train  2 LOOC_BI] arr S2
# 07:16:46 HS2 [Train  1 LOOC_BI] dep S3 for S4
# 07:16:56 HS2 [Train  2 LOOC_BI] dep S2 for S3
# 07:17:23 HS2 [Train  3 LOOC_BI] dep London Old Oak Common for S2
# 07:20:02 HS2 [Train  0 LOOC_BI] arr S5
# 07:20:10 HS2 [Train  4 LOOC_BI] dep London Old Oak Common (DEPOT) for London Old Oak Common
# 07:20:30 HS2 [Train  4 LOOC_BI] arr London Old Oak Common
# 07:20:48 HS2 [Train  1 LOOC_BI] arr S4
# 07:20:58 HS2 [Train  2 LOOC_BI] arr S3
# 07:21:25 HS2 [Train  3 LOOC_BI] arr S2
# 07:21:32 HS2 [Train  0 LOOC_BI] dep S5 for S6
# 07:21:42 HS2 [Train  1 LOOC_BI] dep S4 for S5
# 07:21:54 HS2 [Train  2 LOOC_BI] dep S3 for S4
# 07:22:04 HS2 [Train  3 LOOC_BI] dep S2 for S3
# 07:22:23 HS2 [Train  4 LOOC_BI] dep London Old Oak Common for S2
# 07:25:10 HS2 [Train  5 LOOC_BI] dep London Old Oak Common (DEPOT) for London Old Oak Common
# 07:25:30 HS2 [Train  5 LOOC_BI] arr London Old Oak Common
# 07:25:34 HS2 [Train  0 LOOC_BI] arr S6
# 07:25:44 HS2 [Train  1 LOOC_BI] arr S5
# 07:25:56 HS2 [Train  2 LOOC_BI] arr S4
# 07:26:06 HS2 [Train  3 LOOC_BI] arr S3
# 07:26:07 HS2 [Train  0 LOOC_BI] dep S6 for S7
# 07:26:25 HS2 [Train  4 LOOC_BI] arr S2
# 07:27:14 HS2 [Train  1 LOOC_BI] dep S5 for S6
# 07:27:24 HS2 [Train  2 LOOC_BI] dep S4 for S5
# 07:27:34 HS2 [Train  3 LOOC_BI] dep S3 for S4
# 07:27:44 HS2 [Train  4 LOOC_BI] dep S2 for S3
# 07:27:54 HS2 [Train  5 LOOC_BI] dep London Old Oak Common for S2
# 07:30:09 HS2 [Train  0 LOOC_BI] arr S7
# 07:30:10 HS2 [Train  6 LOOC_BI] dep London Old Oak Common (DEPOT) for London Old Oak Common
# 07:30:25 HS2 [Train  0 LOOC_BI] dep S7 for S8
# 07:30:30 HS2 [Train  6 LOOC_BI] arr London Old Oak Common
# 07:31:16 HS2 [Train  1 LOOC_BI] arr S6
# 07:31:26 HS2 [Train  2 LOOC_BI] arr S5
# 07:31:36 HS2 [Train  3 LOOC_BI] arr S4
# 07:31:46 HS2 [Train  4 LOOC_BI] arr S3
# 07:31:49 HS2 [Train  1 LOOC_BI] dep S6 for S7
# 07:31:56 HS2 [Train  5 LOOC_BI] arr S2
# 07:32:56 HS2 [Train  2 LOOC_BI] dep S5 for S6
# 07:33:06 HS2 [Train  3 LOOC_BI] dep S4 for S5
# 07:33:16 HS2 [Train  4 LOOC_BI] dep S3 for S4
# 07:33:26 HS2 [Train  5 LOOC_BI] dep S2 for S3
# 07:33:36 HS2 [Train  6 LOOC_BI] dep London Old Oak Common for S2
# 07:34:27 HS2 [Train  0 LOOC_BI] arr S8
# 07:35:10 HS2 [Train  7 LOOC_BI] dep London Old Oak Common (DEPOT) for London Old Oak Common
# 07:35:30 HS2 [Train  7 LOOC_BI] arr London Old Oak Common
# 07:35:51 HS2 [Train  1 LOOC_BI] arr S7
# 07:36:56 HS2 [Train  0 LOOC_BI] dep S8 for S9
# 07:36:58 HS2 [Train  2 LOOC_BI] arr S6
# 07:37:06 HS2 [Train  1 LOOC_BI] dep S7 for S8
# 07:37:08 HS2 [Train  3 LOOC_BI] arr S5
# 07:37:18 HS2 [Train  4 LOOC_BI] arr S4
# 07:37:28 HS2 [Train  5 LOOC_BI] arr S3
# 07:37:31 HS2 [Train  2 LOOC_BI] dep S6 for S7
# 07:37:38 HS2 [Train  6 LOOC_BI] arr S2
# 07:38:38 HS2 [Train  3 LOOC_BI] dep S5 for S6
# 07:38:48 HS2 [Train  4 LOOC_BI] dep S4 for S5
# 07:38:58 HS2 [Train  5 LOOC_BI] dep S3 for S4
# 07:39:08 HS2 [Train  6 LOOC_BI] dep S2 for S3
# 07:39:18 HS2 [Train  7 LOOC_BI] dep London Old Oak Common for S2
# 07:40:10 HS2 [Train  8 LOOC_BI] dep London Old Oak Common (DEPOT) for London Old Oak Common
# 07:40:30 HS2 [Train  8 LOOC_BI] arr London Old Oak Common
# 07:40:58 HS2 [Train  0 LOOC_BI] arr S9
# 07:41:08 HS2 [Train  1 LOOC_BI] arr S8
# 07:41:32 HS2 [Train  0 LOOC_BI] dep S9 for S10
# 07:41:33 HS2 [Train  2 LOOC_BI] arr S7
# 07:42:40 HS2 [Train  3 LOOC_BI] arr S6
# 07:42:50 HS2 [Train  4 LOOC_BI] arr S5
# 07:43:00 HS2 [Train  5 LOOC_BI] arr S4
# 07:43:10 HS2 [Train  6 LOOC_BI] arr S3
# 07:43:20 HS2 [Train  7 LOOC_BI] arr S2
# 07:43:37 HS2 [Train  1 LOOC_BI] dep S8 for S9
# 07:43:47 HS2 [Train  2 LOOC_BI] dep S7 for S8
# 07:43:57 HS2 [Train  3 LOOC_BI] dep S6 for S7
# 07:44:20 HS2 [Train  4 LOOC_BI] dep S5 for S6
# 07:44:30 HS2 [Train  5 LOOC_BI] dep S4 for S5
# 07:44:40 HS2 [Train  6 LOOC_BI] dep S3 for S4
# 07:44:50 HS2 [Train  7 LOOC_BI] dep S2 for S3
# 07:45:00 HS2 [Train  8 LOOC_BI] dep London Old Oak Common for S2
# 07:45:10 HS2 [Train  9 LOOC_BI] dep London Old Oak Common (DEPOT) for London Old Oak Common
# 07:45:30 HS2 [Train  9 LOOC_BI] arr London Old Oak Common
# 07:45:34 HS2 [Train  0 LOOC_BI] arr S10
# 07:46:43 HS2 [Train  0 LOOC_BI] dep S10 for S11
# 07:47:39 HS2 [Train  1 LOOC_BI] arr S9
# 07:47:49 HS2 [Train  2 LOOC_BI] arr S8
# 07:47:59 HS2 [Train  3 LOOC_BI] arr S7
# 07:48:13 HS2 [Train  1 LOOC_BI] dep S9 for S10
# 07:48:22 HS2 [Train  4 LOOC_BI] arr S6
# 07:48:32 HS2 [Train  5 LOOC_BI] arr S5
# 07:48:42 HS2 [Train  6 LOOC_BI] arr S4
# 07:48:52 HS2 [Train  7 LOOC_BI] arr S3
# 07:49:02 HS2 [Train  8 LOOC_BI] arr S2
# 07:50:18 HS2 [Train  2 LOOC_BI] dep S8 for S9
# 07:50:28 HS2 [Train  3 LOOC_BI] dep S7 for S8
# 07:50:38 HS2 [Train  4 LOOC_BI] dep S6 for S7
# 07:50:45 HS2 [Train  0 LOOC_BI] arr S11
# 07:50:48 HS2 [Train  5 LOOC_BI] dep S5 for S6
# 07:50:58 HS2 [Train  6 LOOC_BI] dep S4 for S5
# 07:51:08 HS2 [Train  7 LOOC_BI] dep S3 for S4
# 07:51:18 HS2 [Train  8 LOOC_BI] dep S2 for S3
# 07:51:28 HS2 [Train  9 LOOC_BI] dep London Old Oak Common for S2
# 07:51:35 HS2 [Train  0 LOOC_BI] dep S11 for S12
# 07:51:38 HS2 [Train 10 LOOC_BI] dep London Old Oak Common (DEPOT) for London Old Oak Common
# 07:51:58 HS2 [Train 10 LOOC_BI] arr London Old Oak Common
# 07:52:15 HS2 [Train  1 LOOC_BI] arr S10
# 07:53:24 HS2 [Train  1 LOOC_BI] dep S10 for S11
# 07:54:20 HS2 [Train  2 LOOC_BI] arr S9
# 07:54:30 HS2 [Train  3 LOOC_BI] arr S8
# 07:54:40 HS2 [Train  4 LOOC_BI] arr S7
# 07:54:50 HS2 [Train  5 LOOC_BI] arr S6
# 07:54:54 HS2 [Train  2 LOOC_BI] dep S9 for S10
# 07:55:00 HS2 [Train  6 LOOC_BI] arr S5
# 07:55:10 HS2 [Train  7 LOOC_BI] arr S4
# 07:55:20 HS2 [Train  8 LOOC_BI] arr S3
# 07:55:30 HS2 [Train  9 LOOC_BI] arr S2
# 07:55:37 HS2 [Train  0 LOOC_BI] arr S12
# 07:56:06 HS2 [Train  0 LOOC_BI] dep S12 for S13
# 07:56:59 HS2 [Train  3 LOOC_BI] dep S8 for S9
# 07:57:09 HS2 [Train  4 LOOC_BI] dep S7 for S8
# 07:57:19 HS2 [Train  5 LOOC_BI] dep S6 for S7
# 07:57:26 HS2 [Train  1 LOOC_BI] arr S11
# 07:57:29 HS2 [Train  6 LOOC_BI] dep S5 for S6
# 07:57:39 HS2 [Train  7 LOOC_BI] dep S4 for S5
# 07:57:49 HS2 [Train  8 LOOC_BI] dep S3 for S4
# 07:57:59 HS2 [Train  9 LOOC_BI] dep S2 for S3
# 07:58:09 HS2 [Train 10 LOOC_BI] dep London Old Oak Common for S2
# 07:58:16 HS2 [Train  1 LOOC_BI] dep S11 for S12
# 07:58:19 HS2 [Train 11 LOOC_BI] dep London Old Oak Common (DEPOT) for London Old Oak Common
# 07:58:39 HS2 [Train 11 LOOC_BI] arr London Old Oak Common
# 07:58:56 HS2 [Train  2 LOOC_BI] arr S10
# 08:00:05 HS2 [Train  2 LOOC_BI] dep S10 for S11
# 08:00:08 HS2 [Train  0 LOOC_BI] arr S13
# 08:00:15 HS2 [Train  0 LOOC_BI] dep S13 for Birmingham Interchange
# 08:01:01 HS2 [Train  3 LOOC_BI] arr S9
# 08:01:11 HS2 [Train  4 LOOC_BI] arr S8
# 08:01:21 HS2 [Train  5 LOOC_BI] arr S7
# 08:01:31 HS2 [Train  6 LOOC_BI] arr S6
# 08:01:35 HS2 [Train  3 LOOC_BI] dep S9 for S10
# 08:01:41 HS2 [Train  7 LOOC_BI] arr S5
# 08:01:51 HS2 [Train  8 LOOC_BI] arr S4
# 08:02:01 HS2 [Train  9 LOOC_BI] arr S3
# 08:02:11 HS2 [Train 10 LOOC_BI] arr S2
# 08:02:18 HS2 [Train  1 LOOC_BI] arr S12
# 08:02:47 HS2 [Train  1 LOOC_BI] dep S12 for S13
# 08:03:40 HS2 [Train  4 LOOC_BI] dep S8 for S9
# 08:03:50 HS2 [Train  5 LOOC_BI] dep S7 for S8
# 08:04:00 HS2 [Train  6 LOOC_BI] dep S6 for S7
# 08:04:07 HS2 [Train  2 LOOC_BI] arr S11
# 08:04:10 HS2 [Train  7 LOOC_BI] dep S5 for S6
# 08:04:17 HS2 [Train  0 LOOC_BI] arr Birmingham Interchange
# 08:04:20 HS2 [Train  8 LOOC_BI] dep S4 for S5
# 08:04:30 HS2 [Train  9 LOOC_BI] dep S3 for S4
# 08:04:40 HS2 [Train 10 LOOC_BI] dep S2 for S3
# 08:04:50 HS2 [Train 11 LOOC_BI] dep London Old Oak Common for S2
# 08:04:57 HS2 [Train  2 LOOC_BI] dep S11 for S12
# 08:05:00 HS2 [Train 12 LOOC_BI] dep London Old Oak Common (DEPOT) for London Old Oak Common
# 08:05:17 HS2 [Train  0 LOOC_BI] dep Birmingham Interchange for London Old Oak Common (DEPOT)
# 08:05:20 HS2 [Train 12 LOOC_BI] arr London Old Oak Common
# 08:05:37 HS2 [Train  3 LOOC_BI] arr S10
# 08:05:37 HS2 [Train  0 LOOC_BI] arr London Old Oak Common (DEPOT)
# 08:06:46 HS2 [Train  3 LOOC_BI] dep S10 for S11
# 08:06:49 HS2 [Train  1 LOOC_BI] arr S13
# 08:06:56 HS2 [Train  1 LOOC_BI] dep S13 for Birmingham Interchange
# 08:07:42 HS2 [Train  4 LOOC_BI] arr S9
# 08:07:52 HS2 [Train  5 LOOC_BI] arr S8
# 08:08:02 HS2 [Train  6 LOOC_BI] arr S7
# 08:08:12 HS2 [Train  7 LOOC_BI] arr S6
# 08:08:16 HS2 [Train  4 LOOC_BI] dep S9 for S10
# 08:08:22 HS2 [Train  8 LOOC_BI] arr S5
# 08:08:32 HS2 [Train  9 LOOC_BI] arr S4
# 08:08:42 HS2 [Train 10 LOOC_BI] arr S3
# 08:08:52 HS2 [Train 11 LOOC_BI] arr S2
# 08:08:59 HS2 [Train  2 LOOC_BI] arr S12
# 08:09:28 HS2 [Train  2 LOOC_BI] dep S12 for S13
# 08:10:21 HS2 [Train  5 LOOC_BI] dep S8 for S9
# 08:10:31 HS2 [Train  6 LOOC_BI] dep S7 for S8
# 08:10:41 HS2 [Train  7 LOOC_BI] dep S6 for S7
# 08:10:48 HS2 [Train  3 LOOC_BI] arr S11
# 08:10:51 HS2 [Train  8 LOOC_BI] dep S5 for S6
# 08:10:58 HS2 [Train  1 LOOC_BI] arr Birmingham Interchange
# 08:11:01 HS2 [Train  9 LOOC_BI] dep S4 for S5
# 08:11:11 HS2 [Train 10 LOOC_BI] dep S3 for S4
# 08:11:21 HS2 [Train 11 LOOC_BI] dep S2 for S3
# 08:11:31 HS2 [Train 12 LOOC_BI] dep London Old Oak Common for S2
# 08:11:38 HS2 [Train  3 LOOC_BI] dep S11 for S12
# 08:11:41 HS2 [Train 13 LOOC_BI] dep London Old Oak Common (DEPOT) for London Old Oak Common
# 08:11:58 HS2 [Train  1 LOOC_BI] dep Birmingham Interchange for London Old Oak Common (DEPOT)
# 08:12:01 HS2 [Train 13 LOOC_BI] arr London Old Oak Common
# 08:12:18 HS2 [Train  4 LOOC_BI] arr S10
# 08:12:18 HS2 [Train  1 LOOC_BI] arr London Old Oak Common (DEPOT)
# 08:13:27 HS2 [Train  4 LOOC_BI] dep S10 for S11
# 08:13:30 HS2 [Train  2 LOOC_BI] arr S13
# 08:13:37 HS2 [Train  2 LOOC_BI] dep S13 for Birmingham Interchange
# 08:14:23 HS2 [Train  5 LOOC_BI] arr S9
# 08:14:33 HS2 [Train  6 LOOC_BI] arr S8
# 08:14:43 HS2 [Train  7 LOOC_BI] arr S7
# 08:14:53 HS2 [Train  8 LOOC_BI] arr S6
# 08:14:57 HS2 [Train  5 LOOC_BI] dep S9 for S10
# 08:15:03 HS2 [Train  9 LOOC_BI] arr S5
# 08:15:13 HS2 [Train 10 LOOC_BI] arr S4
# 08:15:23 HS2 [Train 11 LOOC_BI] arr S3
# 08:15:33 HS2 [Train 12 LOOC_BI] arr S2
# 08:15:40 HS2 [Train  3 LOOC_BI] arr S12
# 08:16:09 HS2 [Train  3 LOOC_BI] dep S12 for S13
# 08:17:02 HS2 [Train  6 LOOC_BI] dep S8 for S9
# 08:17:12 HS2 [Train  7 LOOC_BI] dep S7 for S8
# 08:17:22 HS2 [Train  8 LOOC_BI] dep S6 for S7
# 08:17:29 HS2 [Train  4 LOOC_BI] arr S11
# 08:17:32 HS2 [Train  9 LOOC_BI] dep S5 for S6
# 08:17:39 HS2 [Train  2 LOOC_BI] arr Birmingham Interchange
# 08:17:42 HS2 [Train 10 LOOC_BI] dep S4 for S5
# 08:17:52 HS2 [Train 11 LOOC_BI] dep S3 for S4
# 08:18:02 HS2 [Train 12 LOOC_BI] dep S2 for S3
# 08:18:12 HS2 [Train 13 LOOC_BI] dep London Old Oak Common for S2
# 08:18:19 HS2 [Train  4 LOOC_BI] dep S11 for S12
# 08:18:22 HS2 [Train 14 LOOC_BI] dep London Old Oak Common (DEPOT) for London Old Oak Common
# 08:18:39 HS2 [Train  2 LOOC_BI] dep Birmingham Interchange for London Old Oak Common (DEPOT)
# 08:18:42 HS2 [Train 14 LOOC_BI] arr London Old Oak Common
# 08:18:59 HS2 [Train  5 LOOC_BI] arr S10
# 08:18:59 HS2 [Train  2 LOOC_BI] arr London Old Oak Common (DEPOT)
# 08:20:08 HS2 [Train  5 LOOC_BI] dep S10 for S11
# 08:20:11 HS2 [Train  3 LOOC_BI] arr S13
# 08:20:18 HS2 [Train  3 LOOC_BI] dep S13 for Birmingham Interchange
# 08:21:04 HS2 [Train  6 LOOC_BI] arr S9
# 08:21:14 HS2 [Train  7 LOOC_BI] arr S8
# 08:21:24 HS2 [Train  8 LOOC_BI] arr S7
# 08:21:34 HS2 [Train  9 LOOC_BI] arr S6
# 08:21:38 HS2 [Train  6 LOOC_BI] dep S9 for S10
# 08:21:44 HS2 [Train 10 LOOC_BI] arr S5
# 08:21:54 HS2 [Train 11 LOOC_BI] arr S4
# 08:22:04 HS2 [Train 12 LOOC_BI] arr S3
# 08:22:14 HS2 [Train 13 LOOC_BI] arr S2
# 08:22:21 HS2 [Train  4 LOOC_BI] arr S12
# 08:22:50 HS2 [Train  4 LOOC_BI] dep S12 for S13
# 08:23:43 HS2 [Train  7 LOOC_BI] dep S8 for S9
# 08:23:53 HS2 [Train  8 LOOC_BI] dep S7 for S8
# 08:24:03 HS2 [Train  9 LOOC_BI] dep S6 for S7
# 08:24:10 HS2 [Train  5 LOOC_BI] arr S11
# 08:24:13 HS2 [Train 10 LOOC_BI] dep S5 for S6
# 08:24:20 HS2 [Train  3 LOOC_BI] arr Birmingham Interchange
# 08:24:23 HS2 [Train 11 LOOC_BI] dep S4 for S5
# 08:24:33 HS2 [Train 12 LOOC_BI] dep S3 for S4
# 08:24:43 HS2 [Train 13 LOOC_BI] dep S2 for S3
# 08:24:53 HS2 [Train 14 LOOC_BI] dep London Old Oak Common for S2
# 08:25:00 HS2 [Train  5 LOOC_BI] dep S11 for S12
# 08:25:03 HS2 [Train 15 LOOC_BI] dep London Old Oak Common (DEPOT) for London Old Oak Common
# 08:25:20 HS2 [Train  3 LOOC_BI] dep Birmingham Interchange for London Old Oak Common (DEPOT)
# 08:25:23 HS2 [Train 15 LOOC_BI] arr London Old Oak Common
# 08:25:40 HS2 [Train  6 LOOC_BI] arr S10
# 08:25:40 HS2 [Train  3 LOOC_BI] arr London Old Oak Common (DEPOT)
# 08:26:49 HS2 [Train  6 LOOC_BI] dep S10 for S11
# 08:26:52 HS2 [Train  4 LOOC_BI] arr S13
# 08:26:59 HS2 [Train  4 LOOC_BI] dep S13 for Birmingham Interchange
# 08:27:45 HS2 [Train  7 LOOC_BI] arr S9
# 08:27:55 HS2 [Train  8 LOOC_BI] arr S8
# 08:28:05 HS2 [Train  9 LOOC_BI] arr S7
# 08:28:15 HS2 [Train 10 LOOC_BI] arr S6
# 08:28:19 HS2 [Train  7 LOOC_BI] dep S9 for S10
# 08:28:25 HS2 [Train 11 LOOC_BI] arr S5
# 08:28:35 HS2 [Train 12 LOOC_BI] arr S4
# 08:28:45 HS2 [Train 13 LOOC_BI] arr S3
# 08:28:55 HS2 [Train 14 LOOC_BI] arr S2
# 08:29:02 HS2 [Train  5 LOOC_BI] arr S12
# 08:29:31 HS2 [Train  5 LOOC_BI] dep S12 for S13
# 08:30:24 HS2 [Train  8 LOOC_BI] dep S8 for S9
# 08:30:34 HS2 [Train  9 LOOC_BI] dep S7 for S8
# 08:30:44 HS2 [Train 10 LOOC_BI] dep S6 for S7
# 08:30:51 HS2 [Train  6 LOOC_BI] arr S11
# 08:30:54 HS2 [Train 11 LOOC_BI] dep S5 for S6
# 08:31:01 HS2 [Train  4 LOOC_BI] arr Birmingham Interchange
# 08:31:04 HS2 [Train 12 LOOC_BI] dep S4 for S5
# 08:31:14 HS2 [Train 13 LOOC_BI] dep S3 for S4
# 08:31:24 HS2 [Train 14 LOOC_BI] dep S2 for S3
# 08:31:34 HS2 [Train 15 LOOC_BI] dep London Old Oak Common for S2
# 08:31:41 HS2 [Train  6 LOOC_BI] dep S11 for S12
# 08:31:44 HS2 [Train 16 LOOC_BI] dep London Old Oak Common (DEPOT) for London Old Oak Common
# 08:32:01 HS2 [Train  4 LOOC_BI] dep Birmingham Interchange for London Old Oak Common (DEPOT)
# 08:32:04 HS2 [Train 16 LOOC_BI] arr London Old Oak Common
# 08:32:21 HS2 [Train  7 LOOC_BI] arr S10
# 08:32:21 HS2 [Train  4 LOOC_BI] arr London Old Oak Common (DEPOT)
# 08:33:30 HS2 [Train  7 LOOC_BI] dep S10 for S11
# 08:33:33 HS2 [Train  5 LOOC_BI] arr S13
# 08:33:40 HS2 [Train  5 LOOC_BI] dep S13 for Birmingham Interchange
# 08:34:26 HS2 [Train  8 LOOC_BI] arr S9
# 08:34:36 HS2 [Train  9 LOOC_BI] arr S8
# 08:34:46 HS2 [Train 10 LOOC_BI] arr S7
# 08:34:56 HS2 [Train 11 LOOC_BI] arr S6
# 08:35:00 HS2 [Train  8 LOOC_BI] dep S9 for S10
# 08:35:06 HS2 [Train 12 LOOC_BI] arr S5
# 08:35:16 HS2 [Train 13 LOOC_BI] arr S4
# 08:35:26 HS2 [Train 14 LOOC_BI] arr S3
# 08:35:36 HS2 [Train 15 LOOC_BI] arr S2
# 08:35:43 HS2 [Train  6 LOOC_BI] arr S12
# 08:36:12 HS2 [Train  6 LOOC_BI] dep S12 for S13
# 08:37:05 HS2 [Train  9 LOOC_BI] dep S8 for S9
# 08:37:15 HS2 [Train 10 LOOC_BI] dep S7 for S8
# 08:37:25 HS2 [Train 11 LOOC_BI] dep S6 for S7
# 08:37:32 HS2 [Train  7 LOOC_BI] arr S11
# 08:37:35 HS2 [Train 12 LOOC_BI] dep S5 for S6
# 08:37:42 HS2 [Train  5 LOOC_BI] arr Birmingham Interchange
# 08:37:45 HS2 [Train 13 LOOC_BI] dep S4 for S5
# 08:37:55 HS2 [Train 14 LOOC_BI] dep S3 for S4
# 08:38:05 HS2 [Train 15 LOOC_BI] dep S2 for S3
# 08:38:15 HS2 [Train 16 LOOC_BI] dep London Old Oak Common for S2
# 08:38:22 HS2 [Train  7 LOOC_BI] dep S11 for S12
# 08:38:25 HS2 [Train 17 LOOC_BI] dep London Old Oak Common (DEPOT) for London Old Oak Common
# 08:38:42 HS2 [Train  5 LOOC_BI] dep Birmingham Interchange for London Old Oak Common (DEPOT)
# 08:38:45 HS2 [Train 17 LOOC_BI] arr London Old Oak Common
# 08:39:02 HS2 [Train  8 LOOC_BI] arr S10
# 08:39:02 HS2 [Train  5 LOOC_BI] arr London Old Oak Common (DEPOT)
# 08:40:11 HS2 [Train  8 LOOC_BI] dep S10 for S11
# 08:40:14 HS2 [Train  6 LOOC_BI] arr S13
# 08:40:21 HS2 [Train  6 LOOC_BI] dep S13 for Birmingham Interchange
# 08:41:07 HS2 [Train  9 LOOC_BI] arr S9
# 08:41:17 HS2 [Train 10 LOOC_BI] arr S8
# 08:41:27 HS2 [Train 11 LOOC_BI] arr S7
# 08:41:37 HS2 [Train 12 LOOC_BI] arr S6
# 08:41:41 HS2 [Train  9 LOOC_BI] dep S9 for S10
# 08:41:47 HS2 [Train 13 LOOC_BI] arr S5
# 08:41:57 HS2 [Train 14 LOOC_BI] arr S4
# 08:42:07 HS2 [Train 15 LOOC_BI] arr S3
# 08:42:17 HS2 [Train 16 LOOC_BI] arr S2
# 08:42:24 HS2 [Train  7 LOOC_BI] arr S12
# 08:42:53 HS2 [Train  7 LOOC_BI] dep S12 for S13
# 08:43:46 HS2 [Train 10 LOOC_BI] dep S8 for S9
# 08:43:56 HS2 [Train 11 LOOC_BI] dep S7 for S8
# 08:44:06 HS2 [Train 12 LOOC_BI] dep S6 for S7
# 08:44:13 HS2 [Train  8 LOOC_BI] arr S11
# 08:44:16 HS2 [Train 13 LOOC_BI] dep S5 for S6
# 08:44:23 HS2 [Train  6 LOOC_BI] arr Birmingham Interchange
# 08:44:26 HS2 [Train 14 LOOC_BI] dep S4 for S5
# 08:44:36 HS2 [Train 15 LOOC_BI] dep S3 for S4
# 08:44:46 HS2 [Train 16 LOOC_BI] dep S2 for S3
# 08:44:56 HS2 [Train 17 LOOC_BI] dep London Old Oak Common for S2
# 08:45:03 HS2 [Train  8 LOOC_BI] dep S11 for S12
# 08:45:06 HS2 [Train 18 LOOC_BI] dep London Old Oak Common (DEPOT) for London Old Oak Common
# 08:45:23 HS2 [Train  6 LOOC_BI] dep Birmingham Interchange for London Old Oak Common (DEPOT)
# 08:45:26 HS2 [Train 18 LOOC_BI] arr London Old Oak Common
# 08:45:43 HS2 [Train  9 LOOC_BI] arr S10
# 08:45:43 HS2 [Train  6 LOOC_BI] arr London Old Oak Common (DEPOT)
# 08:46:52 HS2 [Train  9 LOOC_BI] dep S10 for S11
# 08:46:55 HS2 [Train  7 LOOC_BI] arr S13
# 08:47:02 HS2 [Train  7 LOOC_BI] dep S13 for Birmingham Interchange
# 08:47:48 HS2 [Train 10 LOOC_BI] arr S9
# 08:47:58 HS2 [Train 11 LOOC_BI] arr S8
# 08:48:08 HS2 [Train 12 LOOC_BI] arr S7
# 08:48:18 HS2 [Train 13 LOOC_BI] arr S6
# 08:48:22 HS2 [Train 10 LOOC_BI] dep S9 for S10
# 08:48:28 HS2 [Train 14 LOOC_BI] arr S5
# 08:48:38 HS2 [Train 15 LOOC_BI] arr S4
# 08:48:48 HS2 [Train 16 LOOC_BI] arr S3
# 08:48:58 HS2 [Train 17 LOOC_BI] arr S2
# 08:49:05 HS2 [Train  8 LOOC_BI] arr S12
# 08:49:34 HS2 [Train  8 LOOC_BI] dep S12 for S13
# 08:50:27 HS2 [Train 11 LOOC_BI] dep S8 for S9
# 08:50:37 HS2 [Train 12 LOOC_BI] dep S7 for S8
# 08:50:47 HS2 [Train 13 LOOC_BI] dep S6 for S7
# 08:50:54 HS2 [Train  9 LOOC_BI] arr S11
# 08:50:57 HS2 [Train 14 LOOC_BI] dep S5 for S6
# 08:51:04 HS2 [Train  7 LOOC_BI] arr Birmingham Interchange
# 08:51:07 HS2 [Train 15 LOOC_BI] dep S4 for S5
# 08:51:17 HS2 [Train 16 LOOC_BI] dep S3 for S4
# 08:51:27 HS2 [Train 17 LOOC_BI] dep S2 for S3
# 08:51:37 HS2 [Train 18 LOOC_BI] dep London Old Oak Common for S2
# 08:51:44 HS2 [Train  9 LOOC_BI] dep S11 for S12
# 08:51:47 HS2 [Train 19 LOOC_BI] dep London Old Oak Common (DEPOT) for London Old Oak Common
# 08:52:04 HS2 [Train  7 LOOC_BI] dep Birmingham Interchange for London Old Oak Common (DEPOT)
# 08:52:07 HS2 [Train 19 LOOC_BI] arr London Old Oak Common
# 08:52:24 HS2 [Train 10 LOOC_BI] arr S10
# 08:52:24 HS2 [Train  7 LOOC_BI] arr London Old Oak Common (DEPOT)
# 08:53:33 HS2 [Train 10 LOOC_BI] dep S10 for S11
# 08:53:36 HS2 [Train  8 LOOC_BI] arr S13
# 08:53:43 HS2 [Train  8 LOOC_BI] dep S13 for Birmingham Interchange
# 08:54:29 HS2 [Train 11 LOOC_BI] arr S9
# 08:54:39 HS2 [Train 12 LOOC_BI] arr S8
# 08:54:49 HS2 [Train 13 LOOC_BI] arr S7
# 08:54:59 HS2 [Train 14 LOOC_BI] arr S6
# 08:55:03 HS2 [Train 11 LOOC_BI] dep S9 for S10
# 08:55:09 HS2 [Train 15 LOOC_BI] arr S5
# 08:55:19 HS2 [Train 16 LOOC_BI] arr S4
# 08:55:29 HS2 [Train 17 LOOC_BI] arr S3
# 08:55:39 HS2 [Train 18 LOOC_BI] arr S2
# 08:55:46 HS2 [Train  9 LOOC_BI] arr S12
# 08:56:15 HS2 [Train  9 LOOC_BI] dep S12 for S13
# 08:57:08 HS2 [Train 12 LOOC_BI] dep S8 for S9
# 08:57:18 HS2 [Train 13 LOOC_BI] dep S7 for S8
# 08:57:28 HS2 [Train 14 LOOC_BI] dep S6 for S7
# 08:57:35 HS2 [Train 10 LOOC_BI] arr S11
# 08:57:38 HS2 [Train 15 LOOC_BI] dep S5 for S6
# 08:57:45 HS2 [Train  8 LOOC_BI] arr Birmingham Interchange
# 08:57:48 HS2 [Train 16 LOOC_BI] dep S4 for S5
# 08:57:58 HS2 [Train 17 LOOC_BI] dep S3 for S4
# 08:58:08 HS2 [Train 18 LOOC_BI] dep S2 for S3
# 08:58:18 HS2 [Train 19 LOOC_BI] dep London Old Oak Common for S2
# 08:58:25 HS2 [Train 10 LOOC_BI] dep S11 for S12
# 08:58:28 HS2 [Train 20 LOOC_BI] dep London Old Oak Common (DEPOT) for London Old Oak Common
# 08:58:45 HS2 [Train  8 LOOC_BI] dep Birmingham Interchange for London Old Oak Common (DEPOT)
# 08:58:48 HS2 [Train 20 LOOC_BI] arr London Old Oak Common
# 08:59:05 HS2 [Train 11 LOOC_BI] arr S10
# 08:59:05 HS2 [Train  8 LOOC_BI] arr London Old Oak Common (DEPOT)
# 09:00:14 HS2 [Train 11 LOOC_BI] dep S10 for S11
# 09:00:17 HS2 [Train  9 LOOC_BI] arr S13
# 09:00:24 HS2 [Train  9 LOOC_BI] dep S13 for Birmingham Interchange
# 09:00:41 HS2 [Train 20 LOOC_BI] inc London Old Oak Common expected delay 00:34:19
# 09:01:10 HS2 [Train 12 LOOC_BI] arr S9
# 09:01:20 HS2 [Train 13 LOOC_BI] arr S8
# 09:01:30 HS2 [Train 14 LOOC_BI] arr S7
# 09:01:40 HS2 [Train 15 LOOC_BI] arr S6
# 09:01:44 HS2 [Train 12 LOOC_BI] dep S9 for S10
# 09:01:50 HS2 [Train 16 LOOC_BI] arr S5
# 09:02:00 HS2 [Train 17 LOOC_BI] arr S4
# 09:02:10 HS2 [Train 18 LOOC_BI] arr S3
# 09:02:20 HS2 [Train 19 LOOC_BI] arr S2
# 09:02:27 HS2 [Train 10 LOOC_BI] arr S12
# 09:02:56 HS2 [Train 10 LOOC_BI] dep S12 for S13
# 09:03:49 HS2 [Train 13 LOOC_BI] dep S8 for S9
# 09:03:59 HS2 [Train 14 LOOC_BI] dep S7 for S8
# 09:04:09 HS2 [Train 15 LOOC_BI] dep S6 for S7
# 09:04:16 HS2 [Train 11 LOOC_BI] arr S11
# 09:04:19 HS2 [Train 16 LOOC_BI] dep S5 for S6
# 09:04:26 HS2 [Train  9 LOOC_BI] arr Birmingham Interchange
# 09:04:29 HS2 [Train 17 LOOC_BI] dep S4 for S5
# 09:04:39 HS2 [Train 18 LOOC_BI] dep S3 for S4
# 09:04:49 HS2 [Train 19 LOOC_BI] dep S2 for S3
# 09:05:06 HS2 [Train 11 LOOC_BI] dep S11 for S12
# 09:05:26 HS2 [Train  9 LOOC_BI] dep Birmingham Interchange for London Old Oak Common (DEPOT)
# 09:05:46 HS2 [Train 12 LOOC_BI] arr S10
# 09:05:46 HS2 [Train  9 LOOC_BI] arr London Old Oak Common (DEPOT)
# 09:06:55 HS2 [Train 12 LOOC_BI] dep S10 for S11
# 09:06:58 HS2 [Train 10 LOOC_BI] arr S13
# 09:07:05 HS2 [Train 10 LOOC_BI] dep S13 for Birmingham Interchange
# 09:07:51 HS2 [Train 13 LOOC_BI] arr S9
# 09:08:01 HS2 [Train 14 LOOC_BI] arr S8
# 09:08:11 HS2 [Train 15 LOOC_BI] arr S7
# 09:08:21 HS2 [Train 16 LOOC_BI] arr S6
# 09:08:25 HS2 [Train 13 LOOC_BI] dep S9 for S10
# 09:08:31 HS2 [Train 17 LOOC_BI] arr S5
# 09:08:41 HS2 [Train 18 LOOC_BI] arr S4
# 09:08:51 HS2 [Train 19 LOOC_BI] arr S3
# 09:09:08 HS2 [Train 11 LOOC_BI] arr S12
# 09:09:37 HS2 [Train 11 LOOC_BI] dep S12 for S13
# 09:10:30 HS2 [Train 14 LOOC_BI] dep S8 for S9
# 09:10:40 HS2 [Train 15 LOOC_BI] dep S7 for S8
# 09:10:50 HS2 [Train 16 LOOC_BI] dep S6 for S7
# 09:10:57 HS2 [Train 12 LOOC_BI] arr S11
# 09:11:00 HS2 [Train 17 LOOC_BI] dep S5 for S6
# 09:11:07 HS2 [Train 10 LOOC_BI] arr Birmingham Interchange
# 09:11:10 HS2 [Train 18 LOOC_BI] dep S4 for S5
# 09:11:20 HS2 [Train 19 LOOC_BI] dep S3 for S4
# 09:11:47 HS2 [Train 12 LOOC_BI] dep S11 for S12
# 09:12:07 HS2 [Train 10 LOOC_BI] dep Birmingham Interchange for London Old Oak Common (DEPOT)
# 09:12:27 HS2 [Train 13 LOOC_BI] arr S10
# 09:12:27 HS2 [Train 10 LOOC_BI] arr London Old Oak Common (DEPOT)
# 09:13:36 HS2 [Train 13 LOOC_BI] dep S10 for S11
# 09:13:39 HS2 [Train 11 LOOC_BI] arr S13
# 09:13:46 HS2 [Train 11 LOOC_BI] dep S13 for Birmingham Interchange
# 09:14:32 HS2 [Train 14 LOOC_BI] arr S9
# 09:14:42 HS2 [Train 15 LOOC_BI] arr S8
# 09:14:52 HS2 [Train 16 LOOC_BI] arr S7
# 09:15:02 HS2 [Train 17 LOOC_BI] arr S6
# 09:15:06 HS2 [Train 14 LOOC_BI] dep S9 for S10
# 09:15:12 HS2 [Train 18 LOOC_BI] arr S5
# 09:15:22 HS2 [Train 19 LOOC_BI] arr S4
# 09:15:49 HS2 [Train 12 LOOC_BI] arr S12
# 09:16:18 HS2 [Train 12 LOOC_BI] dep S12 for S13
# 09:17:11 HS2 [Train 15 LOOC_BI] dep S8 for S9
# 09:17:21 HS2 [Train 16 LOOC_BI] dep S7 for S8
# 09:17:31 HS2 [Train 17 LOOC_BI] dep S6 for S7
# 09:17:38 HS2 [Train 13 LOOC_BI] arr S11
# 09:17:41 HS2 [Train 18 LOOC_BI] dep S5 for S6
# 09:17:48 HS2 [Train 11 LOOC_BI] arr Birmingham Interchange
# 09:17:51 HS2 [Train 19 LOOC_BI] dep S4 for S5
# 09:18:28 HS2 [Train 13 LOOC_BI] dep S11 for S12
# 09:18:48 HS2 [Train 11 LOOC_BI] dep Birmingham Interchange for London Old Oak Common (DEPOT)
# 09:19:08 HS2 [Train 14 LOOC_BI] arr S10
# 09:19:08 HS2 [Train 11 LOOC_BI] arr London Old Oak Common (DEPOT)
# 09:20:17 HS2 [Train 14 LOOC_BI] dep S10 for S11
# 09:20:20 HS2 [Train 12 LOOC_BI] arr S13
# 09:20:27 HS2 [Train 12 LOOC_BI] dep S13 for Birmingham Interchange
# 09:21:13 HS2 [Train 15 LOOC_BI] arr S9
# 09:21:23 HS2 [Train 16 LOOC_BI] arr S8
# 09:21:33 HS2 [Train 17 LOOC_BI] arr S7
# 09:21:43 HS2 [Train 18 LOOC_BI] arr S6
# 09:21:47 HS2 [Train 15 LOOC_BI] dep S9 for S10
# 09:21:53 HS2 [Train 19 LOOC_BI] arr S5
# 09:22:30 HS2 [Train 13 LOOC_BI] arr S12
# 09:22:59 HS2 [Train 13 LOOC_BI] dep S12 for S13
# 09:23:52 HS2 [Train 16 LOOC_BI] dep S8 for S9
# 09:24:02 HS2 [Train 17 LOOC_BI] dep S7 for S8
# 09:24:12 HS2 [Train 18 LOOC_BI] dep S6 for S7
# 09:24:19 HS2 [Train 14 LOOC_BI] arr S11
# 09:24:22 HS2 [Train 19 LOOC_BI] dep S5 for S6
# 09:24:29 HS2 [Train 12 LOOC_BI] arr Birmingham Interchange
# 09:25:09 HS2 [Train 14 LOOC_BI] dep S11 for S12
# 09:25:29 HS2 [Train 12 LOOC_BI] dep Birmingham Interchange for London Old Oak Common (DEPOT)
# 09:25:49 HS2 [Train 15 LOOC_BI] arr S10
# 09:25:49 HS2 [Train 12 LOOC_BI] arr London Old Oak Common (DEPOT)
# 09:26:58 HS2 [Train 15 LOOC_BI] dep S10 for S11
# 09:27:01 HS2 [Train 13 LOOC_BI] arr S13
# 09:27:08 HS2 [Train 13 LOOC_BI] dep S13 for Birmingham Interchange
# 09:27:54 HS2 [Train 16 LOOC_BI] arr S9
# 09:28:04 HS2 [Train 17 LOOC_BI] arr S8
# 09:28:14 HS2 [Train 18 LOOC_BI] arr S7
# 09:28:24 HS2 [Train 19 LOOC_BI] arr S6
# 09:28:28 HS2 [Train 16 LOOC_BI] dep S9 for S10
# 09:29:11 HS2 [Train 14 LOOC_BI] arr S12
# 09:29:40 HS2 [Train 14 LOOC_BI] dep S12 for S13
# 09:30:33 HS2 [Train 17 LOOC_BI] dep S8 for S9
# 09:30:43 HS2 [Train 18 LOOC_BI] dep S7 for S8
# 09:30:53 HS2 [Train 19 LOOC_BI] dep S6 for S7
# 09:31:00 HS2 [Train 15 LOOC_BI] arr S11
# 09:31:10 HS2 [Train 13 LOOC_BI] arr Birmingham Interchange
# 09:31:50 HS2 [Train 15 LOOC_BI] dep S11 for S12
# 09:32:10 HS2 [Train 13 LOOC_BI] dep Birmingham Interchange for London Old Oak Common (DEPOT)
# 09:32:30 HS2 [Train 16 LOOC_BI] arr S10
# 09:32:30 HS2 [Train 13 LOOC_BI] arr London Old Oak Common (DEPOT)
# 09:33:39 HS2 [Train 16 LOOC_BI] dep S10 for S11
# 09:33:42 HS2 [Train 14 LOOC_BI] arr S13
# 09:33:49 HS2 [Train 14 LOOC_BI] dep S13 for Birmingham Interchange
# 09:34:35 HS2 [Train 17 LOOC_BI] arr S9
# 09:34:45 HS2 [Train 18 LOOC_BI] arr S8
# 09:34:55 HS2 [Train 19 LOOC_BI] arr S7
# 09:35:00 HS2 [Train 20 LOOC_BI] inc London Old Oak Common incident cleared
# 09:35:00 HS2 [Train 20 LOOC_BI] dep London Old Oak Common for S2
# 09:35:09 HS2 [Train 17 LOOC_BI] dep S9 for S10
# 09:35:10 HS2 [Train 21 LOOC_BI] dep London Old Oak Common (DEPOT) for London Old Oak Common
# 09:35:30 HS2 [Train 21 LOOC_BI] arr London Old Oak Common
# 09:35:52 HS2 [Train 15 LOOC_BI] arr S12
# 09:36:21 HS2 [Train 15 LOOC_BI] dep S12 for S13
# 09:37:14 HS2 [Train 18 LOOC_BI] dep S8 for S9
# 09:37:24 HS2 [Train 19 LOOC_BI] dep S7 for S8
# 09:37:41 HS2 [Train 16 LOOC_BI] arr S11
# 09:37:51 HS2 [Train 14 LOOC_BI] arr Birmingham Interchange
# 09:38:31 HS2 [Train 16 LOOC_BI] dep S11 for S12
# 09:38:51 HS2 [Train 14 LOOC_BI] dep Birmingham Interchange for London Old Oak Common (DEPOT)
# 09:39:02 HS2 [Train 20 LOOC_BI] arr S2
# 09:39:11 HS2 [Train 17 LOOC_BI] arr S10
# 09:39:11 HS2 [Train 14 LOOC_BI] arr London Old Oak Common (DEPOT)
# 09:39:17 HS2 [Train 20 LOOC_BI] dep S2 for S3
# 09:39:27 HS2 [Train 21 LOOC_BI] dep London Old Oak Common for S2
# 09:39:37 HS2 [Train 22 LOOC_BI] dep London Old Oak Common (DEPOT) for London Old Oak Common
# 09:39:57 HS2 [Train 22 LOOC_BI] arr London Old Oak Common
# 09:40:20 HS2 [Train 17 LOOC_BI] dep S10 for S11
# 09:40:23 HS2 [Train 15 LOOC_BI] arr S13
# 09:40:30 HS2 [Train 15 LOOC_BI] dep S13 for Birmingham Interchange
# 09:41:16 HS2 [Train 18 LOOC_BI] arr S9
# 09:41:26 HS2 [Train 19 LOOC_BI] arr S8
# 09:41:50 HS2 [Train 18 LOOC_BI] dep S9 for S10
# 09:42:33 HS2 [Train 16 LOOC_BI] arr S12
# 09:43:02 HS2 [Train 16 LOOC_BI] dep S12 for S13
# 09:43:19 HS2 [Train 20 LOOC_BI] arr S3
# 09:43:29 HS2 [Train 21 LOOC_BI] arr S2
# 09:43:55 HS2 [Train 19 LOOC_BI] dep S8 for S9
# 09:44:15 HS2 [Train 20 LOOC_BI] dep S3 for S4
# 09:44:22 HS2 [Train 17 LOOC_BI] arr S11
# 09:44:25 HS2 [Train 21 LOOC_BI] dep S2 for S3
# 09:44:32 HS2 [Train 15 LOOC_BI] arr Birmingham Interchange
# 09:44:35 HS2 [Train 22 LOOC_BI] dep London Old Oak Common for S2
# 09:44:45 HS2 [Train 23 LOOC_BI] dep London Old Oak Common (DEPOT) for London Old Oak Common
# 09:45:05 HS2 [Train 23 LOOC_BI] arr London Old Oak Common
# 09:45:12 HS2 [Train 17 LOOC_BI] dep S11 for S12
# 09:45:32 HS2 [Train 15 LOOC_BI] dep Birmingham Interchange for London Old Oak Common (DEPOT)
# 09:45:52 HS2 [Train 18 LOOC_BI] arr S10
# 09:45:52 HS2 [Train 15 LOOC_BI] arr London Old Oak Common (DEPOT)
# 09:47:01 HS2 [Train 18 LOOC_BI] dep S10 for S11
# 09:47:04 HS2 [Train 16 LOOC_BI] arr S13
# 09:47:11 HS2 [Train 16 LOOC_BI] dep S13 for Birmingham Interchange
# 09:47:57 HS2 [Train 19 LOOC_BI] arr S9
# 09:48:17 HS2 [Train 20 LOOC_BI] arr S4
# 09:48:27 HS2 [Train 21 LOOC_BI] arr S3
# 09:48:31 HS2 [Train 19 LOOC_BI] dep S9 for S10
# 09:48:37 HS2 [Train 22 LOOC_BI] arr S2
# 09:48:37 HS2 [Train 20 LOOC_BI] dep S4 for S5
# 09:49:14 HS2 [Train 17 LOOC_BI] arr S12
# 09:49:23 HS2 [Train 21 LOOC_BI] dep S3 for S4
# 09:49:33 HS2 [Train 22 LOOC_BI] dep S2 for S3
# 09:49:43 HS2 [Train 17 LOOC_BI] dep S12 for S13
# 09:49:43 HS2 [Train 23 LOOC_BI] dep London Old Oak Common for S2
# 09:49:53 HS2 [Train 24 LOOC_BI] dep London Old Oak Common (DEPOT) for London Old Oak Common
# 09:50:13 HS2 [Train 24 LOOC_BI] arr London Old Oak Common
# 09:51:03 HS2 [Train 18 LOOC_BI] arr S11
# 09:51:13 HS2 [Train 16 LOOC_BI] arr Birmingham Interchange
# 09:51:53 HS2 [Train 18 LOOC_BI] dep S11 for S12
# 09:52:13 HS2 [Train 16 LOOC_BI] dep Birmingham Interchange for London Old Oak Common (DEPOT)
# 09:52:33 HS2 [Train 19 LOOC_BI] arr S10
# 09:52:33 HS2 [Train 16 LOOC_BI] arr London Old Oak Common (DEPOT)
# 09:52:39 HS2 [Train 20 LOOC_BI] arr S5
# 09:53:25 HS2 [Train 21 LOOC_BI] arr S4
# 09:53:35 HS2 [Train 22 LOOC_BI] arr S3
# 09:53:42 HS2 [Train 19 LOOC_BI] dep S10 for S11
# 09:53:45 HS2 [Train 17 LOOC_BI] arr S13
# 09:53:45 HS2 [Train 23 LOOC_BI] arr S2
# 09:53:52 HS2 [Train 17 LOOC_BI] dep S13 for Birmingham Interchange
# 09:54:09 HS2 [Train 20 LOOC_BI] dep S5 for S6
# 09:54:19 HS2 [Train 21 LOOC_BI] dep S4 for S5
# 09:54:31 HS2 [Train 22 LOOC_BI] dep S3 for S4
# 09:54:41 HS2 [Train 23 LOOC_BI] dep S2 for S3
# 09:54:51 HS2 [Train 24 LOOC_BI] dep London Old Oak Common for S2
# 09:55:01 HS2 [Train 25 LOOC_BI] dep London Old Oak Common (DEPOT) for London Old Oak Common
# 09:55:21 HS2 [Train 25 LOOC_BI] arr London Old Oak Common
# 09:55:55 HS2 [Train 18 LOOC_BI] arr S12
# 09:56:24 HS2 [Train 18 LOOC_BI] dep S12 for S13
# 09:57:44 HS2 [Train 19 LOOC_BI] arr S11
# 09:57:54 HS2 [Train 17 LOOC_BI] arr Birmingham Interchange
# 09:58:11 HS2 [Train 20 LOOC_BI] arr S6
# 09:58:21 HS2 [Train 21 LOOC_BI] arr S5
# 09:58:33 HS2 [Train 22 LOOC_BI] arr S4
# 09:58:34 HS2 [Train 19 LOOC_BI] dep S11 for S12
# 09:58:43 HS2 [Train 23 LOOC_BI] arr S3
# 09:58:44 HS2 [Train 20 LOOC_BI] dep S6 for S7
# 09:58:53 HS2 [Train 24 LOOC_BI] arr S2
# 09:58:54 HS2 [Train 17 LOOC_BI] dep Birmingham Interchange for London Old Oak Common (DEPOT)
# 09:59:14 HS2 [Train 17 LOOC_BI] arr London Old Oak Common (DEPOT)
# 09:59:51 HS2 [Train 21 LOOC_BI] dep S5 for S6
# 10:00:01 HS2 [Train 22 LOOC_BI] dep S4 for S5
# 10:00:11 HS2 [Train 23 LOOC_BI] dep S3 for S4
# 10:00:21 HS2 [Train 24 LOOC_BI] dep S2 for S3
# 10:00:26 HS2 [Train 18 LOOC_BI] arr S13
# 10:00:31 HS2 [Train 25 LOOC_BI] dep London Old Oak Common for S2
# 10:00:33 HS2 [Train 18 LOOC_BI] dep S13 for Birmingham Interchange
# 10:00:41 HS2 [Train 26 LOOC_BI] dep London Old Oak Common (DEPOT) for London Old Oak Common
# 10:01:01 HS2 [Train 26 LOOC_BI] arr London Old Oak Common
# 10:02:36 HS2 [Train 19 LOOC_BI] arr S12
# 10:02:46 HS2 [Train 20 LOOC_BI] arr S7
# 10:03:02 HS2 [Train 20 LOOC_BI] dep S7 for S8
# 10:03:05 HS2 [Train 19 LOOC_BI] dep S12 for S13
# 10:03:53 HS2 [Train 21 LOOC_BI] arr S6
# 10:04:03 HS2 [Train 22 LOOC_BI] arr S5
# 10:04:13 HS2 [Train 23 LOOC_BI] arr S4
# 10:04:23 HS2 [Train 24 LOOC_BI] arr S3
# 10:04:26 HS2 [Train 21 LOOC_BI] dep S6 for S7
# 10:04:33 HS2 [Train 25 LOOC_BI] arr S2
# 10:04:35 HS2 [Train 18 LOOC_BI] arr Birmingham Interchange
# 10:05:33 HS2 [Train 22 LOOC_BI] dep S5 for S6
# 10:05:35 HS2 [Train 18 LOOC_BI] dep Birmingham Interchange for London Old Oak Common (DEPOT)
# 10:05:43 HS2 [Train 23 LOOC_BI] dep S4 for S5
# 10:05:53 HS2 [Train 24 LOOC_BI] dep S3 for S4
# 10:05:55 HS2 [Train 18 LOOC_BI] arr London Old Oak Common (DEPOT)
# 10:06:03 HS2 [Train 25 LOOC_BI] dep S2 for S3
# 10:06:13 HS2 [Train 26 LOOC_BI] dep London Old Oak Common for S2
# 10:06:23 HS2 [Train 27 LOOC_BI] dep London Old Oak Common (DEPOT) for London Old Oak Common
# 10:06:43 HS2 [Train 27 LOOC_BI] arr London Old Oak Common
# 10:07:04 HS2 [Train 20 LOOC_BI] arr S8
# 10:07:07 HS2 [Train 19 LOOC_BI] arr S13
# 10:07:14 HS2 [Train 19 LOOC_BI] dep S13 for Birmingham Interchange
# 10:08:28 HS2 [Train 21 LOOC_BI] arr S7
# 10:09:33 HS2 [Train 20 LOOC_BI] dep S8 for S9
# 10:09:35 HS2 [Train 22 LOOC_BI] arr S6
# 10:09:43 HS2 [Train 21 LOOC_BI] dep S7 for S8
# 10:09:45 HS2 [Train 23 LOOC_BI] arr S5
# 10:09:55 HS2 [Train 24 LOOC_BI] arr S4
# 10:10:05 HS2 [Train 25 LOOC_BI] arr S3
# 10:10:08 HS2 [Train 22 LOOC_BI] dep S6 for S7
# 10:10:15 HS2 [Train 26 LOOC_BI] arr S2
# 10:11:15 HS2 [Train 23 LOOC_BI] dep S5 for S6
# 10:11:16 HS2 [Train 19 LOOC_BI] arr Birmingham Interchange
# 10:11:25 HS2 [Train 24 LOOC_BI] dep S4 for S5
# 10:11:35 HS2 [Train 25 LOOC_BI] dep S3 for S4
# 10:11:45 HS2 [Train 26 LOOC_BI] dep S2 for S3
# 10:11:55 HS2 [Train 27 LOOC_BI] dep London Old Oak Common for S2
# 10:12:05 HS2 [Train 28 LOOC_BI] dep London Old Oak Common (DEPOT) for London Old Oak Common
# 10:12:16 HS2 [Train 19 LOOC_BI] dep Birmingham Interchange for London Old Oak Common (DEPOT)
# 10:12:25 HS2 [Train 28 LOOC_BI] arr London Old Oak Common
# 10:12:36 HS2 [Train 19 LOOC_BI] arr London Old Oak Common (DEPOT)
# 10:13:35 HS2 [Train 20 LOOC_BI] arr S9
# 10:13:45 HS2 [Train 21 LOOC_BI] arr S8
# 10:14:09 HS2 [Train 20 LOOC_BI] dep S9 for S10
# 10:14:10 HS2 [Train 22 LOOC_BI] arr S7
# 10:15:17 HS2 [Train 23 LOOC_BI] arr S6
# 10:15:27 HS2 [Train 24 LOOC_BI] arr S5
# 10:15:37 HS2 [Train 25 LOOC_BI] arr S4
# 10:15:47 HS2 [Train 26 LOOC_BI] arr S3
# 10:15:57 HS2 [Train 27 LOOC_BI] arr S2
# 10:16:14 HS2 [Train 21 LOOC_BI] dep S8 for S9
# 10:16:24 HS2 [Train 22 LOOC_BI] dep S7 for S8
# 10:16:34 HS2 [Train 23 LOOC_BI] dep S6 for S7
# 10:16:57 HS2 [Train 24 LOOC_BI] dep S5 for S6
# 10:17:07 HS2 [Train 25 LOOC_BI] dep S4 for S5
# 10:17:17 HS2 [Train 26 LOOC_BI] dep S3 for S4
# 10:17:27 HS2 [Train 27 LOOC_BI] dep S2 for S3
# 10:17:37 HS2 [Train 28 LOOC_BI] dep London Old Oak Common for S2
# 10:17:47 HS2 [Train 29 LOOC_BI] dep London Old Oak Common (DEPOT) for London Old Oak Common
# 10:18:07 HS2 [Train 29 LOOC_BI] arr London Old Oak Common
# 10:18:11 HS2 [Train 20 LOOC_BI] arr S10
# 10:19:20 HS2 [Train 20 LOOC_BI] dep S10 for S11
# 10:20:16 HS2 [Train 21 LOOC_BI] arr S9
# 10:20:26 HS2 [Train 22 LOOC_BI] arr S8
# 10:20:36 HS2 [Train 23 LOOC_BI] arr S7
# 10:20:50 HS2 [Train 21 LOOC_BI] dep S9 for S10
# 10:20:59 HS2 [Train 24 LOOC_BI] arr S6
# 10:21:09 HS2 [Train 25 LOOC_BI] arr S5
# 10:21:19 HS2 [Train 26 LOOC_BI] arr S4
# 10:21:29 HS2 [Train 27 LOOC_BI] arr S3
# 10:21:39 HS2 [Train 28 LOOC_BI] arr S2
# 10:22:55 HS2 [Train 22 LOOC_BI] dep S8 for S9
# 10:23:05 HS2 [Train 23 LOOC_BI] dep S7 for S8
# 10:23:15 HS2 [Train 24 LOOC_BI] dep S6 for S7
# 10:23:22 HS2 [Train 20 LOOC_BI] arr S11
# 10:23:25 HS2 [Train 25 LOOC_BI] dep S5 for S6
# 10:23:35 HS2 [Train 26 LOOC_BI] dep S4 for S5
# 10:23:45 HS2 [Train 27 LOOC_BI] dep S3 for S4
# 10:23:55 HS2 [Train 28 LOOC_BI] dep S2 for S3
# 10:24:05 HS2 [Train 29 LOOC_BI] dep London Old Oak Common for S2
# 10:24:12 HS2 [Train 20 LOOC_BI] dep S11 for S12
# 10:24:15 HS2 [Train 30 LOOC_BI] dep London Old Oak Common (DEPOT) for London Old Oak Common
# 10:24:35 HS2 [Train 30 LOOC_BI] arr London Old Oak Common
# 10:24:52 HS2 [Train 21 LOOC_BI] arr S10
# 10:26:01 HS2 [Train 21 LOOC_BI] dep S10 for S11
# 10:26:57 HS2 [Train 22 LOOC_BI] arr S9
# 10:27:07 HS2 [Train 23 LOOC_BI] arr S8
# 10:27:17 HS2 [Train 24 LOOC_BI] arr S7
# 10:27:27 HS2 [Train 25 LOOC_BI] arr S6
# 10:27:31 HS2 [Train 22 LOOC_BI] dep S9 for S10
# 10:27:37 HS2 [Train 26 LOOC_BI] arr S5
# 10:27:47 HS2 [Train 27 LOOC_BI] arr S4
# 10:27:57 HS2 [Train 28 LOOC_BI] arr S3
# 10:28:07 HS2 [Train 29 LOOC_BI] arr S2
# 10:28:14 HS2 [Train 20 LOOC_BI] arr S12
# 10:28:43 HS2 [Train 20 LOOC_BI] dep S12 for S13
# 10:29:36 HS2 [Train 23 LOOC_BI] dep S8 for S9
# 10:29:46 HS2 [Train 24 LOOC_BI] dep S7 for S8
# 10:29:56 HS2 [Train 25 LOOC_BI] dep S6 for S7
# 10:30:03 HS2 [Train 21 LOOC_BI] arr S11
# 10:30:06 HS2 [Train 26 LOOC_BI] dep S5 for S6
# 10:30:16 HS2 [Train 27 LOOC_BI] dep S4 for S5
# 10:30:26 HS2 [Train 28 LOOC_BI] dep S3 for S4
# 10:30:36 HS2 [Train 29 LOOC_BI] dep S2 for S3
# 10:30:46 HS2 [Train 30 LOOC_BI] dep London Old Oak Common for S2
# 10:30:53 HS2 [Train 21 LOOC_BI] dep S11 for S12
# 10:30:56 HS2 [Train 31 LOOC_BI] dep London Old Oak Common (DEPOT) for London Old Oak Common
# 10:31:16 HS2 [Train 31 LOOC_BI] arr London Old Oak Common
# 10:31:33 HS2 [Train 22 LOOC_BI] arr S10
# 10:32:42 HS2 [Train 22 LOOC_BI] dep S10 for S11
# 10:32:45 HS2 [Train 20 LOOC_BI] arr S13
# 10:32:52 HS2 [Train 20 LOOC_BI] dep S13 for Birmingham Interchange
# 10:33:38 HS2 [Train 23 LOOC_BI] arr S9
# 10:33:48 HS2 [Train 24 LOOC_BI] arr S8
# 10:33:58 HS2 [Train 25 LOOC_BI] arr S7
# 10:34:08 HS2 [Train 26 LOOC_BI] arr S6
# 10:34:12 HS2 [Train 23 LOOC_BI] dep S9 for S10
# 10:34:18 HS2 [Train 27 LOOC_BI] arr S5
# 10:34:28 HS2 [Train 28 LOOC_BI] arr S4
# 10:34:38 HS2 [Train 29 LOOC_BI] arr S3
# 10:34:48 HS2 [Train 30 LOOC_BI] arr S2
# 10:34:55 HS2 [Train 21 LOOC_BI] arr S12
# 10:35:24 HS2 [Train 21 LOOC_BI] dep S12 for S13
# 10:36:17 HS2 [Train 24 LOOC_BI] dep S8 for S9
# 10:36:27 HS2 [Train 25 LOOC_BI] dep S7 for S8
# 10:36:37 HS2 [Train 26 LOOC_BI] dep S6 for S7
# 10:36:44 HS2 [Train 22 LOOC_BI] arr S11
# 10:36:47 HS2 [Train 27 LOOC_BI] dep S5 for S6
# 10:36:54 HS2 [Train 20 LOOC_BI] arr Birmingham Interchange
# 10:36:57 HS2 [Train 28 LOOC_BI] dep S4 for S5
# 10:37:07 HS2 [Train 29 LOOC_BI] dep S3 for S4
# 10:37:17 HS2 [Train 30 LOOC_BI] dep S2 for S3
# 10:37:27 HS2 [Train 31 LOOC_BI] dep London Old Oak Common for S2
# 10:37:34 HS2 [Train 22 LOOC_BI] dep S11 for S12
# 10:37:37 HS2 [Train 32 LOOC_BI] dep London Old Oak Common (DEPOT) for London Old Oak Common
# 10:37:54 HS2 [Train 20 LOOC_BI] dep Birmingham Interchange for London Old Oak Common (DEPOT)
# 10:37:57 HS2 [Train 32 LOOC_BI] arr London Old Oak Common
# 10:38:14 HS2 [Train 23 LOOC_BI] arr S10
# 10:38:14 HS2 [Train 20 LOOC_BI] arr London Old Oak Common (DEPOT)
# 10:39:23 HS2 [Train 23 LOOC_BI] dep S10 for S11
# 10:39:26 HS2 [Train 21 LOOC_BI] arr S13
# 10:39:33 HS2 [Train 21 LOOC_BI] dep S13 for Birmingham Interchange
# 10:40:19 HS2 [Train 24 LOOC_BI] arr S9
# 10:40:29 HS2 [Train 25 LOOC_BI] arr S8
# 10:40:39 HS2 [Train 26 LOOC_BI] arr S7
# 10:40:49 HS2 [Train 27 LOOC_BI] arr S6
# 10:40:53 HS2 [Train 24 LOOC_BI] dep S9 for S10
# 10:40:59 HS2 [Train 28 LOOC_BI] arr S5
# 10:41:09 HS2 [Train 29 LOOC_BI] arr S4
# 10:41:19 HS2 [Train 30 LOOC_BI] arr S3
# 10:41:29 HS2 [Train 31 LOOC_BI] arr S2
# 10:41:36 HS2 [Train 22 LOOC_BI] arr S12
# 10:42:05 HS2 [Train 22 LOOC_BI] dep S12 for S13
# 10:42:58 HS2 [Train 25 LOOC_BI] dep S8 for S9
# 10:43:08 HS2 [Train 26 LOOC_BI] dep S7 for S8
# 10:43:18 HS2 [Train 27 LOOC_BI] dep S6 for S7
# 10:43:25 HS2 [Train 23 LOOC_BI] arr S11
# 10:43:28 HS2 [Train 28 LOOC_BI] dep S5 for S6
# 10:43:35 HS2 [Train 21 LOOC_BI] arr Birmingham Interchange
# 10:43:38 HS2 [Train 29 LOOC_BI] dep S4 for S5
# 10:43:48 HS2 [Train 30 LOOC_BI] dep S3 for S4
# 10:43:58 HS2 [Train 31 LOOC_BI] dep S2 for S3
# 10:44:08 HS2 [Train 32 LOOC_BI] dep London Old Oak Common for S2
# 10:44:15 HS2 [Train 23 LOOC_BI] dep S11 for S12
# 10:44:18 HS2 [Train 33 LOOC_BI] dep London Old Oak Common (DEPOT) for London Old Oak Common
# 10:44:35 HS2 [Train 21 LOOC_BI] dep Birmingham Interchange for London Old Oak Common (DEPOT)
# 10:44:38 HS2 [Train 33 LOOC_BI] arr London Old Oak Common
# 10:44:55 HS2 [Train 24 LOOC_BI] arr S10
# 10:44:55 HS2 [Train 21 LOOC_BI] arr London Old Oak Common (DEPOT)
# 10:46:04 HS2 [Train 24 LOOC_BI] dep S10 for S11
# 10:46:07 HS2 [Train 22 LOOC_BI] arr S13
# 10:46:14 HS2 [Train 22 LOOC_BI] dep S13 for Birmingham Interchange
# 10:47:00 HS2 [Train 25 LOOC_BI] arr S9
# 10:47:10 HS2 [Train 26 LOOC_BI] arr S8
# 10:47:20 HS2 [Train 27 LOOC_BI] arr S7
# 10:47:30 HS2 [Train 28 LOOC_BI] arr S6
# 10:47:34 HS2 [Train 25 LOOC_BI] dep S9 for S10
# 10:47:40 HS2 [Train 29 LOOC_BI] arr S5
# 10:47:50 HS2 [Train 30 LOOC_BI] arr S4
# 10:48:00 HS2 [Train 31 LOOC_BI] arr S3
# 10:48:10 HS2 [Train 32 LOOC_BI] arr S2
# 10:48:17 HS2 [Train 23 LOOC_BI] arr S12
# 10:48:46 HS2 [Train 23 LOOC_BI] dep S12 for S13
# 10:49:39 HS2 [Train 26 LOOC_BI] dep S8 for S9
# 10:49:49 HS2 [Train 27 LOOC_BI] dep S7 for S8
# 10:49:59 HS2 [Train 28 LOOC_BI] dep S6 for S7
# 10:50:06 HS2 [Train 24 LOOC_BI] arr S11
# 10:50:09 HS2 [Train 29 LOOC_BI] dep S5 for S6
# 10:50:16 HS2 [Train 22 LOOC_BI] arr Birmingham Interchange
# 10:50:19 HS2 [Train 30 LOOC_BI] dep S4 for S5
# 10:50:29 HS2 [Train 31 LOOC_BI] dep S3 for S4
# 10:50:39 HS2 [Train 32 LOOC_BI] dep S2 for S3
# 10:50:49 HS2 [Train 33 LOOC_BI] dep London Old Oak Common for S2
# 10:50:56 HS2 [Train 24 LOOC_BI] dep S11 for S12
# 10:50:59 HS2 [Train 34 LOOC_BI] dep London Old Oak Common (DEPOT) for London Old Oak Common
# 10:51:16 HS2 [Train 22 LOOC_BI] dep Birmingham Interchange for London Old Oak Common (DEPOT)
# 10:51:19 HS2 [Train 34 LOOC_BI] arr London Old Oak Common
# 10:51:36 HS2 [Train 25 LOOC_BI] arr S10
# 10:51:36 HS2 [Train 22 LOOC_BI] arr London Old Oak Common (DEPOT)
# 10:52:45 HS2 [Train 25 LOOC_BI] dep S10 for S11
# 10:52:48 HS2 [Train 23 LOOC_BI] arr S13
# 10:52:55 HS2 [Train 23 LOOC_BI] dep S13 for Birmingham Interchange
# 10:53:41 HS2 [Train 26 LOOC_BI] arr S9
# 10:53:51 HS2 [Train 27 LOOC_BI] arr S8
# 10:54:01 HS2 [Train 28 LOOC_BI] arr S7
# 10:54:11 HS2 [Train 29 LOOC_BI] arr S6
# 10:54:15 HS2 [Train 26 LOOC_BI] dep S9 for S10
# 10:54:21 HS2 [Train 30 LOOC_BI] arr S5
# 10:54:31 HS2 [Train 31 LOOC_BI] arr S4
# 10:54:41 HS2 [Train 32 LOOC_BI] arr S3
# 10:54:51 HS2 [Train 33 LOOC_BI] arr S2
# 10:54:58 HS2 [Train 24 LOOC_BI] arr S12
# 10:55:27 HS2 [Train 24 LOOC_BI] dep S12 for S13
# 10:56:20 HS2 [Train 27 LOOC_BI] dep S8 for S9
# 10:56:30 HS2 [Train 28 LOOC_BI] dep S7 for S8
# 10:56:40 HS2 [Train 29 LOOC_BI] dep S6 for S7
# 10:56:47 HS2 [Train 25 LOOC_BI] arr S11
# 10:56:50 HS2 [Train 30 LOOC_BI] dep S5 for S6
# 10:56:57 HS2 [Train 23 LOOC_BI] arr Birmingham Interchange
# 10:57:00 HS2 [Train 31 LOOC_BI] dep S4 for S5
# 10:57:10 HS2 [Train 32 LOOC_BI] dep S3 for S4
# 10:57:20 HS2 [Train 33 LOOC_BI] dep S2 for S3
# 10:57:30 HS2 [Train 34 LOOC_BI] dep London Old Oak Common for S2
# 10:57:37 HS2 [Train 25 LOOC_BI] dep S11 for S12
# 10:57:40 HS2 [Train 35 LOOC_BI] dep London Old Oak Common (DEPOT) for London Old Oak Common
# 10:57:57 HS2 [Train 23 LOOC_BI] dep Birmingham Interchange for London Old Oak Common (DEPOT)
# 10:58:00 HS2 [Train 35 LOOC_BI] arr London Old Oak Common
# 10:58:17 HS2 [Train 26 LOOC_BI] arr S10
# 10:58:17 HS2 [Train 23 LOOC_BI] arr London Old Oak Common (DEPOT)
# 10:59:26 HS2 [Train 26 LOOC_BI] dep S10 for S11
# 10:59:29 HS2 [Train 24 LOOC_BI] arr S13
# 10:59:36 HS2 [Train 24 LOOC_BI] dep S13 for Birmingham Interchange
# 11:00:22 HS2 [Train 27 LOOC_BI] arr S9
# 11:00:32 HS2 [Train 28 LOOC_BI] arr S8
# 11:00:42 HS2 [Train 29 LOOC_BI] arr S7
# 11:00:52 HS2 [Train 30 LOOC_BI] arr S6
# 11:00:56 HS2 [Train 27 LOOC_BI] dep S9 for S10
# 11:01:02 HS2 [Train 31 LOOC_BI] arr S5
# 11:01:12 HS2 [Train 32 LOOC_BI] arr S4
# 11:01:22 HS2 [Train 33 LOOC_BI] arr S3
# 11:01:32 HS2 [Train 34 LOOC_BI] arr S2
# 11:01:39 HS2 [Train 25 LOOC_BI] arr S12
# 11:02:08 HS2 [Train 25 LOOC_BI] dep S12 for S13
# 11:03:01 HS2 [Train 28 LOOC_BI] dep S8 for S9
# 11:03:11 HS2 [Train 29 LOOC_BI] dep S7 for S8
# 11:03:21 HS2 [Train 30 LOOC_BI] dep S6 for S7
# 11:03:28 HS2 [Train 26 LOOC_BI] arr S11
# 11:03:31 HS2 [Train 31 LOOC_BI] dep S5 for S6
# 11:03:38 HS2 [Train 24 LOOC_BI] arr Birmingham Interchange
# 11:03:41 HS2 [Train 32 LOOC_BI] dep S4 for S5
# 11:03:51 HS2 [Train 33 LOOC_BI] dep S3 for S4
# 11:04:01 HS2 [Train 34 LOOC_BI] dep S2 for S3
# 11:04:11 HS2 [Train 35 LOOC_BI] dep London Old Oak Common for S2
# 11:04:18 HS2 [Train 26 LOOC_BI] dep S11 for S12
# 11:04:21 HS2 [Train 36 LOOC_BI] dep London Old Oak Common (DEPOT) for London Old Oak Common
# 11:04:38 HS2 [Train 24 LOOC_BI] dep Birmingham Interchange for London Old Oak Common (DEPOT)
# 11:04:41 HS2 [Train 36 LOOC_BI] arr London Old Oak Common
# 11:04:58 HS2 [Train 27 LOOC_BI] arr S10
# 11:04:58 HS2 [Train 24 LOOC_BI] arr London Old Oak Common (DEPOT)
# 11:06:07 HS2 [Train 27 LOOC_BI] dep S10 for S11
# 11:06:10 HS2 [Train 25 LOOC_BI] arr S13
# 11:06:17 HS2 [Train 25 LOOC_BI] dep S13 for Birmingham Interchange
# 11:07:03 HS2 [Train 28 LOOC_BI] arr S9
# 11:07:13 HS2 [Train 29 LOOC_BI] arr S8
# 11:07:23 HS2 [Train 30 LOOC_BI] arr S7
# 11:07:33 HS2 [Train 31 LOOC_BI] arr S6
# 11:07:37 HS2 [Train 28 LOOC_BI] dep S9 for S10
# 11:07:43 HS2 [Train 32 LOOC_BI] arr S5
# 11:07:53 HS2 [Train 33 LOOC_BI] arr S4
# 11:08:03 HS2 [Train 34 LOOC_BI] arr S3
# 11:08:13 HS2 [Train 35 LOOC_BI] arr S2
# 11:08:20 HS2 [Train 26 LOOC_BI] arr S12
# 11:08:49 HS2 [Train 26 LOOC_BI] dep S12 for S13
# 11:09:42 HS2 [Train 29 LOOC_BI] dep S8 for S9
# 11:09:52 HS2 [Train 30 LOOC_BI] dep S7 for S8
# 11:10:02 HS2 [Train 31 LOOC_BI] dep S6 for S7
# 11:10:09 HS2 [Train 27 LOOC_BI] arr S11
# 11:10:12 HS2 [Train 32 LOOC_BI] dep S5 for S6
# 11:10:19 HS2 [Train 25 LOOC_BI] arr Birmingham Interchange
# 11:10:22 HS2 [Train 33 LOOC_BI] dep S4 for S5
# 11:10:32 HS2 [Train 34 LOOC_BI] dep S3 for S4
# 11:10:42 HS2 [Train 35 LOOC_BI] dep S2 for S3
# 11:10:52 HS2 [Train 36 LOOC_BI] dep London Old Oak Common for S2
# 11:10:59 HS2 [Train 27 LOOC_BI] dep S11 for S12
# 11:11:02 HS2 [Train 37 LOOC_BI] dep London Old Oak Common (DEPOT) for London Old Oak Common
# 11:11:19 HS2 [Train 25 LOOC_BI] dep Birmingham Interchange for London Old Oak Common (DEPOT)
# 11:11:22 HS2 [Train 37 LOOC_BI] arr London Old Oak Common
# 11:11:39 HS2 [Train 28 LOOC_BI] arr S10
# 11:11:39 HS2 [Train 25 LOOC_BI] arr London Old Oak Common (DEPOT)
# 11:12:48 HS2 [Train 28 LOOC_BI] dep S10 for S11
# 11:12:51 HS2 [Train 26 LOOC_BI] arr S13
# 11:12:58 HS2 [Train 26 LOOC_BI] dep S13 for Birmingham Interchange
# 11:13:44 HS2 [Train 29 LOOC_BI] arr S9
# 11:13:54 HS2 [Train 30 LOOC_BI] arr S8
# 11:14:04 HS2 [Train 31 LOOC_BI] arr S7
# 11:14:14 HS2 [Train 32 LOOC_BI] arr S6
# 11:14:18 HS2 [Train 29 LOOC_BI] dep S9 for S10
# 11:14:24 HS2 [Train 33 LOOC_BI] arr S5
# 11:14:34 HS2 [Train 34 LOOC_BI] arr S4
# 11:14:44 HS2 [Train 35 LOOC_BI] arr S3
# 11:14:54 HS2 [Train 36 LOOC_BI] arr S2
# 11:15:01 HS2 [Train 27 LOOC_BI] arr S12
# 11:15:30 HS2 [Train 27 LOOC_BI] dep S12 for S13
# 11:16:23 HS2 [Train 30 LOOC_BI] dep S8 for S9
# 11:16:33 HS2 [Train 31 LOOC_BI] dep S7 for S8
# 11:16:43 HS2 [Train 32 LOOC_BI] dep S6 for S7
# 11:16:50 HS2 [Train 28 LOOC_BI] arr S11
# 11:16:53 HS2 [Train 33 LOOC_BI] dep S5 for S6
# 11:17:00 HS2 [Train 26 LOOC_BI] arr Birmingham Interchange
# 11:17:03 HS2 [Train 34 LOOC_BI] dep S4 for S5
# 11:17:13 HS2 [Train 35 LOOC_BI] dep S3 for S4
# 11:17:23 HS2 [Train 36 LOOC_BI] dep S2 for S3
# 11:17:33 HS2 [Train 37 LOOC_BI] dep London Old Oak Common for S2
# 11:17:40 HS2 [Train 28 LOOC_BI] dep S11 for S12
# 11:17:43 HS2 [Train 38 LOOC_BI] dep London Old Oak Common (DEPOT) for London Old Oak Common
# 11:18:00 HS2 [Train 26 LOOC_BI] dep Birmingham Interchange for London Old Oak Common (DEPOT)
# 11:18:03 HS2 [Train 38 LOOC_BI] arr London Old Oak Common
# 11:18:20 HS2 [Train 29 LOOC_BI] arr S10
# 11:18:20 HS2 [Train 26 LOOC_BI] arr London Old Oak Common (DEPOT)
# 11:19:29 HS2 [Train 29 LOOC_BI] dep S10 for S11
# 11:19:32 HS2 [Train 27 LOOC_BI] arr S13
# 11:19:39 HS2 [Train 27 LOOC_BI] dep S13 for Birmingham Interchange
# 11:20:25 HS2 [Train 30 LOOC_BI] arr S9
# 11:20:35 HS2 [Train 31 LOOC_BI] arr S8
# 11:20:45 HS2 [Train 32 LOOC_BI] arr S7
# 11:20:55 HS2 [Train 33 LOOC_BI] arr S6
# ...
# 20:51:29 HS2 [Train 118 LOOC_BI] dep S6 for S7
# 20:51:36 HS2 [Train 114 LOOC_BI] arr S11
# 20:51:39 HS2 [Train 119 LOOC_BI] dep S5 for S6
# 20:51:46 HS2 [Train 112 LOOC_BI] arr Birmingham Interchange
# 20:51:49 HS2 [Train 120 LOOC_BI] dep S4 for S5
# 20:51:59 HS2 [Train 121 LOOC_BI] dep S3 for S4
# 20:52:09 HS2 [Train 122 LOOC_BI] dep S2 for S3
# 20:52:19 HS2 [Train 123 LOOC_BI] dep London Old Oak Common for S2
# 20:52:26 HS2 [Train 114 LOOC_BI] dep S11 for S12
# 20:52:29 HS2 [Train 124 LOOC_BI] dep London Old Oak Common (DEPOT) for London Old Oak Common
# 20:52:46 HS2 [Train 112 LOOC_BI] dep Birmingham Interchange for London Old Oak Common (DEPOT)
# 20:52:49 HS2 [Train 124 LOOC_BI] arr London Old Oak Common
# 20:53:06 HS2 [Train 115 LOOC_BI] arr S10
# 20:53:06 HS2 [Train 112 LOOC_BI] arr London Old Oak Common (DEPOT)
# 20:54:15 HS2 [Train 115 LOOC_BI] dep S10 for S11
# 20:54:18 HS2 [Train 113 LOOC_BI] arr S13
# 20:54:25 HS2 [Train 113 LOOC_BI] dep S13 for Birmingham Interchange
# 20:55:11 HS2 [Train 116 LOOC_BI] arr S9
# 20:55:21 HS2 [Train 117 LOOC_BI] arr S8
# 20:55:31 HS2 [Train 118 LOOC_BI] arr S7
# 20:55:41 HS2 [Train 119 LOOC_BI] arr S6
# 20:55:45 HS2 [Train 116 LOOC_BI] dep S9 for S10
# 20:55:51 HS2 [Train 120 LOOC_BI] arr S5
# 20:56:01 HS2 [Train 121 LOOC_BI] arr S4
# 20:56:11 HS2 [Train 122 LOOC_BI] arr S3
# 20:56:21 HS2 [Train 123 LOOC_BI] arr S2
# 20:56:28 HS2 [Train 114 LOOC_BI] arr S12
# 20:56:57 HS2 [Train 114 LOOC_BI] dep S12 for S13
# 20:57:50 HS2 [Train 117 LOOC_BI] dep S8 for S9
# 20:58:00 HS2 [Train 118 LOOC_BI] dep S7 for S8
# 20:58:10 HS2 [Train 119 LOOC_BI] dep S6 for S7
# 20:58:17 HS2 [Train 115 LOOC_BI] arr S11
# 20:58:20 HS2 [Train 120 LOOC_BI] dep S5 for S6
# 20:58:27 HS2 [Train 113 LOOC_BI] arr Birmingham Interchange
# 20:58:30 HS2 [Train 121 LOOC_BI] dep S4 for S5
# 20:58:40 HS2 [Train 122 LOOC_BI] dep S3 for S4
# 20:58:50 HS2 [Train 123 LOOC_BI] dep S2 for S3
# 20:59:00 HS2 [Train 124 LOOC_BI] dep London Old Oak Common for S2
# 20:59:07 HS2 [Train 115 LOOC_BI] dep S11 for S12
# 20:59:10 HS2 [Train 125 LOOC_BI] dep London Old Oak Common (DEPOT) for London Old Oak Common
# 20:59:27 HS2 [Train 113 LOOC_BI] dep Birmingham Interchange for London Old Oak Common (DEPOT)
# 20:59:30 HS2 [Train 125 LOOC_BI] arr London Old Oak Common
# 20:59:47 HS2 [Train 116 LOOC_BI] arr S10
# 20:59:47 HS2 [Train 113 LOOC_BI] arr London Old Oak Common (DEPOT)
# 21:00:56 HS2 [Train 116 LOOC_BI] dep S10 for S11
# 21:00:59 HS2 [Train 114 LOOC_BI] arr S13
# 21:01:06 HS2 [Train 114 LOOC_BI] dep S13 for Birmingham Interchange
# 21:01:52 HS2 [Train 117 LOOC_BI] arr S9
# 21:02:02 HS2 [Train 118 LOOC_BI] arr S8
# 21:02:12 HS2 [Train 119 LOOC_BI] arr S7
# 21:02:22 HS2 [Train 120 LOOC_BI] arr S6
# 21:02:26 HS2 [Train 117 LOOC_BI] dep S9 for S10
# 21:02:32 HS2 [Train 121 LOOC_BI] arr S5
# 21:02:42 HS2 [Train 122 LOOC_BI] arr S4
# 21:02:52 HS2 [Train 123 LOOC_BI] arr S3
# 21:03:02 HS2 [Train 124 LOOC_BI] arr S2
# 21:03:09 HS2 [Train 115 LOOC_BI] arr S12
# 21:03:38 HS2 [Train 115 LOOC_BI] dep S12 for S13
# 21:04:31 HS2 [Train 118 LOOC_BI] dep S8 for S9
# 21:04:41 HS2 [Train 119 LOOC_BI] dep S7 for S8
# 21:04:51 HS2 [Train 120 LOOC_BI] dep S6 for S7
# 21:04:58 HS2 [Train 116 LOOC_BI] arr S11
# 21:05:01 HS2 [Train 121 LOOC_BI] dep S5 for S6
# 21:05:08 HS2 [Train 114 LOOC_BI] arr Birmingham Interchange
# 21:05:11 HS2 [Train 122 LOOC_BI] dep S4 for S5
# 21:05:21 HS2 [Train 123 LOOC_BI] dep S3 for S4
# 21:05:31 HS2 [Train 124 LOOC_BI] dep S2 for S3
# 21:05:41 HS2 [Train 125 LOOC_BI] dep London Old Oak Common for S2
# 21:05:48 HS2 [Train 116 LOOC_BI] dep S11 for S12
# 21:05:51 HS2 [Train 126 LOOC_BI] dep London Old Oak Common (DEPOT) for London Old Oak Common
# 21:06:08 HS2 [Train 114 LOOC_BI] dep Birmingham Interchange for London Old Oak Common (DEPOT)
# 21:06:11 HS2 [Train 126 LOOC_BI] arr London Old Oak Common
# 21:06:28 HS2 [Train 117 LOOC_BI] arr S10
# 21:06:28 HS2 [Train 114 LOOC_BI] arr London Old Oak Common (DEPOT)
# 21:07:37 HS2 [Train 117 LOOC_BI] dep S10 for S11
# 21:07:40 HS2 [Train 115 LOOC_BI] arr S13
# 21:07:47 HS2 [Train 115 LOOC_BI] dep S13 for Birmingham Interchange
# 21:08:33 HS2 [Train 118 LOOC_BI] arr S9
# 21:08:43 HS2 [Train 119 LOOC_BI] arr S8
# 21:08:53 HS2 [Train 120 LOOC_BI] arr S7
# 21:09:03 HS2 [Train 121 LOOC_BI] arr S6
# 21:09:07 HS2 [Train 118 LOOC_BI] dep S9 for S10
# 21:09:13 HS2 [Train 122 LOOC_BI] arr S5
# 21:09:23 HS2 [Train 123 LOOC_BI] arr S4
# 21:09:33 HS2 [Train 124 LOOC_BI] arr S3
# 21:09:43 HS2 [Train 125 LOOC_BI] arr S2
# 21:09:50 HS2 [Train 116 LOOC_BI] arr S12
# 21:10:19 HS2 [Train 116 LOOC_BI] dep S12 for S13
# 21:11:12 HS2 [Train 119 LOOC_BI] dep S8 for S9
# 21:11:22 HS2 [Train 120 LOOC_BI] dep S7 for S8
# 21:11:32 HS2 [Train 121 LOOC_BI] dep S6 for S7
# 21:11:39 HS2 [Train 117 LOOC_BI] arr S11
# 21:11:42 HS2 [Train 122 LOOC_BI] dep S5 for S6
# 21:11:49 HS2 [Train 115 LOOC_BI] arr Birmingham Interchange
# 21:11:52 HS2 [Train 123 LOOC_BI] dep S4 for S5
# 21:12:02 HS2 [Train 124 LOOC_BI] dep S3 for S4
# 21:12:12 HS2 [Train 125 LOOC_BI] dep S2 for S3
# 21:12:22 HS2 [Train 126 LOOC_BI] dep London Old Oak Common for S2
# 21:12:29 HS2 [Train 117 LOOC_BI] dep S11 for S12
# 21:12:32 HS2 [Train 127 LOOC_BI] dep London Old Oak Common (DEPOT) for London Old Oak Common
# 21:12:49 HS2 [Train 115 LOOC_BI] dep Birmingham Interchange for London Old Oak Common (DEPOT)
# 21:12:52 HS2 [Train 127 LOOC_BI] arr London Old Oak Common
# 21:13:09 HS2 [Train 118 LOOC_BI] arr S10
# 21:13:09 HS2 [Train 115 LOOC_BI] arr London Old Oak Common (DEPOT)
# 21:14:18 HS2 [Train 118 LOOC_BI] dep S10 for S11
# 21:14:21 HS2 [Train 116 LOOC_BI] arr S13
# 21:14:28 HS2 [Train 116 LOOC_BI] dep S13 for Birmingham Interchange
# 21:15:14 HS2 [Train 119 LOOC_BI] arr S9
# 21:15:24 HS2 [Train 120 LOOC_BI] arr S8
# 21:15:34 HS2 [Train 121 LOOC_BI] arr S7
# 21:15:44 HS2 [Train 122 LOOC_BI] arr S6
# 21:15:48 HS2 [Train 119 LOOC_BI] dep S9 for S10
# 21:15:54 HS2 [Train 123 LOOC_BI] arr S5
# 21:16:04 HS2 [Train 124 LOOC_BI] arr S4
# 21:16:14 HS2 [Train 125 LOOC_BI] arr S3
# 21:16:24 HS2 [Train 126 LOOC_BI] arr S2
# 21:16:31 HS2 [Train 117 LOOC_BI] arr S12
# 21:17:00 HS2 [Train 117 LOOC_BI] dep S12 for S13
# 21:17:53 HS2 [Train 120 LOOC_BI] dep S8 for S9
# 21:18:03 HS2 [Train 121 LOOC_BI] dep S7 for S8
# 21:18:13 HS2 [Train 122 LOOC_BI] dep S6 for S7
# 21:18:20 HS2 [Train 118 LOOC_BI] arr S11
# 21:18:23 HS2 [Train 123 LOOC_BI] dep S5 for S6
# 21:18:30 HS2 [Train 116 LOOC_BI] arr Birmingham Interchange
# 21:18:33 HS2 [Train 124 LOOC_BI] dep S4 for S5
# 21:18:43 HS2 [Train 125 LOOC_BI] dep S3 for S4
# 21:18:53 HS2 [Train 126 LOOC_BI] dep S2 for S3
# 21:19:03 HS2 [Train 127 LOOC_BI] dep London Old Oak Common for S2
# 21:19:10 HS2 [Train 118 LOOC_BI] dep S11 for S12
# 21:19:13 HS2 [Train 128 LOOC_BI] dep London Old Oak Common (DEPOT) for London Old Oak Common
# 21:19:30 HS2 [Train 116 LOOC_BI] dep Birmingham Interchange for London Old Oak Common (DEPOT)
# 21:19:33 HS2 [Train 128 LOOC_BI] arr London Old Oak Common
# 21:19:50 HS2 [Train 119 LOOC_BI] arr S10
# 21:19:50 HS2 [Train 116 LOOC_BI] arr London Old Oak Common (DEPOT)
# 21:20:59 HS2 [Train 119 LOOC_BI] dep S10 for S11
# 21:21:02 HS2 [Train 117 LOOC_BI] arr S13
# 21:21:09 HS2 [Train 117 LOOC_BI] dep S13 for Birmingham Interchange
# 21:21:55 HS2 [Train 120 LOOC_BI] arr S9
# 21:22:05 HS2 [Train 121 LOOC_BI] arr S8
# 21:22:15 HS2 [Train 122 LOOC_BI] arr S7
# 21:22:25 HS2 [Train 123 LOOC_BI] arr S6
# 21:22:29 HS2 [Train 120 LOOC_BI] dep S9 for S10
# 21:22:35 HS2 [Train 124 LOOC_BI] arr S5
# 21:22:45 HS2 [Train 125 LOOC_BI] arr S4
# 21:22:55 HS2 [Train 126 LOOC_BI] arr S3
# 21:23:05 HS2 [Train 127 LOOC_BI] arr S2
# 21:23:12 HS2 [Train 118 LOOC_BI] arr S12
# 21:23:41 HS2 [Train 118 LOOC_BI] dep S12 for S13
# 21:24:34 HS2 [Train 121 LOOC_BI] dep S8 for S9
# 21:24:44 HS2 [Train 122 LOOC_BI] dep S7 for S8
# 21:24:54 HS2 [Train 123 LOOC_BI] dep S6 for S7
# 21:25:01 HS2 [Train 119 LOOC_BI] arr S11
# 21:25:04 HS2 [Train 124 LOOC_BI] dep S5 for S6
# 21:25:11 HS2 [Train 117 LOOC_BI] arr Birmingham Interchange
# 21:25:14 HS2 [Train 125 LOOC_BI] dep S4 for S5
# 21:25:24 HS2 [Train 126 LOOC_BI] dep S3 for S4
# 21:25:34 HS2 [Train 127 LOOC_BI] dep S2 for S3
# 21:25:44 HS2 [Train 128 LOOC_BI] dep London Old Oak Common for S2
# 21:25:51 HS2 [Train 119 LOOC_BI] dep S11 for S12
# 21:25:54 HS2 [Train 129 LOOC_BI] dep London Old Oak Common (DEPOT) for London Old Oak Common
# 21:26:11 HS2 [Train 117 LOOC_BI] dep Birmingham Interchange for London Old Oak Common (DEPOT)
# 21:26:14 HS2 [Train 129 LOOC_BI] arr London Old Oak Common
# 21:26:31 HS2 [Train 120 LOOC_BI] arr S10
# 21:26:31 HS2 [Train 117 LOOC_BI] arr London Old Oak Common (DEPOT)
# 21:27:40 HS2 [Train 120 LOOC_BI] dep S10 for S11
# 21:27:43 HS2 [Train 118 LOOC_BI] arr S13
# 21:27:50 HS2 [Train 118 LOOC_BI] dep S13 for Birmingham Interchange
# 21:28:36 HS2 [Train 121 LOOC_BI] arr S9
# 21:28:46 HS2 [Train 122 LOOC_BI] arr S8
# 21:28:56 HS2 [Train 123 LOOC_BI] arr S7
# 21:29:06 HS2 [Train 124 LOOC_BI] arr S6
# 21:29:10 HS2 [Train 121 LOOC_BI] dep S9 for S10
# 21:29:16 HS2 [Train 125 LOOC_BI] arr S5
# 21:29:26 HS2 [Train 126 LOOC_BI] arr S4
# 21:29:36 HS2 [Train 127 LOOC_BI] arr S3
# 21:29:46 HS2 [Train 128 LOOC_BI] arr S2
# 21:29:53 HS2 [Train 119 LOOC_BI] arr S12
# 21:30:22 HS2 [Train 119 LOOC_BI] dep S12 for S13
# 21:31:15 HS2 [Train 122 LOOC_BI] dep S8 for S9
# 21:31:25 HS2 [Train 123 LOOC_BI] dep S7 for S8
# 21:31:35 HS2 [Train 124 LOOC_BI] dep S6 for S7
# 21:31:42 HS2 [Train 120 LOOC_BI] arr S11
# 21:31:45 HS2 [Train 125 LOOC_BI] dep S5 for S6
# 21:31:52 HS2 [Train 118 LOOC_BI] arr Birmingham Interchange
# 21:31:55 HS2 [Train 126 LOOC_BI] dep S4 for S5
# 21:32:05 HS2 [Train 127 LOOC_BI] dep S3 for S4
# 21:32:15 HS2 [Train 128 LOOC_BI] dep S2 for S3
# 21:32:25 HS2 [Train 129 LOOC_BI] dep London Old Oak Common for S2
# 21:32:32 HS2 [Train 120 LOOC_BI] dep S11 for S12
# 21:32:35 HS2 [Train 130 LOOC_BI] dep London Old Oak Common (DEPOT) for London Old Oak Common
# 21:32:52 HS2 [Train 118 LOOC_BI] dep Birmingham Interchange for London Old Oak Common (DEPOT)
# 21:32:55 HS2 [Train 130 LOOC_BI] arr London Old Oak Common
# 21:33:12 HS2 [Train 121 LOOC_BI] arr S10
# 21:33:12 HS2 [Train 118 LOOC_BI] arr London Old Oak Common (DEPOT)
# 21:34:21 HS2 [Train 121 LOOC_BI] dep S10 for S11
# 21:34:24 HS2 [Train 119 LOOC_BI] arr S13
# 21:34:31 HS2 [Train 119 LOOC_BI] dep S13 for Birmingham Interchange
# 21:35:17 HS2 [Train 122 LOOC_BI] arr S9
# 21:35:27 HS2 [Train 123 LOOC_BI] arr S8
# 21:35:37 HS2 [Train 124 LOOC_BI] arr S7
# 21:35:47 HS2 [Train 125 LOOC_BI] arr S6
# 21:35:51 HS2 [Train 122 LOOC_BI] dep S9 for S10
# 21:35:57 HS2 [Train 126 LOOC_BI] arr S5
# 21:36:07 HS2 [Train 127 LOOC_BI] arr S4
# 21:36:17 HS2 [Train 128 LOOC_BI] arr S3
# 21:36:27 HS2 [Train 129 LOOC_BI] arr S2
# 21:36:34 HS2 [Train 120 LOOC_BI] arr S12
# 21:37:03 HS2 [Train 120 LOOC_BI] dep S12 for S13
# 21:37:56 HS2 [Train 123 LOOC_BI] dep S8 for S9
# 21:38:06 HS2 [Train 124 LOOC_BI] dep S7 for S8
# 21:38:16 HS2 [Train 125 LOOC_BI] dep S6 for S7
# 21:38:23 HS2 [Train 121 LOOC_BI] arr S11
# 21:38:26 HS2 [Train 126 LOOC_BI] dep S5 for S6
# 21:38:33 HS2 [Train 119 LOOC_BI] arr Birmingham Interchange
# 21:38:36 HS2 [Train 127 LOOC_BI] dep S4 for S5
# 21:38:46 HS2 [Train 128 LOOC_BI] dep S3 for S4
# 21:38:56 HS2 [Train 129 LOOC_BI] dep S2 for S3
# 21:39:06 HS2 [Train 130 LOOC_BI] dep London Old Oak Common for S2
# 21:39:13 HS2 [Train 121 LOOC_BI] dep S11 for S12
# 21:39:16 HS2 [Train 131 LOOC_BI] dep London Old Oak Common (DEPOT) for London Old Oak Common
# 21:39:33 HS2 [Train 119 LOOC_BI] dep Birmingham Interchange for London Old Oak Common (DEPOT)
# 21:39:36 HS2 [Train 131 LOOC_BI] arr London Old Oak Common
# 21:39:53 HS2 [Train 122 LOOC_BI] arr S10
# 21:39:53 HS2 [Train 119 LOOC_BI] arr London Old Oak Common (DEPOT)
# 21:41:02 HS2 [Train 122 LOOC_BI] dep S10 for S11
# 21:41:05 HS2 [Train 120 LOOC_BI] arr S13
# 21:41:12 HS2 [Train 120 LOOC_BI] dep S13 for Birmingham Interchange
# 21:41:58 HS2 [Train 123 LOOC_BI] arr S9
# 21:42:08 HS2 [Train 124 LOOC_BI] arr S8
# 21:42:18 HS2 [Train 125 LOOC_BI] arr S7
# 21:42:28 HS2 [Train 126 LOOC_BI] arr S6
# 21:42:32 HS2 [Train 123 LOOC_BI] dep S9 for S10
# 21:42:38 HS2 [Train 127 LOOC_BI] arr S5
# 21:42:48 HS2 [Train 128 LOOC_BI] arr S4
# 21:42:58 HS2 [Train 129 LOOC_BI] arr S3
# 21:43:08 HS2 [Train 130 LOOC_BI] arr S2
# 21:43:15 HS2 [Train 121 LOOC_BI] arr S12
# 21:43:44 HS2 [Train 121 LOOC_BI] dep S12 for S13
# 21:44:37 HS2 [Train 124 LOOC_BI] dep S8 for S9
# 21:44:47 HS2 [Train 125 LOOC_BI] dep S7 for S8
# 21:44:57 HS2 [Train 126 LOOC_BI] dep S6 for S7
# 21:45:04 HS2 [Train 122 LOOC_BI] arr S11
# 21:45:07 HS2 [Train 127 LOOC_BI] dep S5 for S6
# 21:45:14 HS2 [Train 120 LOOC_BI] arr Birmingham Interchange
# 21:45:17 HS2 [Train 128 LOOC_BI] dep S4 for S5
# 21:45:27 HS2 [Train 129 LOOC_BI] dep S3 for S4
# 21:45:37 HS2 [Train 130 LOOC_BI] dep S2 for S3
# 21:45:47 HS2 [Train 131 LOOC_BI] dep London Old Oak Common for S2
# 21:45:54 HS2 [Train 122 LOOC_BI] dep S11 for S12
# 21:45:57 HS2 [Train 132 LOOC_BI] dep London Old Oak Common (DEPOT) for London Old Oak Common
# 21:46:14 HS2 [Train 120 LOOC_BI] dep Birmingham Interchange for London Old Oak Common (DEPOT)
# 21:46:17 HS2 [Train 132 LOOC_BI] arr London Old Oak Common
# 21:46:34 HS2 [Train 123 LOOC_BI] arr S10
# 21:46:34 HS2 [Train 120 LOOC_BI] arr London Old Oak Common (DEPOT)
# 21:47:43 HS2 [Train 123 LOOC_BI] dep S10 for S11
# 21:47:46 HS2 [Train 121 LOOC_BI] arr S13
# 21:47:53 HS2 [Train 121 LOOC_BI] dep S13 for Birmingham Interchange
# 21:48:39 HS2 [Train 124 LOOC_BI] arr S9
# 21:48:49 HS2 [Train 125 LOOC_BI] arr S8
# 21:48:59 HS2 [Train 126 LOOC_BI] arr S7
# 21:49:09 HS2 [Train 127 LOOC_BI] arr S6
# 21:49:13 HS2 [Train 124 LOOC_BI] dep S9 for S10
# 21:49:19 HS2 [Train 128 LOOC_BI] arr S5
# 21:49:29 HS2 [Train 129 LOOC_BI] arr S4
# 21:49:39 HS2 [Train 130 LOOC_BI] arr S3
# 21:49:49 HS2 [Train 131 LOOC_BI] arr S2
# 21:49:56 HS2 [Train 122 LOOC_BI] arr S12
# 21:50:25 HS2 [Train 122 LOOC_BI] dep S12 for S13
# 21:51:18 HS2 [Train 125 LOOC_BI] dep S8 for S9
# 21:51:28 HS2 [Train 126 LOOC_BI] dep S7 for S8
# 21:51:38 HS2 [Train 127 LOOC_BI] dep S6 for S7
# 21:51:45 HS2 [Train 123 LOOC_BI] arr S11
# 21:51:48 HS2 [Train 128 LOOC_BI] dep S5 for S6
# 21:51:55 HS2 [Train 121 LOOC_BI] arr Birmingham Interchange
# 21:51:58 HS2 [Train 129 LOOC_BI] dep S4 for S5
# 21:52:08 HS2 [Train 130 LOOC_BI] dep S3 for S4
# 21:52:18 HS2 [Train 131 LOOC_BI] dep S2 for S3
# 21:52:28 HS2 [Train 132 LOOC_BI] dep London Old Oak Common for S2
# 21:52:35 HS2 [Train 123 LOOC_BI] dep S11 for S12
# 21:52:38 HS2 [Train 133 LOOC_BI] dep London Old Oak Common (DEPOT) for London Old Oak Common
# 21:52:55 HS2 [Train 121 LOOC_BI] dep Birmingham Interchange for London Old Oak Common (DEPOT)
# 21:52:58 HS2 [Train 133 LOOC_BI] arr London Old Oak Common
# 21:53:15 HS2 [Train 124 LOOC_BI] arr S10
# 21:53:15 HS2 [Train 121 LOOC_BI] arr London Old Oak Common (DEPOT)
# 21:54:24 HS2 [Train 124 LOOC_BI] dep S10 for S11
# 21:54:27 HS2 [Train 122 LOOC_BI] arr S13
# 21:54:34 HS2 [Train 122 LOOC_BI] dep S13 for Birmingham Interchange
# 21:55:20 HS2 [Train 125 LOOC_BI] arr S9
# 21:55:30 HS2 [Train 126 LOOC_BI] arr S8
# 21:55:40 HS2 [Train 127 LOOC_BI] arr S7
# 21:55:50 HS2 [Train 128 LOOC_BI] arr S6
# 21:55:54 HS2 [Train 125 LOOC_BI] dep S9 for S10
# 21:56:00 HS2 [Train 129 LOOC_BI] arr S5
# 21:56:10 HS2 [Train 130 LOOC_BI] arr S4
# 21:56:20 HS2 [Train 131 LOOC_BI] arr S3
# 21:56:30 HS2 [Train 132 LOOC_BI] arr S2
# 21:56:37 HS2 [Train 123 LOOC_BI] arr S12
# 21:57:06 HS2 [Train 123 LOOC_BI] dep S12 for S13
# 21:57:59 HS2 [Train 126 LOOC_BI] dep S8 for S9
# 21:58:09 HS2 [Train 127 LOOC_BI] dep S7 for S8
# 21:58:19 HS2 [Train 128 LOOC_BI] dep S6 for S7
# 21:58:26 HS2 [Train 124 LOOC_BI] arr S11
# 21:58:29 HS2 [Train 129 LOOC_BI] dep S5 for S6
# 21:58:36 HS2 [Train 122 LOOC_BI] arr Birmingham Interchange
# 21:58:39 HS2 [Train 130 LOOC_BI] dep S4 for S5
# 21:58:49 HS2 [Train 131 LOOC_BI] dep S3 for S4
# 21:58:59 HS2 [Train 132 LOOC_BI] dep S2 for S3
# 21:59:09 HS2 [Train 133 LOOC_BI] dep London Old Oak Common for S2
# 21:59:16 HS2 [Train 124 LOOC_BI] dep S11 for S12
# 21:59:19 HS2 [Train 134 LOOC_BI] dep London Old Oak Common (DEPOT) for London Old Oak Common
# 21:59:36 HS2 [Train 122 LOOC_BI] dep Birmingham Interchange for London Old Oak Common (DEPOT)
# 21:59:39 HS2 [Train 134 LOOC_BI] arr London Old Oak Common
# 21:59:56 HS2 [Train 125 LOOC_BI] arr S10
# 21:59:56 HS2 [Train 122 LOOC_BI] arr London Old Oak Common (DEPOT)

# %%
class wait_time:
    def __init__(self):
        self.wt = 0

    def London_OOC(self):
        self.wt = 0
        return (self.wt)

    #def London_OOC(self):
     #   self.wt = (2 / 60) + np.random.exponential(1 / 60)
      #  return (self.wt)

    #def Birmingham_Int(self):
     #   self.wt = (2 / 60) + np.random.exponential(1 / 60)
      #  return (self.wt)

    def Birmingham_Int(self):
        self.wt = 0
        return (self.wt)

# %%
class Train(object):
    def __init__(self, env, sig_blocks, res, wait_class):
        self.sig_blocks=sig_blocks
        self.res = res
        self.wait_class = wait_class
        self.env=env
        
    def daytime(t):
        t=int(t)
        return f"{t//3600:02d}:{(t%3600)//60:02d}:{t%60:02d}"
    def now(env):
        return daytime(env.now)

    def Execute_Train(self ,ID):
        wc = self.wait_class
        row = {}
        row['No_Blocks'] = len(self.sig_blocks) - 1 # London and two birmingham blocks dont add to the total
        row['Train_No'] = ID

        yield (self.env.timeout(wc.London_OOC()))
        lon = self.res['London'].request()
        yield (lon)
        print('Train {} leaves London Old Oak  common at {}'.format(ID, daytime(self.env.now * 3600)))
        #row['Delay'] = self.env.now *60
  
        row['Departure_Time'] = daytime(self.env.now * 3600)
        yield (self.env.timeout(5 / 60))  # 5 minute wait
        print('Train {} arrives in Block0  at {}'.format(ID, daytime(self.env.now * 3600)))
        #row['Delay'] = self.env.now *60
        yield (self.env.timeout(wc.London_OOC()))  # wait for mandatory two mins with an extra delay of an average of one minute
        print('Train {} leaves Block0 at {}'.format(ID, daytime(self.env.now * 3600)))
        #row['Delay'] = self.env.now *60

        req_list = []
        req_list.append(self.res['Straight'][0].request())
        yield (req_list[0])
        yield(self.res['London'].release(lon))
        # Enter the long straight between London and brimingham
        SD_Ind = False
        Entry_speed = 0
        for i in range(1, len(self.sig_blocks)):
            print('Train {} enters signalling block {} at {}'.format(ID, i, daytime(self.env.now * 3600)))
            if i == len(self.sig_blocks) - 1:
                SD_Ind = True
            elif self.res['Straight'][i].count > 0:
                SD_Ind = True
                Entry_speed = 0
            elif i != 1:
                SD_Ind = False
                Entry_speed = 300

            Tib = Time_In_Block(i, self.sig_blocks, SD_Ind, Entry_speed)
            yield (self.env.timeout(Tib))
           


            # When we arrive at birmingham
            if i == len(self.sig_blocks) - 1:
                print('Train {} arrives in Block{} at {}'.format(ID ,len(self.sig_blocks),  daytime(self.env.now * 3600)))
                yield (self.env.timeout(wc.Birmingham_Int()))  # wait for mandatory two mins with an extra delay of an average of one minute
                #row['Delay'] = self.env.now *60
                bir1 = self.res['Birmingham'][0].request()
                yield (bir1)

            else:
                print('Train {} reaches end of signalling block {} at {}'.format(ID ,i , daytime(self.env.now * 3600)))
                req_list.append(self.res['Straight'][i].request())
                yield (req_list[i])

            self.res['Straight'][i - 1].release(req_list[i - 1])

        print('Train {} leaves Block{} at {}'.format(ID, len(self.sig_blocks) ,daytime(self.env.now * 3600)))
        yield (self.env.timeout(4.5 / 60))  # 4.5 Min journey
        #row['Delay'] = self.env.now *60
        print('Train {} is at Block number{} Block {}'.format(ID,len(self.sig_blocks)+1, daytime(self.env.now * 3600)))
        bir2 = self.res['Birmingham'][1].request()
        yield (bir2)
        self.res['Birmingham'][0].release(bir1)
        yield (self.env.timeout(4.5 / 60))  # 4.5 Min journey
        #row['Delay'] = self.env.now *60
        row['Arrival_Time'] = daytime(self.env.now * 3600)
        self.res['Birmingham'][1].release(bir2)
        print('Train {} arrives in Birmingham  Interchange at {}'.format(ID, daytime(self.env.now * 3600)))

        #append to output data frame
        global df_out
        df_out = df_out.append(row, ignore_index=True)
        
    def daytime(t):
        t=int(t)
        return f"{t//3600:02d}:{(t%3600)//60:02d}:{t%60:02d}"
    def now(env):
        return daytime(env.now)

# %%
import datetime
class London_2_Birmingham(object):
    def __init__(self, env, k, Times, Day_Num, wait_class, start, stop):
        self.env = env
        self.k = k
        self.Times = Times
        self.Day_Num = Day_Num
        self.wait_class = wait_class
        self.start = start
        self.stop = stop
        self.df = pd.DataFrame(
            {'No_Blocks': [], 'Train_No': [], 'Departure_Time': [], 'Arrival_Time': [], 'Journey_Time': [], 'Day': [],
             'Trains_PH': [], 'Delay': [], 'Train_Time_Interval': []})
        self.action = env.process(self.run(self.k, self.Times))
        

    # The overall process
    def run(self, k, Times):
        sig_blocks = Block_Location(k)

        # create resources
        avail = {}
        avail['Straight'] = self.Resources(k)  # A vector of train locations, True indcates presence of train
        avail['London'] = simpy.Resource(self.env, capacity=1)
        avail['Birmingham'] = self.Resources(2)

        global df_out
        df_out = pd.DataFrame(
            {'No_Blocks': [], 'Train_No': [], 'Departure_Time': [], 'Arrival_Time': [], 'Journey_Time': [], 'Day': [],
             'Trains_PH': [], 'Delay': [], 'Train_Time_Interval': []})

        Train_obj = Train(self.env, sig_blocks, avail, self.wait_class())

        x = 1  # Train ID
        self.env.process(Train_obj.Execute_Train(x))
        #self.df = self.df.append(row_vect, ignore_index=True)

        while True:
            yield (self.env.timeout(1 / Times))  # Times per hour
            x = x + 1
            self.env.process(Train_obj.Execute_Train(x))
            #self.df = self.df.append(row_vect, ignore_index=True)

    def Resources(self, k):
        out_l = []
        for i in range(k):
            out_l.append(simpy.Resource(self.env, capacity=1))
        return (out_l)

    def Return_Df(self):
        self.df = df_out        
        self.df['Day'] = self.Day_Num
        self.df['Train_Time_Interval'] = float(60 / self.Times)
        self.df['Trains_PH'] = self.Times
        return (self.df)

# %%
def daytime(t):
    t=int(t)
    return f"{t//3600:02d}:{(t%3600)//60:02d}:{t%60:02d}"
def now(env):
    return daytime(env.now)

# %%
def Full_Simulation(trains,signals,n_days):  # few Variable Inputs, keep everything consistent

    Output_df = pd.DataFrame(
        {'No_Blocks': [], 'Train_No': [], 'Departure_Time': [], 'Arrival_Time': [], 'Journey_Time': [], 'Day': [],
         'Trains_PH': [], 'Delay': [], 'Train_Time_Interval': []})

    for Tr in trains:
        for sig in signals:
            for day in range(1, n_days+1): 
                env = simpy.Environment()
                print(env.now)
                proc = London_2_Birmingham(env, sig, Tr, day, wait_time, start=6*3600, stop=7*3600)
                env.run(until=22)  # Assume trains operate 6am to midnight 18 hours
                Output_df = Output_df.append(proc.Return_Df(), ignore_index=True)
    return (Output_df)
Trains_PH = [6]
Sig_blocks = [3]

Sim_Data_1 = Full_Simulation(Trains_PH,Sig_blocks,1)
# Out:
# 0
# Train 1 leaves London Old Oak  common at 00:00:00
# Train 1 arrives in Block0  at 00:05:00
# Train 1 leaves Block0 at 00:05:00
# Train 1 enters signalling block 1 at 00:05:00
# Train 2 leaves London Old Oak  common at 00:10:00
# Train 2 arrives in Block0  at 00:15:00
# Train 2 leaves Block0 at 00:15:00
# Train 1 reaches end of signalling block 1 at 00:17:01
# Train 1 enters signalling block 2 at 00:17:01
# Train 2 enters signalling block 1 at 00:17:01
# Train 3 leaves London Old Oak  common at 00:20:00
# Train 3 arrives in Block0  at 00:24:59
# Train 3 leaves Block0 at 00:24:59
# Train 1 reaches end of signalling block 2 at 00:25:52
# Train 1 enters signalling block 3 at 00:25:52
# Train 2 reaches end of signalling block 1 at 00:28:17
# Train 2 enters signalling block 2 at 00:28:17
# Train 3 enters signalling block 1 at 00:28:17
# Train 4 leaves London Old Oak  common at 00:30:00
# Train 4 arrives in Block0  at 00:35:00
# Train 4 leaves Block0 at 00:35:00
# Train 1 arrives in Block4 at 00:35:39
# Train 1 leaves Block4 at 00:35:39
# Train 3 reaches end of signalling block 1 at 00:37:27
# Train 1 is at Block number5 Block 00:40:09
# Train 2 reaches end of signalling block 2 at 00:41:13
# Train 2 enters signalling block 3 at 00:41:13
# Train 3 enters signalling block 2 at 00:41:13
# Train 4 enters signalling block 1 at 00:41:13
# Train 5 leaves London Old Oak  common at 00:41:13
# Train 1 arrives in Birmingham  Interchange at 00:44:39
# Train 5 arrives in Block0  at 00:46:13
# Train 5 leaves Block0 at 00:46:13
# Train 3 reaches end of signalling block 2 at 00:52:12
# Train 4 reaches end of signalling block 1 at 00:53:29
# Train 2 arrives in Block4 at 00:55:11
# Train 2 leaves Block4 at 00:55:11
# Train 3 enters signalling block 3 at 00:55:11
# Train 4 enters signalling block 2 at 00:55:11
# Train 5 enters signalling block 1 at 00:55:11
# Train 6 leaves London Old Oak  common at 00:55:11
# Train 2 is at Block number5 Block 00:59:41
# Train 6 arrives in Block0  at 01:00:11
# Train 6 leaves Block0 at 01:00:11
# Train 2 arrives in Birmingham  Interchange at 01:04:11
# Train 5 reaches end of signalling block 1 at 01:04:38
# Train 3 arrives in Block4 at 01:06:47
# Train 3 leaves Block4 at 01:06:47
# Train 4 reaches end of signalling block 2 at 01:08:49
# Train 4 enters signalling block 3 at 01:08:49
# Train 5 enters signalling block 2 at 01:08:49
# Train 6 enters signalling block 1 at 01:08:49
# Train 7 leaves London Old Oak  common at 01:08:49
# Train 3 is at Block number5 Block 01:11:17
# Train 7 arrives in Block0  at 01:13:49
# Train 7 leaves Block0 at 01:13:49
# Train 3 arrives in Birmingham  Interchange at 01:15:47
# Train 5 reaches end of signalling block 2 at 01:20:15
# Train 4 arrives in Block4 at 01:20:20
# Train 4 leaves Block4 at 01:20:20
# Train 5 enters signalling block 3 at 01:20:20
# Train 6 reaches end of signalling block 1 at 01:22:04
# Train 6 enters signalling block 2 at 01:22:04
# Train 7 enters signalling block 1 at 01:22:04
# Train 8 leaves London Old Oak  common at 01:22:04
# Train 4 is at Block number5 Block 01:24:50
# Train 8 arrives in Block0  at 01:27:04
# Train 8 leaves Block0 at 01:27:04
# Train 4 arrives in Birmingham  Interchange at 01:29:20
# Train 5 arrives in Block4 at 01:30:55
# Train 5 leaves Block4 at 01:30:55
# Train 7 reaches end of signalling block 1 at 01:32:55
# Train 6 reaches end of signalling block 2 at 01:33:45
# Train 6 enters signalling block 3 at 01:33:45
# Train 7 enters signalling block 2 at 01:33:45
# Train 8 enters signalling block 1 at 01:33:45
# Train 9 leaves London Old Oak  common at 01:33:45
# Train 5 is at Block number5 Block 01:35:25
# Train 9 arrives in Block0  at 01:38:45
# Train 9 leaves Block0 at 01:38:45
# Train 5 arrives in Birmingham  Interchange at 01:39:55
# Train 8 reaches end of signalling block 1 at 01:44:20
# Train 6 arrives in Block4 at 01:45:42
# Train 6 leaves Block4 at 01:45:42
# Train 7 reaches end of signalling block 2 at 01:46:20
# Train 7 enters signalling block 3 at 01:46:20
# Train 8 enters signalling block 2 at 01:46:20
# Train 9 enters signalling block 1 at 01:46:20
# Train 10 leaves London Old Oak  common at 01:46:20
# Train 6 is at Block number5 Block 01:50:12
# Train 10 arrives in Block0  at 01:51:20
# Train 10 leaves Block0 at 01:51:20
# Train 6 arrives in Birmingham  Interchange at 01:54:42
# Train 9 reaches end of signalling block 1 at 01:58:50
# Train 8 reaches end of signalling block 2 at 01:59:18
# Train 7 arrives in Block4 at 01:59:36
# Train 7 leaves Block4 at 01:59:36
# Train 8 enters signalling block 3 at 01:59:36
# Train 9 enters signalling block 2 at 01:59:36
# Train 10 enters signalling block 1 at 01:59:36
# Train 11 leaves London Old Oak  common at 01:59:36
# Train 7 is at Block number5 Block 02:04:06
# Train 11 arrives in Block0  at 02:04:36
# Train 11 leaves Block0 at 02:04:36
# Train 7 arrives in Birmingham  Interchange at 02:08:36
# Train 9 reaches end of signalling block 2 at 02:10:40
# Train 10 reaches end of signalling block 1 at 02:11:20
# Train 8 arrives in Block4 at 02:12:34
# Train 8 leaves Block4 at 02:12:34
# Train 9 enters signalling block 3 at 02:12:34
# Train 10 enters signalling block 2 at 02:12:34
# Train 11 enters signalling block 1 at 02:12:34
# Train 12 leaves London Old Oak  common at 02:12:34
# Train 8 is at Block number5 Block 02:17:04
# Train 12 arrives in Block0  at 02:17:34
# Train 12 leaves Block0 at 02:17:34
# Train 8 arrives in Birmingham  Interchange at 02:21:34
# Train 9 arrives in Block4 at 02:23:20
# Train 9 leaves Block4 at 02:23:20
# Train 10 reaches end of signalling block 2 at 02:24:08
# Train 10 enters signalling block 3 at 02:24:08
# Train 11 reaches end of signalling block 1 at 02:25:05
# Train 11 enters signalling block 2 at 02:25:05
# Train 12 enters signalling block 1 at 02:25:05
# Train 13 leaves London Old Oak  common at 02:25:05
# Train 9 is at Block number5 Block 02:27:50
# Train 13 arrives in Block0  at 02:30:05
# Train 13 leaves Block0 at 02:30:05
# Train 9 arrives in Birmingham  Interchange at 02:32:20
# Train 10 arrives in Block4 at 02:35:12
# Train 10 leaves Block4 at 02:35:12
# Train 12 reaches end of signalling block 1 at 02:36:10
# Train 11 reaches end of signalling block 2 at 02:36:30
# Train 11 enters signalling block 3 at 02:36:30
# Train 12 enters signalling block 2 at 02:36:30
# Train 13 enters signalling block 1 at 02:36:30
# Train 14 leaves London Old Oak  common at 02:36:30
# Train 10 is at Block number5 Block 02:39:42
# Train 14 arrives in Block0  at 02:41:30
# Train 14 leaves Block0 at 02:41:30
# Train 10 arrives in Birmingham  Interchange at 02:44:12
# Train 11 arrives in Block4 at 02:47:24
# Train 11 leaves Block4 at 02:47:24
# Train 12 reaches end of signalling block 2 at 02:47:36
# Train 12 enters signalling block 3 at 02:47:36
# Train 13 reaches end of signalling block 1 at 02:48:23
# Train 13 enters signalling block 2 at 02:48:23
# Train 14 enters signalling block 1 at 02:48:23
# Train 15 leaves London Old Oak  common at 02:48:23
# Train 11 is at Block number5 Block 02:51:54
# Train 15 arrives in Block0  at 02:53:23
# Train 15 leaves Block0 at 02:53:23
# Train 11 arrives in Birmingham  Interchange at 02:56:24
# Train 12 arrives in Block4 at 02:58:10
# Train 12 leaves Block4 at 02:58:10
# Train 13 reaches end of signalling block 2 at 03:00:34
# Train 13 enters signalling block 3 at 03:00:34
# Train 14 reaches end of signalling block 1 at 03:02:15
# Train 14 enters signalling block 2 at 03:02:15
# Train 15 enters signalling block 1 at 03:02:15
# Train 16 leaves London Old Oak  common at 03:02:15
# Train 12 is at Block number5 Block 03:02:40
# Train 12 arrives in Birmingham  Interchange at 03:07:10
# Train 16 arrives in Block0  at 03:07:15
# Train 16 leaves Block0 at 03:07:15
# Train 15 reaches end of signalling block 1 at 03:13:06
# Train 13 arrives in Block4 at 03:13:20
# Train 13 leaves Block4 at 03:13:20
# Train 14 reaches end of signalling block 2 at 03:13:55
# Train 14 enters signalling block 3 at 03:13:55
# Train 15 enters signalling block 2 at 03:13:55
# Train 16 enters signalling block 1 at 03:13:55
# Train 17 leaves London Old Oak  common at 03:13:55
# Train 13 is at Block number5 Block 03:17:50
# Train 17 arrives in Block0  at 03:18:55
# Train 17 leaves Block0 at 03:18:55
# Train 13 arrives in Birmingham  Interchange at 03:22:20
# Train 14 arrives in Block4 at 03:24:56
# Train 14 leaves Block4 at 03:24:56
# Train 16 reaches end of signalling block 1 at 03:25:52
# Train 15 reaches end of signalling block 2 at 03:27:50
# Train 15 enters signalling block 3 at 03:27:50
# Train 16 enters signalling block 2 at 03:27:50
# Train 17 enters signalling block 1 at 03:27:50
# Train 18 leaves London Old Oak  common at 03:27:50
# Train 14 is at Block number5 Block 03:29:26
# Train 18 arrives in Block0  at 03:32:50
# Train 18 leaves Block0 at 03:32:50
# Train 14 arrives in Birmingham  Interchange at 03:33:56
# Train 15 arrives in Block4 at 03:38:58
# Train 15 leaves Block4 at 03:38:58
# Train 16 reaches end of signalling block 2 at 03:39:57
# Train 16 enters signalling block 3 at 03:39:57
# Train 17 reaches end of signalling block 1 at 03:42:13
# Train 17 enters signalling block 2 at 03:42:13
# Train 18 enters signalling block 1 at 03:42:13
# Train 19 leaves London Old Oak  common at 03:42:13
# Train 15 is at Block number5 Block 03:43:28
# Train 19 arrives in Block0  at 03:47:13
# Train 19 leaves Block0 at 03:47:13
# Train 15 arrives in Birmingham  Interchange at 03:47:58
# Train 16 arrives in Block4 at 03:51:59
# Train 16 leaves Block4 at 03:51:59
# Train 18 reaches end of signalling block 1 at 03:54:28
# Train 17 reaches end of signalling block 2 at 03:54:51
# Train 17 enters signalling block 3 at 03:54:51
# Train 18 enters signalling block 2 at 03:54:51
# Train 19 enters signalling block 1 at 03:54:51
# Train 20 leaves London Old Oak  common at 03:54:51
# Train 16 is at Block number5 Block 03:56:29
# Train 20 arrives in Block0  at 03:59:51
# Train 20 leaves Block0 at 03:59:51
# Train 16 arrives in Birmingham  Interchange at 04:00:59
# Train 18 reaches end of signalling block 2 at 04:05:23
# Train 17 arrives in Block4 at 04:06:19
# Train 17 leaves Block4 at 04:06:19
# Train 18 enters signalling block 3 at 04:06:19
# Train 19 reaches end of signalling block 1 at 04:06:20
# Train 19 enters signalling block 2 at 04:06:20
# Train 20 enters signalling block 1 at 04:06:20
# Train 21 leaves London Old Oak  common at 04:06:20
# Train 17 is at Block number5 Block 04:10:49
# Train 21 arrives in Block0  at 04:11:20
# Train 21 leaves Block0 at 04:11:20
# Train 17 arrives in Birmingham  Interchange at 04:15:19
# Train 18 arrives in Block4 at 04:17:58
# Train 18 leaves Block4 at 04:17:58
# Train 19 reaches end of signalling block 2 at 04:18:55
# Train 19 enters signalling block 3 at 04:18:55
# Train 20 reaches end of signalling block 1 at 04:19:13
# Train 20 enters signalling block 2 at 04:19:13
# Train 21 enters signalling block 1 at 04:19:13
# Train 22 leaves London Old Oak  common at 04:19:13
# Train 18 is at Block number5 Block 04:22:28
# Train 22 arrives in Block0  at 04:24:13
# Train 22 leaves Block0 at 04:24:13
# Train 18 arrives in Birmingham  Interchange at 04:26:58
# Train 20 reaches end of signalling block 2 at 04:31:27
# Train 19 arrives in Block4 at 04:31:55
# Train 19 leaves Block4 at 04:31:55
# Train 20 enters signalling block 3 at 04:31:55
# Train 21 reaches end of signalling block 1 at 04:32:10
# Train 21 enters signalling block 2 at 04:32:10
# Train 22 enters signalling block 1 at 04:32:10
# Train 23 leaves London Old Oak  common at 04:32:10
# Train 19 is at Block number5 Block 04:36:25
# Train 23 arrives in Block0  at 04:37:10
# Train 23 leaves Block0 at 04:37:10
# Train 19 arrives in Birmingham  Interchange at 04:40:55
# Train 20 arrives in Block4 at 04:42:55
# Train 20 leaves Block4 at 04:42:55
# Train 22 reaches end of signalling block 1 at 04:44:40
# Train 21 reaches end of signalling block 2 at 04:45:33
# Train 21 enters signalling block 3 at 04:45:33
# Train 22 enters signalling block 2 at 04:45:33
# Train 23 enters signalling block 1 at 04:45:33
# Train 24 leaves London Old Oak  common at 04:45:33
# Train 20 is at Block number5 Block 04:47:25
# Train 24 arrives in Block0  at 04:50:33
# Train 24 leaves Block0 at 04:50:33
# Train 20 arrives in Birmingham  Interchange at 04:51:55
# Train 21 arrives in Block4 at 04:57:05
# Train 21 leaves Block4 at 04:57:05
# Train 23 reaches end of signalling block 1 at 04:57:21
# Train 22 reaches end of signalling block 2 at 04:58:02
# Train 22 enters signalling block 3 at 04:58:02
# Train 23 enters signalling block 2 at 04:58:02
# Train 24 enters signalling block 1 at 04:58:02
# Train 25 leaves London Old Oak  common at 04:58:02
# Train 21 is at Block number5 Block 05:01:35
# Train 25 arrives in Block0  at 05:03:02
# Train 25 leaves Block0 at 05:03:02
# Train 21 arrives in Birmingham  Interchange at 05:06:05
# Train 22 arrives in Block4 at 05:11:16
# Train 22 leaves Block4 at 05:11:16
# Train 23 reaches end of signalling block 2 at 05:11:44
# Train 23 enters signalling block 3 at 05:11:44
# Train 24 reaches end of signalling block 1 at 05:12:31
# Train 24 enters signalling block 2 at 05:12:31
# Train 25 enters signalling block 1 at 05:12:31
# Train 26 leaves London Old Oak  common at 05:12:31
# Train 22 is at Block number5 Block 05:15:46
# Train 26 arrives in Block0  at 05:17:31
# Train 26 leaves Block0 at 05:17:31
# Train 22 arrives in Birmingham  Interchange at 05:20:16
# Train 23 arrives in Block4 at 05:21:58
# Train 23 leaves Block4 at 05:21:58
# Train 24 reaches end of signalling block 2 at 05:22:42
# Train 24 enters signalling block 3 at 05:22:42
# Train 25 reaches end of signalling block 1 at 05:23:49
# Train 25 enters signalling block 2 at 05:23:49
# Train 26 enters signalling block 1 at 05:23:49
# Train 27 leaves London Old Oak  common at 05:23:49
# Train 23 is at Block number5 Block 05:26:28
# Train 27 arrives in Block0  at 05:28:49
# Train 27 leaves Block0 at 05:28:49
# Train 23 arrives in Birmingham  Interchange at 05:30:58
# Train 24 arrives in Block4 at 05:34:47
# Train 24 leaves Block4 at 05:34:47
# Train 26 reaches end of signalling block 1 at 05:36:05
# Train 25 reaches end of signalling block 2 at 05:36:45
# Train 25 enters signalling block 3 at 05:36:45
# Train 26 enters signalling block 2 at 05:36:45
# Train 27 enters signalling block 1 at 05:36:45
# Train 28 leaves London Old Oak  common at 05:36:45
# Train 24 is at Block number5 Block 05:39:17
# Train 28 arrives in Block0  at 05:41:45
# Train 28 leaves Block0 at 05:41:45
# Train 24 arrives in Birmingham  Interchange at 05:43:47
# Train 25 arrives in Block4 at 05:46:14
# Train 25 leaves Block4 at 05:46:14
# Train 26 reaches end of signalling block 2 at 05:48:17
# Train 26 enters signalling block 3 at 05:48:17
# Train 27 reaches end of signalling block 1 at 05:49:38
# Train 27 enters signalling block 2 at 05:49:38
# Train 28 enters signalling block 1 at 05:49:38
# Train 29 leaves London Old Oak  common at 05:49:38
# Train 25 is at Block number5 Block 05:50:44
# Train 29 arrives in Block0  at 05:54:38
# Train 29 leaves Block0 at 05:54:38
# Train 25 arrives in Birmingham  Interchange at 05:55:14
# Train 26 arrives in Block4 at 06:00:27
# Train 26 leaves Block4 at 06:00:27
# Train 28 reaches end of signalling block 1 at 06:01:16
# Train 27 reaches end of signalling block 2 at 06:02:26
# Train 27 enters signalling block 3 at 06:02:26
# Train 28 enters signalling block 2 at 06:02:26
# Train 29 enters signalling block 1 at 06:02:26
# Train 30 leaves London Old Oak  common at 06:02:26
# Train 26 is at Block number5 Block 06:04:57
# Train 30 arrives in Block0  at 06:07:26
# Train 30 leaves Block0 at 06:07:26
# Train 26 arrives in Birmingham  Interchange at 06:09:27
# Train 27 arrives in Block4 at 06:14:05
# Train 27 leaves Block4 at 06:14:05
# Train 28 reaches end of signalling block 2 at 06:14:33
# Train 28 enters signalling block 3 at 06:14:33
# Train 29 reaches end of signalling block 1 at 06:14:49
# Train 29 enters signalling block 2 at 06:14:49
# Train 30 enters signalling block 1 at 06:14:49
# Train 31 leaves London Old Oak  common at 06:14:49
# Train 27 is at Block number5 Block 06:18:35
# Train 31 arrives in Block0  at 06:19:49
# Train 31 leaves Block0 at 06:19:49
# Train 27 arrives in Birmingham  Interchange at 06:23:05
# Train 30 reaches end of signalling block 1 at 06:25:55
# Train 28 arrives in Block4 at 06:26:41
# Train 28 leaves Block4 at 06:26:41
# Train 29 reaches end of signalling block 2 at 06:26:51
# Train 29 enters signalling block 3 at 06:26:51
# Train 30 enters signalling block 2 at 06:26:51
# Train 31 enters signalling block 1 at 06:26:51
# Train 32 leaves London Old Oak  common at 06:26:51
# Train 28 is at Block number5 Block 06:31:11
# Train 32 arrives in Block0  at 06:31:51
# Train 32 leaves Block0 at 06:31:51
# Train 28 arrives in Birmingham  Interchange at 06:35:41
# Train 30 reaches end of signalling block 2 at 06:38:53
# Train 29 arrives in Block4 at 06:39:12
# Train 29 leaves Block4 at 06:39:12
# Train 30 enters signalling block 3 at 06:39:12
# Train 31 reaches end of signalling block 1 at 06:40:05
# Train 31 enters signalling block 2 at 06:40:05
# Train 32 enters signalling block 1 at 06:40:05
# Train 33 leaves London Old Oak  common at 06:40:05
# Train 29 is at Block number5 Block 06:43:42
# Train 33 arrives in Block0  at 06:45:05
# Train 33 leaves Block0 at 06:45:05
# Train 29 arrives in Birmingham  Interchange at 06:48:12
# Train 32 reaches end of signalling block 1 at 06:51:32
# Train 31 reaches end of signalling block 2 at 06:52:12
# Train 30 arrives in Block4 at 06:52:31
# Train 30 leaves Block4 at 06:52:31
# Train 31 enters signalling block 3 at 06:52:31
# Train 32 enters signalling block 2 at 06:52:31
# Train 33 enters signalling block 1 at 06:52:31
# Train 34 leaves London Old Oak  common at 06:52:31
# Train 30 is at Block number5 Block 06:57:01
# Train 34 arrives in Block0  at 06:57:31
# Train 34 leaves Block0 at 06:57:31
# Train 30 arrives in Birmingham  Interchange at 07:01:31
# Train 31 arrives in Block4 at 07:03:39
# Train 31 leaves Block4 at 07:03:39
# Train 33 reaches end of signalling block 1 at 07:04:30
# Train 32 reaches end of signalling block 2 at 07:04:55
# Train 32 enters signalling block 3 at 07:04:55
# Train 33 enters signalling block 2 at 07:04:55
# Train 34 enters signalling block 1 at 07:04:55
# Train 35 leaves London Old Oak  common at 07:04:55
# Train 31 is at Block number5 Block 07:08:09
# Train 35 arrives in Block0  at 07:09:55
# Train 35 leaves Block0 at 07:09:55
# Train 31 arrives in Birmingham  Interchange at 07:12:39
# Train 34 reaches end of signalling block 1 at 07:16:04
# Train 32 arrives in Block4 at 07:16:24
# Train 32 leaves Block4 at 07:16:24
# Train 33 reaches end of signalling block 2 at 07:16:51
# Train 33 enters signalling block 3 at 07:16:51
# Train 34 enters signalling block 2 at 07:16:51
# Train 35 enters signalling block 1 at 07:16:51
# Train 36 leaves London Old Oak  common at 07:16:51
# Train 32 is at Block number5 Block 07:20:54
# Train 36 arrives in Block0  at 07:21:51
# Train 36 leaves Block0 at 07:21:51
# Train 32 arrives in Birmingham  Interchange at 07:25:24
# Train 34 reaches end of signalling block 2 at 07:28:13
# Train 33 arrives in Block4 at 07:29:35
# Train 33 leaves Block4 at 07:29:35
# Train 34 enters signalling block 3 at 07:29:35
# Train 35 reaches end of signalling block 1 at 07:30:12
# Train 35 enters signalling block 2 at 07:30:12
# Train 36 enters signalling block 1 at 07:30:12
# Train 37 leaves London Old Oak  common at 07:30:12
# Train 33 is at Block number5 Block 07:34:05
# Train 37 arrives in Block0  at 07:35:12
# Train 37 leaves Block0 at 07:35:12
# Train 33 arrives in Birmingham  Interchange at 07:38:35
# Train 36 reaches end of signalling block 1 at 07:40:48
# Train 34 arrives in Block4 at 07:41:57
# Train 34 leaves Block4 at 07:41:57
# Train 35 reaches end of signalling block 2 at 07:42:48
# Train 35 enters signalling block 3 at 07:42:48
# Train 36 enters signalling block 2 at 07:42:48
# Train 37 enters signalling block 1 at 07:42:48
# Train 38 leaves London Old Oak  common at 07:42:48
# Train 34 is at Block number5 Block 07:46:27
# Train 38 arrives in Block0  at 07:47:48
# Train 38 leaves Block0 at 07:47:48
# Train 34 arrives in Birmingham  Interchange at 07:50:57
# Train 37 reaches end of signalling block 1 at 07:53:34
# Train 35 arrives in Block4 at 07:54:54
# Train 35 leaves Block4 at 07:54:54
# Train 36 reaches end of signalling block 2 at 07:55:35
# Train 36 enters signalling block 3 at 07:55:35
# Train 37 enters signalling block 2 at 07:55:35
# Train 38 enters signalling block 1 at 07:55:35
# Train 39 leaves London Old Oak  common at 07:55:35
# Train 35 is at Block number5 Block 07:59:24
# Train 39 arrives in Block0  at 08:00:35
# Train 39 leaves Block0 at 08:00:35
# Train 35 arrives in Birmingham  Interchange at 08:03:54
# Train 38 reaches end of signalling block 1 at 08:05:51
# Train 36 arrives in Block4 at 08:07:10
# Train 36 leaves Block4 at 08:07:10
# Train 37 reaches end of signalling block 2 at 08:07:31
# Train 37 enters signalling block 3 at 08:07:31
# Train 38 enters signalling block 2 at 08:07:31
# Train 39 enters signalling block 1 at 08:07:31
# Train 40 leaves London Old Oak  common at 08:07:31
# Train 36 is at Block number5 Block 08:11:40
# Train 40 arrives in Block0  at 08:12:31
# Train 40 leaves Block0 at 08:12:31
# Train 36 arrives in Birmingham  Interchange at 08:16:10
# Train 39 reaches end of signalling block 1 at 08:18:23
# Train 37 arrives in Block4 at 08:19:47
# Train 37 leaves Block4 at 08:19:47
# Train 38 reaches end of signalling block 2 at 08:20:25
# Train 38 enters signalling block 3 at 08:20:25
# Train 39 enters signalling block 2 at 08:20:25
# Train 40 enters signalling block 1 at 08:20:25
# Train 41 leaves London Old Oak  common at 08:20:25
# Train 37 is at Block number5 Block 08:24:17
# Train 41 arrives in Block0  at 08:25:25
# Train 41 leaves Block0 at 08:25:25
# Train 37 arrives in Birmingham  Interchange at 08:28:47
# Train 39 reaches end of signalling block 2 at 08:30:45
# Train 40 reaches end of signalling block 1 at 08:32:16
# Train 38 arrives in Block4 at 08:32:44
# Train 38 leaves Block4 at 08:32:44
# Train 39 enters signalling block 3 at 08:32:44
# Train 40 enters signalling block 2 at 08:32:44
# Train 41 enters signalling block 1 at 08:32:44
# Train 42 leaves London Old Oak  common at 08:32:44
# Train 38 is at Block number5 Block 08:37:14
# Train 42 arrives in Block0  at 08:37:44
# Train 42 leaves Block0 at 08:37:44
# Train 38 arrives in Birmingham  Interchange at 08:41:44
# Train 39 arrives in Block4 at 08:42:42
# Train 39 leaves Block4 at 08:42:42
# Train 41 reaches end of signalling block 1 at 08:45:07
# Train 40 reaches end of signalling block 2 at 08:45:57
# Train 40 enters signalling block 3 at 08:45:57
# Train 41 enters signalling block 2 at 08:45:57
# Train 42 enters signalling block 1 at 08:45:57
# Train 43 leaves London Old Oak  common at 08:45:57
# Train 39 is at Block number5 Block 08:47:12
# Train 43 arrives in Block0  at 08:50:57
# Train 43 leaves Block0 at 08:50:57
# Train 39 arrives in Birmingham  Interchange at 08:51:42
# Train 41 reaches end of signalling block 2 at 08:56:56
# Train 40 arrives in Block4 at 08:57:49
# Train 40 leaves Block4 at 08:57:49
# Train 41 enters signalling block 3 at 08:57:49
# Train 42 reaches end of signalling block 1 at 08:59:22
# Train 42 enters signalling block 2 at 08:59:22
# Train 43 enters signalling block 1 at 08:59:22
# Train 44 leaves London Old Oak  common at 08:59:22
# Train 40 is at Block number5 Block 09:02:19
# Train 44 arrives in Block0  at 09:04:22
# Train 44 leaves Block0 at 09:04:22
# Train 40 arrives in Birmingham  Interchange at 09:06:49
# Train 42 reaches end of signalling block 2 at 09:09:03
# Train 41 arrives in Block4 at 09:12:03
# Train 41 leaves Block4 at 09:12:03
# Train 42 enters signalling block 3 at 09:12:03
# Train 43 reaches end of signalling block 1 at 09:12:44
# Train 43 enters signalling block 2 at 09:12:44
# Train 44 enters signalling block 1 at 09:12:44
# Train 45 leaves London Old Oak  common at 09:12:44
# Train 41 is at Block number5 Block 09:16:33
# Train 45 arrives in Block0  at 09:17:44
# Train 45 leaves Block0 at 09:17:44
# Train 41 arrives in Birmingham  Interchange at 09:21:03
# Train 44 reaches end of signalling block 1 at 09:23:12
# Train 43 reaches end of signalling block 2 at 09:25:02
# Train 42 arrives in Block4 at 09:25:53
# Train 42 leaves Block4 at 09:25:53
# Train 43 enters signalling block 3 at 09:25:53
# Train 44 enters signalling block 2 at 09:25:53
# Train 45 enters signalling block 1 at 09:25:53
# Train 46 leaves London Old Oak  common at 09:25:53
# Train 42 is at Block number5 Block 09:30:23
# Train 46 arrives in Block0  at 09:30:53
# Train 46 leaves Block0 at 09:30:53
# Train 42 arrives in Birmingham  Interchange at 09:34:53
# Train 45 reaches end of signalling block 1 at 09:37:04
# Train 44 reaches end of signalling block 2 at 09:37:34
# Train 43 arrives in Block4 at 09:38:48
# Train 43 leaves Block4 at 09:38:48
# Train 44 enters signalling block 3 at 09:38:48
# Train 45 enters signalling block 2 at 09:38:48
# Train 46 enters signalling block 1 at 09:38:48
# Train 47 leaves London Old Oak  common at 09:38:48
# Train 43 is at Block number5 Block 09:43:18
# Train 47 arrives in Block0  at 09:43:48
# Train 47 leaves Block0 at 09:43:48
# Train 43 arrives in Birmingham  Interchange at 09:47:48
# Train 44 arrives in Block4 at 09:49:14
# Train 44 leaves Block4 at 09:49:14
# Train 45 reaches end of signalling block 2 at 09:51:21
# Train 45 enters signalling block 3 at 09:51:21
# Train 46 reaches end of signalling block 1 at 09:51:39
# Train 46 enters signalling block 2 at 09:51:39
# Train 47 enters signalling block 1 at 09:51:39
# Train 48 leaves London Old Oak  common at 09:51:39
# Train 44 is at Block number5 Block 09:53:44
# Train 48 arrives in Block0  at 09:56:39
# Train 48 leaves Block0 at 09:56:39
# Train 44 arrives in Birmingham  Interchange at 09:58:14
# Train 47 reaches end of signalling block 1 at 10:02:11
# Train 45 arrives in Block4 at 10:02:31
# Train 45 leaves Block4 at 10:02:31
# Train 46 reaches end of signalling block 2 at 10:04:09
# Train 46 enters signalling block 3 at 10:04:09
# Train 47 enters signalling block 2 at 10:04:09
# Train 48 enters signalling block 1 at 10:04:09
# Train 49 leaves London Old Oak  common at 10:04:09
# Train 45 is at Block number5 Block 10:07:01
# Train 49 arrives in Block0  at 10:09:09
# Train 49 leaves Block0 at 10:09:09
# Train 45 arrives in Birmingham  Interchange at 10:11:31
# Train 48 reaches end of signalling block 1 at 10:15:50
# Train 47 reaches end of signalling block 2 at 10:16:06
# Train 46 arrives in Block4 at 10:17:00
# Train 46 leaves Block4 at 10:17:00
# Train 47 enters signalling block 3 at 10:17:00
# Train 48 enters signalling block 2 at 10:17:00
# Train 49 enters signalling block 1 at 10:17:00
# Train 50 leaves London Old Oak  common at 10:17:00
# Train 46 is at Block number5 Block 10:21:30
# Train 50 arrives in Block0  at 10:22:00
# Train 50 leaves Block0 at 10:22:00
# Train 46 arrives in Birmingham  Interchange at 10:26:00
# Train 47 arrives in Block4 at 10:28:47
# Train 47 leaves Block4 at 10:28:47
# Train 49 reaches end of signalling block 1 at 10:29:48
# Train 48 reaches end of signalling block 2 at 10:29:56
# Train 48 enters signalling block 3 at 10:29:56
# Train 49 enters signalling block 2 at 10:29:56
# Train 50 enters signalling block 1 at 10:29:56
# Train 51 leaves London Old Oak  common at 10:29:56
# Train 47 is at Block number5 Block 10:33:17
# Train 51 arrives in Block0  at 10:34:56
# Train 51 leaves Block0 at 10:34:56
# Train 47 arrives in Birmingham  Interchange at 10:37:47
# Train 50 reaches end of signalling block 1 at 10:41:55
# Train 49 reaches end of signalling block 2 at 10:41:59
# Train 48 arrives in Block4 at 10:42:27
# Train 48 leaves Block4 at 10:42:27
# Train 49 enters signalling block 3 at 10:42:27
# Train 50 enters signalling block 2 at 10:42:27
# Train 51 enters signalling block 1 at 10:42:27
# Train 52 leaves London Old Oak  common at 10:42:27
# Train 48 is at Block number5 Block 10:46:57
# Train 52 arrives in Block0  at 10:47:27
# Train 52 leaves Block0 at 10:47:27
# Train 48 arrives in Birmingham  Interchange at 10:51:27
# Train 50 reaches end of signalling block 2 at 10:54:38
# Train 49 arrives in Block4 at 10:55:05
# Train 49 leaves Block4 at 10:55:05
# Train 50 enters signalling block 3 at 10:55:05
# Train 51 reaches end of signalling block 1 at 10:55:10
# Train 51 enters signalling block 2 at 10:55:10
# Train 52 enters signalling block 1 at 10:55:10
# Train 53 leaves London Old Oak  common at 10:55:10
# Train 49 is at Block number5 Block 10:59:35
# Train 53 arrives in Block0  at 11:00:10
# Train 53 leaves Block0 at 11:00:10
# Train 49 arrives in Birmingham  Interchange at 11:04:05
# Train 51 reaches end of signalling block 2 at 11:04:10
# Train 50 arrives in Block4 at 11:06:37
# Train 50 leaves Block4 at 11:06:37
# Train 51 enters signalling block 3 at 11:06:37
# Train 52 reaches end of signalling block 1 at 11:08:18
# Train 52 enters signalling block 2 at 11:08:18
# Train 53 enters signalling block 1 at 11:08:18
# Train 54 leaves London Old Oak  common at 11:08:18
# Train 50 is at Block number5 Block 11:11:07
# Train 54 arrives in Block0  at 11:13:18
# Train 54 leaves Block0 at 11:13:18
# Train 50 arrives in Birmingham  Interchange at 11:15:37
# Train 53 reaches end of signalling block 1 at 11:20:04
# Train 52 reaches end of signalling block 2 at 11:20:43
# Train 51 arrives in Block4 at 11:21:06
# Train 51 leaves Block4 at 11:21:06
# Train 52 enters signalling block 3 at 11:21:06
# Train 53 enters signalling block 2 at 11:21:06
# Train 54 enters signalling block 1 at 11:21:06
# Train 55 leaves London Old Oak  common at 11:21:06
# Train 51 is at Block number5 Block 11:25:36
# Train 55 arrives in Block0  at 11:26:06
# Train 55 leaves Block0 at 11:26:06
# Train 51 arrives in Birmingham  Interchange at 11:30:06
# Train 52 arrives in Block4 at 11:32:50
# Train 52 leaves Block4 at 11:32:50
# Train 53 reaches end of signalling block 2 at 11:32:52
# Train 53 enters signalling block 3 at 11:32:52
# Train 54 reaches end of signalling block 1 at 11:33:01
# Train 54 enters signalling block 2 at 11:33:01
# Train 55 enters signalling block 1 at 11:33:01
# Train 56 leaves London Old Oak  common at 11:33:01
# Train 52 is at Block number5 Block 11:37:20
# Train 56 arrives in Block0  at 11:38:01
# Train 56 leaves Block0 at 11:38:01
# Train 52 arrives in Birmingham  Interchange at 11:41:50
# Train 53 arrives in Block4 at 11:43:25
# Train 53 leaves Block4 at 11:43:25
# Train 55 reaches end of signalling block 1 at 11:43:44
# Train 54 reaches end of signalling block 2 at 11:44:18
# Train 54 enters signalling block 3 at 11:44:18
# Train 55 enters signalling block 2 at 11:44:18
# Train 56 enters signalling block 1 at 11:44:18
# Train 57 leaves London Old Oak  common at 11:44:18
# Train 53 is at Block number5 Block 11:47:55
# Train 57 arrives in Block0  at 11:49:18
# Train 57 leaves Block0 at 11:49:18
# Train 53 arrives in Birmingham  Interchange at 11:52:25
# Train 55 reaches end of signalling block 2 at 11:55:51
# Train 54 arrives in Block4 at 11:56:30
# Train 54 leaves Block4 at 11:56:30
# Train 55 enters signalling block 3 at 11:56:30
# Train 56 reaches end of signalling block 1 at 11:56:47
# Train 56 enters signalling block 2 at 11:56:47
# Train 57 enters signalling block 1 at 11:56:47
# Train 58 leaves London Old Oak  common at 11:56:47
# Train 54 is at Block number5 Block 12:01:00
# Train 58 arrives in Block0  at 12:01:47
# Train 58 leaves Block0 at 12:01:47
# Train 54 arrives in Birmingham  Interchange at 12:05:30
# Train 55 arrives in Block4 at 12:08:11
# Train 55 leaves Block4 at 12:08:11
# Train 57 reaches end of signalling block 1 at 12:08:56
# Train 56 reaches end of signalling block 2 at 12:09:51
# Train 56 enters signalling block 3 at 12:09:51
# Train 57 enters signalling block 2 at 12:09:51
# Train 58 enters signalling block 1 at 12:09:51
# Train 59 leaves London Old Oak  common at 12:09:51
# Train 55 is at Block number5 Block 12:12:41
# Train 59 arrives in Block0  at 12:14:51
# Train 59 leaves Block0 at 12:14:51
# Train 55 arrives in Birmingham  Interchange at 12:17:11
# Train 57 reaches end of signalling block 2 at 12:19:30
# Train 58 reaches end of signalling block 1 at 12:20:59
# Train 56 arrives in Block4 at 12:24:21
# Train 56 leaves Block4 at 12:24:21
# Train 57 enters signalling block 3 at 12:24:21
# Train 58 enters signalling block 2 at 12:24:21
# Train 59 enters signalling block 1 at 12:24:21
# Train 60 leaves London Old Oak  common at 12:24:21
# Train 56 is at Block number5 Block 12:28:51
# Train 60 arrives in Block0  at 12:29:21
# Train 60 leaves Block0 at 12:29:21
# Train 56 arrives in Birmingham  Interchange at 12:33:21
# Train 59 reaches end of signalling block 1 at 12:35:57
# Train 57 arrives in Block4 at 12:37:19
# Train 57 leaves Block4 at 12:37:19
# Train 58 reaches end of signalling block 2 at 12:39:15
# Train 58 enters signalling block 3 at 12:39:15
# Train 59 enters signalling block 2 at 12:39:15
# Train 60 enters signalling block 1 at 12:39:15
# Train 61 leaves London Old Oak  common at 12:39:15
# Train 57 is at Block number5 Block 12:41:49
# Train 61 arrives in Block0  at 12:44:15
# Train 61 leaves Block0 at 12:44:15
# Train 57 arrives in Birmingham  Interchange at 12:46:19
# Train 59 reaches end of signalling block 2 at 12:50:53
# Train 58 arrives in Block4 at 12:51:12
# Train 58 leaves Block4 at 12:51:12
# Train 59 enters signalling block 3 at 12:51:12
# Train 60 reaches end of signalling block 1 at 12:52:44
# Train 60 enters signalling block 2 at 12:52:44
# Train 61 enters signalling block 1 at 12:52:44
# Train 62 leaves London Old Oak  common at 12:52:44
# Train 58 is at Block number5 Block 12:55:42
# Train 62 arrives in Block0  at 12:57:44
# Train 62 leaves Block0 at 12:57:44
# Train 58 arrives in Birmingham  Interchange at 13:00:12
# Train 59 arrives in Block4 at 13:02:45
# Train 59 leaves Block4 at 13:02:45
# Train 61 reaches end of signalling block 1 at 13:04:15
# Train 60 reaches end of signalling block 2 at 13:05:26
# Train 60 enters signalling block 3 at 13:05:26
# Train 61 enters signalling block 2 at 13:05:26
# Train 62 enters signalling block 1 at 13:05:26
# Train 63 leaves London Old Oak  common at 13:05:26
# Train 59 is at Block number5 Block 13:07:15
# Train 63 arrives in Block0  at 13:10:26
# Train 63 leaves Block0 at 13:10:26
# Train 59 arrives in Birmingham  Interchange at 13:11:45
# Train 60 arrives in Block4 at 13:15:49
# Train 60 leaves Block4 at 13:15:49
# Train 61 reaches end of signalling block 2 at 13:17:42
# Train 61 enters signalling block 3 at 13:17:42
# Train 62 reaches end of signalling block 1 at 13:17:56
# Train 62 enters signalling block 2 at 13:17:56
# Train 63 enters signalling block 1 at 13:17:56
# Train 64 leaves London Old Oak  common at 13:17:56
# Train 60 is at Block number5 Block 13:20:19
# Train 64 arrives in Block0  at 13:22:56
# Train 64 leaves Block0 at 13:22:56
# Train 60 arrives in Birmingham  Interchange at 13:24:49
# Train 63 reaches end of signalling block 1 at 13:29:05
# Train 62 reaches end of signalling block 2 at 13:29:42
# Train 61 arrives in Block4 at 13:31:08
# Train 61 leaves Block4 at 13:31:08
# Train 62 enters signalling block 3 at 13:31:08
# Train 63 enters signalling block 2 at 13:31:08
# Train 64 enters signalling block 1 at 13:31:08
# Train 65 leaves London Old Oak  common at 13:31:08
# Train 61 is at Block number5 Block 13:35:38
# Train 65 arrives in Block0  at 13:36:08
# Train 65 leaves Block0 at 13:36:08
# Train 61 arrives in Birmingham  Interchange at 13:40:08
# Train 63 reaches end of signalling block 2 at 13:43:19
# Train 64 reaches end of signalling block 1 at 13:43:22
# Train 62 arrives in Block4 at 13:43:42
# Train 62 leaves Block4 at 13:43:42
# Train 63 enters signalling block 3 at 13:43:42
# Train 64 enters signalling block 2 at 13:43:42
# Train 65 enters signalling block 1 at 13:43:42
# Train 66 leaves London Old Oak  common at 13:43:42
# Train 62 is at Block number5 Block 13:48:12
# Train 66 arrives in Block0  at 13:48:42
# Train 66 leaves Block0 at 13:48:42
# Train 62 arrives in Birmingham  Interchange at 13:52:42
# Train 63 arrives in Block4 at 13:55:30
# Train 63 leaves Block4 at 13:55:30
# Train 65 reaches end of signalling block 1 at 13:56:02
# Train 64 reaches end of signalling block 2 at 13:56:58
# Train 64 enters signalling block 3 at 13:56:58
# Train 65 enters signalling block 2 at 13:56:58
# Train 66 enters signalling block 1 at 13:56:58
# Train 67 leaves London Old Oak  common at 13:56:58
# Train 63 is at Block number5 Block 14:00:00
# Train 67 arrives in Block0  at 14:01:58
# Train 67 leaves Block0 at 14:01:58
# Train 63 arrives in Birmingham  Interchange at 14:04:30
# Train 66 reaches end of signalling block 1 at 14:09:39
# Train 65 reaches end of signalling block 2 at 14:10:11
# Train 64 arrives in Block4 at 14:11:08
# Train 64 leaves Block4 at 14:11:08
# Train 65 enters signalling block 3 at 14:11:08
# Train 66 enters signalling block 2 at 14:11:08
# Train 67 enters signalling block 1 at 14:11:08
# Train 68 leaves London Old Oak  common at 14:11:08
# Train 64 is at Block number5 Block 14:15:38
# Train 68 arrives in Block0  at 14:16:08
# Train 68 leaves Block0 at 14:16:08
# Train 64 arrives in Birmingham  Interchange at 14:20:08
# Train 65 arrives in Block4 at 14:21:06
# Train 65 leaves Block4 at 14:21:06
# Train 67 reaches end of signalling block 1 at 14:23:32
# Train 66 reaches end of signalling block 2 at 14:23:45
# Train 66 enters signalling block 3 at 14:23:45
# Train 67 enters signalling block 2 at 14:23:45
# Train 68 enters signalling block 1 at 14:23:45
# Train 69 leaves London Old Oak  common at 14:23:45
# Train 65 is at Block number5 Block 14:25:36
# Train 69 arrives in Block0  at 14:28:45
# Train 69 leaves Block0 at 14:28:45
# Train 65 arrives in Birmingham  Interchange at 14:30:06
# Train 68 reaches end of signalling block 1 at 14:35:10
# Train 66 arrives in Block4 at 14:36:36
# Train 66 leaves Block4 at 14:36:36
# Train 67 reaches end of signalling block 2 at 14:36:53
# Train 67 enters signalling block 3 at 14:36:53
# Train 68 enters signalling block 2 at 14:36:53
# Train 69 enters signalling block 1 at 14:36:53
# Train 70 leaves London Old Oak  common at 14:36:53
# Train 66 is at Block number5 Block 14:41:06
# Train 70 arrives in Block0  at 14:41:53
# Train 70 leaves Block0 at 14:41:53
# Train 66 arrives in Birmingham  Interchange at 14:45:36
# Train 68 reaches end of signalling block 2 at 14:48:06
# Train 67 arrives in Block4 at 14:49:45
# Train 67 leaves Block4 at 14:49:45
# Train 68 enters signalling block 3 at 14:49:45
# Train 69 reaches end of signalling block 1 at 14:51:06
# Train 69 enters signalling block 2 at 14:51:06
# Train 70 enters signalling block 1 at 14:51:06
# Train 71 leaves London Old Oak  common at 14:51:06
# Train 67 is at Block number5 Block 14:54:15
# Train 71 arrives in Block0  at 14:56:06
# Train 71 leaves Block0 at 14:56:06
# Train 67 arrives in Birmingham  Interchange at 14:58:45
# Train 68 arrives in Block4 at 15:00:04
# Train 68 leaves Block4 at 15:00:04
# Train 69 reaches end of signalling block 2 at 15:00:54
# Train 69 enters signalling block 3 at 15:00:54
# Train 70 reaches end of signalling block 1 at 15:01:02
# Train 70 enters signalling block 2 at 15:01:02
# Train 71 enters signalling block 1 at 15:01:02
# Train 72 leaves London Old Oak  common at 15:01:02
# Train 68 is at Block number5 Block 15:04:34
# Train 72 arrives in Block0  at 15:06:02
# Train 72 leaves Block0 at 15:06:02
# Train 68 arrives in Birmingham  Interchange at 15:09:04
# Train 70 reaches end of signalling block 2 at 15:11:36
# Train 69 arrives in Block4 at 15:11:44
# Train 69 leaves Block4 at 15:11:44
# Train 70 enters signalling block 3 at 15:11:44
# Train 71 reaches end of signalling block 1 at 15:15:15
# Train 71 enters signalling block 2 at 15:15:15
# Train 72 enters signalling block 1 at 15:15:15
# Train 73 leaves London Old Oak  common at 15:15:15
# Train 69 is at Block number5 Block 15:16:14
# Train 73 arrives in Block0  at 15:20:15
# Train 73 leaves Block0 at 15:20:15
# Train 69 arrives in Birmingham  Interchange at 15:20:44
# Train 70 arrives in Block4 at 15:23:14
# Train 70 leaves Block4 at 15:23:14
# Train 71 reaches end of signalling block 2 at 15:25:33
# Train 71 enters signalling block 3 at 15:25:33
# Train 70 is at Block number5 Block 15:27:44
# Train 72 reaches end of signalling block 1 at 15:28:28
# Train 72 enters signalling block 2 at 15:28:28
# Train 73 enters signalling block 1 at 15:28:28
# Train 74 leaves London Old Oak  common at 15:28:28
# Train 70 arrives in Birmingham  Interchange at 15:32:14
# Train 74 arrives in Block0  at 15:33:28
# Train 74 leaves Block0 at 15:33:28
# Train 71 arrives in Block4 at 15:36:45
# Train 71 leaves Block4 at 15:36:45
# Train 72 reaches end of signalling block 2 at 15:38:54
# Train 72 enters signalling block 3 at 15:38:54
# Train 71 is at Block number5 Block 15:41:15
# Train 73 reaches end of signalling block 1 at 15:41:24
# Train 73 enters signalling block 2 at 15:41:24
# Train 74 enters signalling block 1 at 15:41:24
# Train 75 leaves London Old Oak  common at 15:41:24
# Train 71 arrives in Birmingham  Interchange at 15:45:45
# Train 75 arrives in Block0  at 15:46:24
# Train 75 leaves Block0 at 15:46:24
# Train 72 arrives in Block4 at 15:51:32
# Train 72 leaves Block4 at 15:51:32
# Train 73 reaches end of signalling block 2 at 15:52:47
# Train 73 enters signalling block 3 at 15:52:47
# Train 74 reaches end of signalling block 1 at 15:54:59
# Train 74 enters signalling block 2 at 15:54:59
# Train 75 enters signalling block 1 at 15:54:59
# Train 76 leaves London Old Oak  common at 15:54:59
# Train 72 is at Block number5 Block 15:56:02
# Train 76 arrives in Block0  at 15:59:59
# Train 76 leaves Block0 at 15:59:59
# Train 72 arrives in Birmingham  Interchange at 16:00:32
# Train 73 arrives in Block4 at 16:04:50
# Train 73 leaves Block4 at 16:04:50
# Train 75 reaches end of signalling block 1 at 16:07:28
# Train 74 reaches end of signalling block 2 at 16:08:48
# Train 74 enters signalling block 3 at 16:08:48
# Train 75 enters signalling block 2 at 16:08:48
# Train 76 enters signalling block 1 at 16:08:48
# Train 77 leaves London Old Oak  common at 16:08:48
# Train 73 is at Block number5 Block 16:09:20
# Train 77 arrives in Block0  at 16:13:48
# Train 77 leaves Block0 at 16:13:48
# Train 73 arrives in Birmingham  Interchange at 16:13:50
# Train 76 reaches end of signalling block 1 at 16:19:14
# Train 75 reaches end of signalling block 2 at 16:20:49
# Train 74 arrives in Block4 at 16:22:33
# Train 74 leaves Block4 at 16:22:33
# Train 75 enters signalling block 3 at 16:22:33
# Train 76 enters signalling block 2 at 16:22:33
# Train 77 enters signalling block 1 at 16:22:33
# Train 78 leaves London Old Oak  common at 16:22:33
# Train 74 is at Block number5 Block 16:27:03
# Train 78 arrives in Block0  at 16:27:33
# Train 78 leaves Block0 at 16:27:33
# Train 74 arrives in Birmingham  Interchange at 16:31:33
# Train 76 reaches end of signalling block 2 at 16:33:47
# Train 77 reaches end of signalling block 1 at 16:34:12
# Train 75 arrives in Block4 at 16:37:21
# Train 75 leaves Block4 at 16:37:21
# Train 76 enters signalling block 3 at 16:37:21
# Train 77 enters signalling block 2 at 16:37:21
# Train 78 enters signalling block 1 at 16:37:21
# Train 79 leaves London Old Oak  common at 16:37:21
# Train 75 is at Block number5 Block 16:41:51
# Train 79 arrives in Block0  at 16:42:21
# Train 79 leaves Block0 at 16:42:21
# Train 75 arrives in Birmingham  Interchange at 16:46:21
# Train 76 arrives in Block4 at 16:48:25
# Train 76 leaves Block4 at 16:48:25
# Train 77 reaches end of signalling block 2 at 16:49:00
# Train 77 enters signalling block 3 at 16:49:00
# Train 78 reaches end of signalling block 1 at 16:49:32
# Train 78 enters signalling block 2 at 16:49:32
# Train 79 enters signalling block 1 at 16:49:32
# Train 80 leaves London Old Oak  common at 16:49:32
# Train 76 is at Block number5 Block 16:52:55
# Train 80 arrives in Block0  at 16:54:32
# Train 80 leaves Block0 at 16:54:32
# Train 76 arrives in Birmingham  Interchange at 16:57:25
# Train 77 arrives in Block4 at 17:01:08
# Train 77 leaves Block4 at 17:01:08
# Train 78 reaches end of signalling block 2 at 17:02:13
# Train 78 enters signalling block 3 at 17:02:13
# Train 79 reaches end of signalling block 1 at 17:03:34
# Train 79 enters signalling block 2 at 17:03:34
# Train 80 enters signalling block 1 at 17:03:34
# Train 81 leaves London Old Oak  common at 17:03:34
# Train 77 is at Block number5 Block 17:05:38
# Train 81 arrives in Block0  at 17:08:34
# Train 81 leaves Block0 at 17:08:34
# Train 77 arrives in Birmingham  Interchange at 17:10:08
# Train 78 arrives in Block4 at 17:13:58
# Train 78 leaves Block4 at 17:13:58
# Train 79 reaches end of signalling block 2 at 17:13:59
# Train 79 enters signalling block 3 at 17:13:59
# Train 80 reaches end of signalling block 1 at 17:14:03
# Train 80 enters signalling block 2 at 17:14:03
# Train 81 enters signalling block 1 at 17:14:03
# Train 82 leaves London Old Oak  common at 17:14:03
# Train 78 is at Block number5 Block 17:18:28
# Train 82 arrives in Block0  at 17:19:03
# Train 82 leaves Block0 at 17:19:03
# Train 78 arrives in Birmingham  Interchange at 17:22:58
# Train 80 reaches end of signalling block 2 at 17:23:57
# Train 79 arrives in Block4 at 17:25:05
# Train 79 leaves Block4 at 17:25:05
# Train 80 enters signalling block 3 at 17:25:05
# Train 81 reaches end of signalling block 1 at 17:26:55
# Train 81 enters signalling block 2 at 17:26:55
# Train 82 enters signalling block 1 at 17:26:55
# Train 83 leaves London Old Oak  common at 17:26:55
# Train 79 is at Block number5 Block 17:29:35
# Train 83 arrives in Block0  at 17:31:55
# Train 83 leaves Block0 at 17:31:55
# Train 79 arrives in Birmingham  Interchange at 17:34:05
# Train 80 arrives in Block4 at 17:36:23
# Train 80 leaves Block4 at 17:36:23
# Train 81 reaches end of signalling block 2 at 17:38:27
# Train 81 enters signalling block 3 at 17:38:27
# Train 82 reaches end of signalling block 1 at 17:38:49
# Train 82 enters signalling block 2 at 17:38:49
# Train 83 enters signalling block 1 at 17:38:49
# Train 84 leaves London Old Oak  common at 17:38:49
# Train 80 is at Block number5 Block 17:40:53
# Train 84 arrives in Block0  at 17:43:49
# Train 84 leaves Block0 at 17:43:49
# Train 80 arrives in Birmingham  Interchange at 17:45:23
# Train 81 arrives in Block4 at 17:48:41
# Train 81 leaves Block4 at 17:48:41
# Train 82 reaches end of signalling block 2 at 17:49:41
# Train 82 enters signalling block 3 at 17:49:41
# Train 83 reaches end of signalling block 1 at 17:51:31
# Train 83 enters signalling block 2 at 17:51:31
# Train 84 enters signalling block 1 at 17:51:31
# Train 85 leaves London Old Oak  common at 17:51:31
# Train 81 is at Block number5 Block 17:53:11
# Train 85 arrives in Block0  at 17:56:31
# Train 85 leaves Block0 at 17:56:31
# Train 81 arrives in Birmingham  Interchange at 17:57:41
# Train 82 arrives in Block4 at 18:02:19
# Train 82 leaves Block4 at 18:02:19
# Train 83 reaches end of signalling block 2 at 18:02:53
# Train 83 enters signalling block 3 at 18:02:53
# Train 84 reaches end of signalling block 1 at 18:05:34
# Train 84 enters signalling block 2 at 18:05:34
# Train 85 enters signalling block 1 at 18:05:34
# Train 86 leaves London Old Oak  common at 18:05:34
# Train 82 is at Block number5 Block 18:06:49
# Train 86 arrives in Block0  at 18:10:34
# Train 86 leaves Block0 at 18:10:34
# Train 82 arrives in Birmingham  Interchange at 18:11:19
# Train 83 arrives in Block4 at 18:13:13
# Train 83 leaves Block4 at 18:13:13
# Train 84 reaches end of signalling block 2 at 18:17:03
# Train 84 enters signalling block 3 at 18:17:03
# Train 85 reaches end of signalling block 1 at 18:17:11
# Train 85 enters signalling block 2 at 18:17:11
# Train 86 enters signalling block 1 at 18:17:11
# Train 87 leaves London Old Oak  common at 18:17:11
# Train 83 is at Block number5 Block 18:17:43
# Train 87 arrives in Block0  at 18:22:11
# Train 87 leaves Block0 at 18:22:11
# Train 83 arrives in Birmingham  Interchange at 18:22:13
# Train 84 arrives in Block4 at 18:25:37
# Train 84 leaves Block4 at 18:25:37
# Train 86 reaches end of signalling block 1 at 18:29:31
# Train 84 is at Block number5 Block 18:30:07
# Train 85 reaches end of signalling block 2 at 18:31:23
# Train 85 enters signalling block 3 at 18:31:23
# Train 86 enters signalling block 2 at 18:31:23
# Train 87 enters signalling block 1 at 18:31:23
# Train 88 leaves London Old Oak  common at 18:31:23
# Train 84 arrives in Birmingham  Interchange at 18:34:37
# Train 88 arrives in Block0  at 18:36:23
# Train 88 leaves Block0 at 18:36:23
# Train 85 arrives in Block4 at 18:42:02
# Train 85 leaves Block4 at 18:42:02
# Train 87 reaches end of signalling block 1 at 18:43:58
# Train 86 reaches end of signalling block 2 at 18:45:43
# Train 86 enters signalling block 3 at 18:45:43
# Train 87 enters signalling block 2 at 18:45:43
# Train 88 enters signalling block 1 at 18:45:43
# Train 89 leaves London Old Oak  common at 18:45:43
# Train 85 is at Block number5 Block 18:46:32
# Train 89 arrives in Block0  at 18:50:43
# Train 89 leaves Block0 at 18:50:43
# Train 85 arrives in Birmingham  Interchange at 18:51:02
# Train 87 reaches end of signalling block 2 at 18:56:53
# Train 88 reaches end of signalling block 1 at 18:57:44
# Train 86 arrives in Block4 at 18:58:07
# Train 86 leaves Block4 at 18:58:07
# Train 87 enters signalling block 3 at 18:58:07
# Train 88 enters signalling block 2 at 18:58:07
# Train 89 enters signalling block 1 at 18:58:07
# Train 90 leaves London Old Oak  common at 18:58:07
# Train 86 is at Block number5 Block 19:02:37
# Train 90 arrives in Block0  at 19:03:07
# Train 90 leaves Block0 at 19:03:07
# Train 86 arrives in Birmingham  Interchange at 19:07:07
# Train 87 arrives in Block4 at 19:08:12
# Train 87 leaves Block4 at 19:08:12
# Train 89 reaches end of signalling block 1 at 19:09:34
# Train 88 reaches end of signalling block 2 at 19:10:57
# Train 88 enters signalling block 3 at 19:10:57
# Train 89 enters signalling block 2 at 19:10:57
# Train 90 enters signalling block 1 at 19:10:57
# Train 91 leaves London Old Oak  common at 19:10:57
# Train 87 is at Block number5 Block 19:12:42
# Train 91 arrives in Block0  at 19:15:57
# Train 91 leaves Block0 at 19:15:57
# Train 87 arrives in Birmingham  Interchange at 19:17:12
# Train 88 arrives in Block4 at 19:23:01
# Train 88 leaves Block4 at 19:23:01
# Train 90 reaches end of signalling block 1 at 19:23:11
# Train 89 reaches end of signalling block 2 at 19:24:17
# Train 89 enters signalling block 3 at 19:24:17
# Train 90 enters signalling block 2 at 19:24:17
# Train 91 enters signalling block 1 at 19:24:17
# Train 92 leaves London Old Oak  common at 19:24:17
# Train 88 is at Block number5 Block 19:27:31
# Train 92 arrives in Block0  at 19:29:17
# Train 92 leaves Block0 at 19:29:17
# Train 88 arrives in Birmingham  Interchange at 19:32:01
# Train 91 reaches end of signalling block 1 at 19:35:18
# Train 89 arrives in Block4 at 19:36:29
# Train 89 leaves Block4 at 19:36:29
# Train 90 reaches end of signalling block 2 at 19:36:30
# Train 90 enters signalling block 3 at 19:36:30
# Train 91 enters signalling block 2 at 19:36:30
# Train 92 enters signalling block 1 at 19:36:30
# Train 93 leaves London Old Oak  common at 19:36:30
# Train 89 is at Block number5 Block 19:40:59
# Train 93 arrives in Block0  at 19:41:30
# Train 93 leaves Block0 at 19:41:30
# Train 89 arrives in Birmingham  Interchange at 19:45:29
# Train 92 reaches end of signalling block 1 at 19:49:18
# Train 90 arrives in Block4 at 19:49:24
# Train 90 leaves Block4 at 19:49:24
# Train 91 reaches end of signalling block 2 at 19:50:14
# Train 91 enters signalling block 3 at 19:50:14
# Train 92 enters signalling block 2 at 19:50:14
# Train 93 enters signalling block 1 at 19:50:14
# Train 94 leaves London Old Oak  common at 19:50:14
# Train 90 is at Block number5 Block 19:53:54
# Train 94 arrives in Block0  at 19:55:14
# Train 94 leaves Block0 at 19:55:14
# Train 90 arrives in Birmingham  Interchange at 19:58:24
# Train 92 reaches end of signalling block 2 at 20:01:05
# Train 93 reaches end of signalling block 1 at 20:01:06
# Train 91 arrives in Block4 at 20:03:11
# Train 91 leaves Block4 at 20:03:11
# Train 92 enters signalling block 3 at 20:03:11
# Train 93 enters signalling block 2 at 20:03:11
# Train 94 enters signalling block 1 at 20:03:11
# Train 95 leaves London Old Oak  common at 20:03:11
# Train 91 is at Block number5 Block 20:07:41
# Train 95 arrives in Block0  at 20:08:11
# Train 95 leaves Block0 at 20:08:11
# Train 91 arrives in Birmingham  Interchange at 20:12:11
# Train 92 arrives in Block4 at 20:13:22
# Train 92 leaves Block4 at 20:13:22
# Train 94 reaches end of signalling block 1 at 20:14:46
# Train 93 reaches end of signalling block 2 at 20:16:32
# Train 93 enters signalling block 3 at 20:16:32
# Train 94 enters signalling block 2 at 20:16:32
# Train 95 enters signalling block 1 at 20:16:32
# Train 96 leaves London Old Oak  common at 20:16:32
# Train 92 is at Block number5 Block 20:17:52
# Train 96 arrives in Block0  at 20:21:32
# Train 96 leaves Block0 at 20:21:32
# Train 92 arrives in Birmingham  Interchange at 20:22:22
# Train 94 reaches end of signalling block 2 at 20:27:30
# Train 95 reaches end of signalling block 1 at 20:27:55
# Train 93 arrives in Block4 at 20:30:06
# Train 93 leaves Block4 at 20:30:06
# Train 94 enters signalling block 3 at 20:30:06
# Train 95 enters signalling block 2 at 20:30:06
# Train 96 enters signalling block 1 at 20:30:06
# Train 97 leaves London Old Oak  common at 20:30:06
# Train 93 is at Block number5 Block 20:34:36
# Train 97 arrives in Block0  at 20:35:06
# Train 97 leaves Block0 at 20:35:06
# Train 93 arrives in Birmingham  Interchange at 20:39:06
# Train 96 reaches end of signalling block 1 at 20:42:04
# Train 94 arrives in Block4 at 20:42:07
# Train 94 leaves Block4 at 20:42:07
# Train 95 reaches end of signalling block 2 at 20:43:05
# Train 95 enters signalling block 3 at 20:43:05
# Train 96 enters signalling block 2 at 20:43:05
# Train 97 enters signalling block 1 at 20:43:05
# Train 98 leaves London Old Oak  common at 20:43:05
# Train 94 is at Block number5 Block 20:46:37
# Train 98 arrives in Block0  at 20:48:05
# Train 98 leaves Block0 at 20:48:05
# Train 94 arrives in Birmingham  Interchange at 20:51:07
# Train 96 reaches end of signalling block 2 at 20:55:00
# Train 97 reaches end of signalling block 1 at 20:55:12
# Train 95 arrives in Block4 at 20:55:14
# Train 95 leaves Block4 at 20:55:14
# Train 96 enters signalling block 3 at 20:55:14
# Train 97 enters signalling block 2 at 20:55:14
# Train 98 enters signalling block 1 at 20:55:14
# Train 99 leaves London Old Oak  common at 20:55:14
# Train 95 is at Block number5 Block 20:59:44
# Train 99 arrives in Block0  at 21:00:14
# Train 99 leaves Block0 at 21:00:14
# Train 95 arrives in Birmingham  Interchange at 21:04:14
# Train 96 arrives in Block4 at 21:05:48
# Train 96 leaves Block4 at 21:05:48
# Train 98 reaches end of signalling block 1 at 21:06:55
# Train 97 reaches end of signalling block 2 at 21:07:14
# Train 97 enters signalling block 3 at 21:07:14
# Train 98 enters signalling block 2 at 21:07:14
# Train 99 enters signalling block 1 at 21:07:14
# Train 100 leaves London Old Oak  common at 21:07:14
# Train 96 is at Block number5 Block 21:10:18
# Train 100 arrives in Block0  at 21:12:14
# Train 100 leaves Block0 at 21:12:14
# Train 96 arrives in Birmingham  Interchange at 21:14:48
# Train 99 reaches end of signalling block 1 at 21:18:19
# Train 97 arrives in Block4 at 21:19:03
# Train 97 leaves Block4 at 21:19:03
# Train 98 reaches end of signalling block 2 at 21:19:42
# Train 98 enters signalling block 3 at 21:19:42
# Train 99 enters signalling block 2 at 21:19:42
# Train 100 enters signalling block 1 at 21:19:42
# Train 101 leaves London Old Oak  common at 21:19:42
# Train 97 is at Block number5 Block 21:23:33
# Train 101 arrives in Block0  at 21:24:42
# Train 101 leaves Block0 at 21:24:42
# Train 97 arrives in Birmingham  Interchange at 21:28:03
# Train 99 reaches end of signalling block 2 at 21:31:15
# Train 98 arrives in Block4 at 21:31:30
# Train 98 leaves Block4 at 21:31:30
# Train 99 enters signalling block 3 at 21:31:30
# Train 100 reaches end of signalling block 1 at 21:32:06
# Train 100 enters signalling block 2 at 21:32:06
# Train 101 enters signalling block 1 at 21:32:06
# Train 102 leaves London Old Oak  common at 21:32:06
# Train 98 is at Block number5 Block 21:36:00
# Train 102 arrives in Block0  at 21:37:06
# Train 102 leaves Block0 at 21:37:06
# Train 98 arrives in Birmingham  Interchange at 21:40:30
# Train 100 reaches end of signalling block 2 at 21:42:51
# Train 99 arrives in Block4 at 21:44:20
# Train 99 leaves Block4 at 21:44:20
# Train 100 enters signalling block 3 at 21:44:20
# Train 101 reaches end of signalling block 1 at 21:44:41
# Train 101 enters signalling block 2 at 21:44:41
# Train 102 enters signalling block 1 at 21:44:41
# Train 103 leaves London Old Oak  common at 21:44:41
# Train 99 is at Block number5 Block 21:48:50
# Train 103 arrives in Block0  at 21:49:41
# Train 103 leaves Block0 at 21:49:41
# Train 99 arrives in Birmingham  Interchange at 21:53:20
# Train 101 reaches end of signalling block 2 at 21:54:50
# Train 102 reaches end of signalling block 1 at 21:55:36
# Train 100 arrives in Block4 at 21:58:41
# Train 100 leaves Block4 at 21:58:41
# Train 101 enters signalling block 3 at 21:58:41
# Train 102 enters signalling block 2 at 21:58:41
# Train 103 enters signalling block 1 at 21:58:41
# Train 104 leaves London Old Oak  common at 21:58:41

# %%
Trains_PH = [3]
Sig_blocks = [5]

Sim_Data_2 = Full_Simulation(Trains_PH,Sig_blocks,1)
# Out:
# 0
# Train 1 leaves London Old Oak  common at 00:00:00
# Train 1 arrives in Block0  at 00:05:00
# Train 1 leaves Block0 at 00:05:00
# Train 1 enters signalling block 1 at 00:05:00
# Train 1 reaches end of signalling block 1 at 00:11:37
# Train 1 enters signalling block 2 at 00:11:37
# Train 1 reaches end of signalling block 2 at 00:16:53
# Train 1 enters signalling block 3 at 00:16:53
# Train 2 leaves London Old Oak  common at 00:20:00
# Train 1 reaches end of signalling block 3 at 00:22:55
# Train 1 enters signalling block 4 at 00:22:55
# Train 2 arrives in Block0  at 00:24:59
# Train 2 leaves Block0 at 00:24:59
# Train 2 enters signalling block 1 at 00:24:59
# Train 1 reaches end of signalling block 4 at 00:28:15
# Train 1 enters signalling block 5 at 00:28:15
# Train 2 reaches end of signalling block 1 at 00:32:21
# Train 2 enters signalling block 2 at 00:32:21
# Train 1 arrives in Block6 at 00:35:42
# Train 1 leaves Block6 at 00:35:42
# Train 2 reaches end of signalling block 2 at 00:38:48
# Train 2 enters signalling block 3 at 00:38:48
# Train 3 leaves London Old Oak  common at 00:40:00
# Train 1 is at Block number7 Block 00:40:12
# Train 2 reaches end of signalling block 3 at 00:44:06
# Train 2 enters signalling block 4 at 00:44:06
# Train 1 arrives in Birmingham  Interchange at 00:44:42
# Train 3 arrives in Block0  at 00:45:00
# Train 3 leaves Block0 at 00:45:00
# Train 3 enters signalling block 1 at 00:45:00
# Train 2 reaches end of signalling block 4 at 00:51:30
# Train 2 enters signalling block 5 at 00:51:30
# Train 3 reaches end of signalling block 1 at 00:52:09
# Train 3 enters signalling block 2 at 00:52:09
# Train 3 reaches end of signalling block 2 at 00:57:48
# Train 3 enters signalling block 3 at 00:57:48
# Train 2 arrives in Block6 at 00:59:12
# Train 2 leaves Block6 at 00:59:12
# Train 4 leaves London Old Oak  common at 01:00:00
# Train 3 reaches end of signalling block 3 at 01:03:03
# Train 3 enters signalling block 4 at 01:03:03
# Train 2 is at Block number7 Block 01:03:42
# Train 4 arrives in Block0  at 01:04:59
# Train 4 leaves Block0 at 01:04:59
# Train 4 enters signalling block 1 at 01:04:59
# Train 2 arrives in Birmingham  Interchange at 01:08:12
# Train 3 reaches end of signalling block 4 at 01:08:14
# Train 3 enters signalling block 5 at 01:08:14
# Train 4 reaches end of signalling block 1 at 01:11:31
# Train 4 enters signalling block 2 at 01:11:31
# Train 3 arrives in Block6 at 01:14:53
# Train 3 leaves Block6 at 01:14:53
# Train 4 reaches end of signalling block 2 at 01:17:21
# Train 4 enters signalling block 3 at 01:17:21
# Train 3 is at Block number7 Block 01:19:23
# Train 5 leaves London Old Oak  common at 01:20:00
# Train 4 reaches end of signalling block 3 at 01:22:33
# Train 4 enters signalling block 4 at 01:22:33
# Train 3 arrives in Birmingham  Interchange at 01:23:53
# Train 5 arrives in Block0  at 01:24:59
# Train 5 leaves Block0 at 01:24:59
# Train 5 enters signalling block 1 at 01:24:59
# Train 4 reaches end of signalling block 4 at 01:28:35
# Train 4 enters signalling block 5 at 01:28:35
# Train 5 reaches end of signalling block 1 at 01:32:14
# Train 5 enters signalling block 2 at 01:32:14
# Train 4 arrives in Block6 at 01:35:17
# Train 4 leaves Block6 at 01:35:17
# Train 5 reaches end of signalling block 2 at 01:38:35
# Train 5 enters signalling block 3 at 01:38:35
# Train 4 is at Block number7 Block 01:39:47
# Train 6 leaves London Old Oak  common at 01:39:59
# Train 5 reaches end of signalling block 3 at 01:44:08
# Train 5 enters signalling block 4 at 01:44:08
# Train 4 arrives in Birmingham  Interchange at 01:44:17
# Train 6 arrives in Block0  at 01:44:59
# Train 6 leaves Block0 at 01:44:59
# Train 6 enters signalling block 1 at 01:44:59
# Train 5 reaches end of signalling block 4 at 01:50:27
# Train 5 enters signalling block 5 at 01:50:27
# Train 6 reaches end of signalling block 1 at 01:51:53
# Train 6 enters signalling block 2 at 01:51:53
# Train 6 reaches end of signalling block 2 at 01:57:00
# Train 6 enters signalling block 3 at 01:57:00
# Train 5 arrives in Block6 at 01:58:29
# Train 5 leaves Block6 at 01:58:29
# Train 7 leaves London Old Oak  common at 01:59:59
# Train 6 reaches end of signalling block 3 at 02:02:37
# Train 6 enters signalling block 4 at 02:02:37
# Train 5 is at Block number7 Block 02:02:59
# Train 7 arrives in Block0  at 02:04:59
# Train 7 leaves Block0 at 02:04:59
# Train 7 enters signalling block 1 at 02:04:59
# Train 5 arrives in Birmingham  Interchange at 02:07:29
# Train 6 reaches end of signalling block 4 at 02:09:07
# Train 6 enters signalling block 5 at 02:09:07
# Train 7 reaches end of signalling block 1 at 02:11:12
# Train 7 enters signalling block 2 at 02:11:12
# Train 6 arrives in Block6 at 02:14:52
# Train 6 leaves Block6 at 02:14:52
# Train 7 reaches end of signalling block 2 at 02:15:46
# Train 7 enters signalling block 3 at 02:15:46
# Train 6 is at Block number7 Block 02:19:22
# Train 8 leaves London Old Oak  common at 02:19:59
# Train 7 reaches end of signalling block 3 at 02:20:01
# Train 7 enters signalling block 4 at 02:20:01
# Train 6 arrives in Birmingham  Interchange at 02:23:52
# Train 7 reaches end of signalling block 4 at 02:24:30
# Train 7 enters signalling block 5 at 02:24:30
# Train 8 arrives in Block0  at 02:25:00
# Train 8 leaves Block0 at 02:25:00
# Train 8 enters signalling block 1 at 02:25:00
# Train 7 arrives in Block6 at 02:31:25
# Train 7 leaves Block6 at 02:31:25
# Train 8 reaches end of signalling block 1 at 02:32:27
# Train 8 enters signalling block 2 at 02:32:27
# Train 7 is at Block number7 Block 02:35:55
# Train 8 reaches end of signalling block 2 at 02:37:52
# Train 8 enters signalling block 3 at 02:37:52
# Train 9 leaves London Old Oak  common at 02:40:00
# Train 7 arrives in Birmingham  Interchange at 02:40:25
# Train 8 reaches end of signalling block 3 at 02:43:44
# Train 8 enters signalling block 4 at 02:43:44
# Train 9 arrives in Block0  at 02:45:00
# Train 9 leaves Block0 at 02:45:00
# Train 9 enters signalling block 1 at 02:45:00
# Train 8 reaches end of signalling block 4 at 02:49:21
# Train 8 enters signalling block 5 at 02:49:21
# Train 9 reaches end of signalling block 1 at 02:51:36
# Train 9 enters signalling block 2 at 02:51:36
# Train 8 arrives in Block6 at 02:56:26
# Train 8 leaves Block6 at 02:56:26
# Train 9 reaches end of signalling block 2 at 02:57:11
# Train 9 enters signalling block 3 at 02:57:11
# Train 10 leaves London Old Oak  common at 03:00:00
# Train 8 is at Block number7 Block 03:00:56
# Train 9 reaches end of signalling block 3 at 03:03:07
# Train 9 enters signalling block 4 at 03:03:07
# Train 10 arrives in Block0  at 03:05:00
# Train 10 leaves Block0 at 03:05:00
# Train 10 enters signalling block 1 at 03:05:00
# Train 8 arrives in Birmingham  Interchange at 03:05:26
# Train 9 reaches end of signalling block 4 at 03:08:08
# Train 9 enters signalling block 5 at 03:08:08
# Train 10 reaches end of signalling block 1 at 03:12:16
# Train 10 enters signalling block 2 at 03:12:16
# Train 9 arrives in Block6 at 03:16:01
# Train 9 leaves Block6 at 03:16:01
# Train 10 reaches end of signalling block 2 at 03:17:50
# Train 10 enters signalling block 3 at 03:17:50
# Train 11 leaves London Old Oak  common at 03:20:00
# Train 9 is at Block number7 Block 03:20:31
# Train 10 reaches end of signalling block 3 at 03:23:58
# Train 10 enters signalling block 4 at 03:23:58
# Train 11 arrives in Block0  at 03:25:00
# Train 11 leaves Block0 at 03:25:00
# Train 11 enters signalling block 1 at 03:25:00
# Train 9 arrives in Birmingham  Interchange at 03:25:01
# Train 10 reaches end of signalling block 4 at 03:29:15
# Train 10 enters signalling block 5 at 03:29:15
# Train 11 reaches end of signalling block 1 at 03:31:15
# Train 11 enters signalling block 2 at 03:31:15
# Train 10 arrives in Block6 at 03:36:35
# Train 10 leaves Block6 at 03:36:35
# Train 11 reaches end of signalling block 2 at 03:36:49
# Train 11 enters signalling block 3 at 03:36:49
# Train 12 leaves London Old Oak  common at 03:40:00
# Train 10 is at Block number7 Block 03:41:05
# Train 11 reaches end of signalling block 3 at 03:42:14
# Train 11 enters signalling block 4 at 03:42:14
# Train 12 arrives in Block0  at 03:45:00
# Train 12 leaves Block0 at 03:45:00
# Train 12 enters signalling block 1 at 03:45:00
# Train 10 arrives in Birmingham  Interchange at 03:45:35
# Train 11 reaches end of signalling block 4 at 03:47:32
# Train 11 enters signalling block 5 at 03:47:32
# Train 12 reaches end of signalling block 1 at 03:51:14
# Train 12 enters signalling block 2 at 03:51:14
# Train 11 arrives in Block6 at 03:55:25
# Train 11 leaves Block6 at 03:55:25
# Train 12 reaches end of signalling block 2 at 03:55:48
# Train 12 enters signalling block 3 at 03:55:48
# Train 11 is at Block number7 Block 03:59:55
# Train 13 leaves London Old Oak  common at 04:00:00
# Train 12 reaches end of signalling block 3 at 04:01:41
# Train 12 enters signalling block 4 at 04:01:41
# Train 11 arrives in Birmingham  Interchange at 04:04:25
# Train 13 arrives in Block0  at 04:04:59
# Train 13 leaves Block0 at 04:04:59
# Train 13 enters signalling block 1 at 04:04:59
# Train 12 reaches end of signalling block 4 at 04:07:13
# Train 12 enters signalling block 5 at 04:07:13
# Train 13 reaches end of signalling block 1 at 04:12:05
# Train 13 enters signalling block 2 at 04:12:05
# Train 12 arrives in Block6 at 04:14:49
# Train 12 leaves Block6 at 04:14:49
# Train 13 reaches end of signalling block 2 at 04:16:11
# Train 13 enters signalling block 3 at 04:16:11
# Train 12 is at Block number7 Block 04:19:19
# Train 14 leaves London Old Oak  common at 04:19:59
# Train 13 reaches end of signalling block 3 at 04:22:11
# Train 13 enters signalling block 4 at 04:22:11
# Train 12 arrives in Birmingham  Interchange at 04:23:49
# Train 14 arrives in Block0  at 04:24:59
# Train 14 leaves Block0 at 04:24:59
# Train 14 enters signalling block 1 at 04:24:59
# Train 13 reaches end of signalling block 4 at 04:28:03
# Train 13 enters signalling block 5 at 04:28:03
# Train 14 reaches end of signalling block 1 at 04:31:37
# Train 14 enters signalling block 2 at 04:31:37
# Train 13 arrives in Block6 at 04:34:56
# Train 13 leaves Block6 at 04:34:56
# Train 14 reaches end of signalling block 2 at 04:37:47
# Train 14 enters signalling block 3 at 04:37:47
# Train 13 is at Block number7 Block 04:39:26
# Train 15 leaves London Old Oak  common at 04:39:59
# Train 14 reaches end of signalling block 3 at 04:43:13
# Train 14 enters signalling block 4 at 04:43:13
# Train 13 arrives in Birmingham  Interchange at 04:43:56
# Train 15 arrives in Block0  at 04:44:59
# Train 15 leaves Block0 at 04:44:59
# Train 15 enters signalling block 1 at 04:44:59
# Train 14 reaches end of signalling block 4 at 04:49:56
# Train 14 enters signalling block 5 at 04:49:56
# Train 15 reaches end of signalling block 1 at 04:51:58
# Train 15 enters signalling block 2 at 04:51:58
# Train 15 reaches end of signalling block 2 at 04:57:12
# Train 15 enters signalling block 3 at 04:57:12
# Train 14 arrives in Block6 at 04:58:42
# Train 14 leaves Block6 at 04:58:42
# Train 16 leaves London Old Oak  common at 04:59:59
# Train 15 reaches end of signalling block 3 at 05:01:53
# Train 15 enters signalling block 4 at 05:01:53
# Train 14 is at Block number7 Block 05:03:12
# Train 16 arrives in Block0  at 05:04:59
# Train 16 leaves Block0 at 05:04:59
# Train 16 enters signalling block 1 at 05:04:59
# Train 14 arrives in Birmingham  Interchange at 05:07:42
# Train 15 reaches end of signalling block 4 at 05:07:58
# Train 15 enters signalling block 5 at 05:07:58
# Train 16 reaches end of signalling block 1 at 05:12:10
# Train 16 enters signalling block 2 at 05:12:10
# Train 15 arrives in Block6 at 05:15:12
# Train 15 leaves Block6 at 05:15:12
# Train 16 reaches end of signalling block 2 at 05:16:58
# Train 16 enters signalling block 3 at 05:16:58
# Train 15 is at Block number7 Block 05:19:42
# Train 17 leaves London Old Oak  common at 05:19:59
# Train 16 reaches end of signalling block 3 at 05:22:23
# Train 16 enters signalling block 4 at 05:22:23
# Train 15 arrives in Birmingham  Interchange at 05:24:12
# Train 17 arrives in Block0  at 05:24:59
# Train 17 leaves Block0 at 05:24:59
# Train 17 enters signalling block 1 at 05:24:59
# Train 16 reaches end of signalling block 4 at 05:28:25
# Train 16 enters signalling block 5 at 05:28:25
# Train 17 reaches end of signalling block 1 at 05:31:29
# Train 17 enters signalling block 2 at 05:31:29
# Train 16 arrives in Block6 at 05:35:33
# Train 16 leaves Block6 at 05:35:33
# Train 17 reaches end of signalling block 2 at 05:37:03
# Train 17 enters signalling block 3 at 05:37:03
# Train 18 leaves London Old Oak  common at 05:39:59
# Train 16 is at Block number7 Block 05:40:03
# Train 17 reaches end of signalling block 3 at 05:42:12
# Train 17 enters signalling block 4 at 05:42:12
# Train 16 arrives in Birmingham  Interchange at 05:44:33
# Train 18 arrives in Block0  at 05:44:59
# Train 18 leaves Block0 at 05:44:59
# Train 18 enters signalling block 1 at 05:44:59
# Train 17 reaches end of signalling block 4 at 05:47:34
# Train 17 enters signalling block 5 at 05:47:34
# Train 18 reaches end of signalling block 1 at 05:50:40
# Train 18 enters signalling block 2 at 05:50:40
# Train 18 reaches end of signalling block 2 at 05:56:04
# Train 18 enters signalling block 3 at 05:56:04
# Train 17 arrives in Block6 at 05:56:04
# Train 17 leaves Block6 at 05:56:04
# Train 19 leaves London Old Oak  common at 05:59:59
# Train 17 is at Block number7 Block 06:00:34
# Train 18 reaches end of signalling block 3 at 06:02:01
# Train 18 enters signalling block 4 at 06:02:01
# Train 19 arrives in Block0  at 06:04:59
# Train 19 leaves Block0 at 06:04:59
# Train 19 enters signalling block 1 at 06:04:59
# Train 17 arrives in Birmingham  Interchange at 06:05:04
# Train 18 reaches end of signalling block 4 at 06:07:06
# Train 18 enters signalling block 5 at 06:07:06
# Train 19 reaches end of signalling block 1 at 06:12:08
# Train 19 enters signalling block 2 at 06:12:08
# Train 18 arrives in Block6 at 06:12:58
# Train 18 leaves Block6 at 06:12:58
# Train 18 is at Block number7 Block 06:17:28
# Train 19 reaches end of signalling block 2 at 06:18:19
# Train 19 enters signalling block 3 at 06:18:19
# Train 20 leaves London Old Oak  common at 06:19:59
# Train 18 arrives in Birmingham  Interchange at 06:21:58
# Train 19 reaches end of signalling block 3 at 06:23:59
# Train 19 enters signalling block 4 at 06:23:59
# Train 20 arrives in Block0  at 06:24:59
# Train 20 leaves Block0 at 06:24:59
# Train 20 enters signalling block 1 at 06:24:59
# Train 20 reaches end of signalling block 1 at 06:30:44
# Train 20 enters signalling block 2 at 06:30:44
# Train 19 reaches end of signalling block 4 at 06:30:51
# Train 19 enters signalling block 5 at 06:30:51
# Train 20 reaches end of signalling block 2 at 06:36:27
# Train 20 enters signalling block 3 at 06:36:27
# Train 19 arrives in Block6 at 06:38:20
# Train 19 leaves Block6 at 06:38:20
# Train 21 leaves London Old Oak  common at 06:39:59
# Train 20 reaches end of signalling block 3 at 06:42:50
# Train 20 enters signalling block 4 at 06:42:50
# Train 19 is at Block number7 Block 06:42:50
# Train 21 arrives in Block0  at 06:44:59
# Train 21 leaves Block0 at 06:44:59
# Train 21 enters signalling block 1 at 06:44:59
# Train 19 arrives in Birmingham  Interchange at 06:47:20
# Train 20 reaches end of signalling block 4 at 06:48:16
# Train 20 enters signalling block 5 at 06:48:16
# Train 21 reaches end of signalling block 1 at 06:51:40
# Train 21 enters signalling block 2 at 06:51:40
# Train 20 arrives in Block6 at 06:53:56
# Train 20 leaves Block6 at 06:53:56
# Train 21 reaches end of signalling block 2 at 06:56:52
# Train 21 enters signalling block 3 at 06:56:52
# Train 20 is at Block number7 Block 06:58:26
# Train 22 leaves London Old Oak  common at 06:59:59
# Train 21 reaches end of signalling block 3 at 07:02:48
# Train 21 enters signalling block 4 at 07:02:48
# Train 20 arrives in Birmingham  Interchange at 07:02:56
# Train 22 arrives in Block0  at 07:04:59
# Train 22 leaves Block0 at 07:04:59
# Train 22 enters signalling block 1 at 07:04:59
# Train 21 reaches end of signalling block 4 at 07:09:06
# Train 21 enters signalling block 5 at 07:09:06
# Train 22 reaches end of signalling block 1 at 07:11:25
# Train 22 enters signalling block 2 at 07:11:25
# Train 21 arrives in Block6 at 07:17:48
# Train 21 leaves Block6 at 07:17:48
# Train 22 reaches end of signalling block 2 at 07:18:05
# Train 22 enters signalling block 3 at 07:18:05
# Train 23 leaves London Old Oak  common at 07:19:59
# Train 21 is at Block number7 Block 07:22:18
# Train 22 reaches end of signalling block 3 at 07:23:44
# Train 22 enters signalling block 4 at 07:23:44
# Train 23 arrives in Block0  at 07:24:59
# Train 23 leaves Block0 at 07:24:59
# Train 23 enters signalling block 1 at 07:24:59
# Train 21 arrives in Birmingham  Interchange at 07:26:48
# Train 22 reaches end of signalling block 4 at 07:28:02
# Train 22 enters signalling block 5 at 07:28:02
# Train 23 reaches end of signalling block 1 at 07:30:26
# Train 23 enters signalling block 2 at 07:30:26
# Train 22 arrives in Block6 at 07:34:42
# Train 22 leaves Block6 at 07:34:42
# Train 23 reaches end of signalling block 2 at 07:36:44
# Train 23 enters signalling block 3 at 07:36:44
# Train 22 is at Block number7 Block 07:39:12
# Train 24 leaves London Old Oak  common at 07:39:59
# Train 23 reaches end of signalling block 3 at 07:42:35
# Train 23 enters signalling block 4 at 07:42:35
# Train 22 arrives in Birmingham  Interchange at 07:43:42
# Train 24 arrives in Block0  at 07:44:59
# Train 24 leaves Block0 at 07:44:59
# Train 24 enters signalling block 1 at 07:44:59
# Train 23 reaches end of signalling block 4 at 07:47:04
# Train 23 enters signalling block 5 at 07:47:04
# Train 24 reaches end of signalling block 1 at 07:51:27
# Train 24 enters signalling block 2 at 07:51:27
# Train 23 arrives in Block6 at 07:55:27
# Train 23 leaves Block6 at 07:55:27
# Train 24 reaches end of signalling block 2 at 07:56:55
# Train 24 enters signalling block 3 at 07:56:55
# Train 23 is at Block number7 Block 07:59:57
# Train 25 leaves London Old Oak  common at 07:59:59
# Train 24 reaches end of signalling block 3 at 08:02:10
# Train 24 enters signalling block 4 at 08:02:10
# Train 23 arrives in Birmingham  Interchange at 08:04:27
# Train 25 arrives in Block0  at 08:04:59
# Train 25 leaves Block0 at 08:04:59
# Train 25 enters signalling block 1 at 08:04:59
# Train 24 reaches end of signalling block 4 at 08:09:00
# Train 24 enters signalling block 5 at 08:09:00
# Train 25 reaches end of signalling block 1 at 08:11:38
# Train 25 enters signalling block 2 at 08:11:38
# Train 24 arrives in Block6 at 08:15:53
# Train 24 leaves Block6 at 08:15:53
# Train 25 reaches end of signalling block 2 at 08:17:31
# Train 25 enters signalling block 3 at 08:17:31
# Train 26 leaves London Old Oak  common at 08:19:59
# Train 24 is at Block number7 Block 08:20:23
# Train 25 reaches end of signalling block 3 at 08:23:12
# Train 25 enters signalling block 4 at 08:23:12
# Train 24 arrives in Birmingham  Interchange at 08:24:53
# Train 26 arrives in Block0  at 08:24:59
# Train 26 leaves Block0 at 08:24:59
# Train 26 enters signalling block 1 at 08:24:59
# Train 25 reaches end of signalling block 4 at 08:28:38
# Train 25 enters signalling block 5 at 08:28:38
# Train 26 reaches end of signalling block 1 at 08:32:24
# Train 26 enters signalling block 2 at 08:32:24
# Train 25 arrives in Block6 at 08:36:39
# Train 25 leaves Block6 at 08:36:39
# Train 26 reaches end of signalling block 2 at 08:38:33
# Train 26 enters signalling block 3 at 08:38:33
# Train 27 leaves London Old Oak  common at 08:39:59
# Train 25 is at Block number7 Block 08:41:09
# Train 26 reaches end of signalling block 3 at 08:44:10
# Train 26 enters signalling block 4 at 08:44:10
# Train 27 arrives in Block0  at 08:44:59
# Train 27 leaves Block0 at 08:44:59
# Train 27 enters signalling block 1 at 08:44:59
# Train 25 arrives in Birmingham  Interchange at 08:45:39
# Train 26 reaches end of signalling block 4 at 08:50:30
# Train 26 enters signalling block 5 at 08:50:30
# Train 27 reaches end of signalling block 1 at 08:51:34
# Train 27 enters signalling block 2 at 08:51:34
# Train 27 reaches end of signalling block 2 at 08:57:50
# Train 27 enters signalling block 3 at 08:57:50
# Train 26 arrives in Block6 at 08:58:03
# Train 26 leaves Block6 at 08:58:03
# Train 28 leaves London Old Oak  common at 08:59:59
# Train 26 is at Block number7 Block 09:02:33
# Train 27 reaches end of signalling block 3 at 09:03:58
# Train 27 enters signalling block 4 at 09:03:58
# Train 28 arrives in Block0  at 09:04:59
# Train 28 leaves Block0 at 09:04:59
# Train 28 enters signalling block 1 at 09:04:59
# Train 26 arrives in Birmingham  Interchange at 09:07:03
# Train 27 reaches end of signalling block 4 at 09:10:39
# Train 27 enters signalling block 5 at 09:10:39
# Train 28 reaches end of signalling block 1 at 09:11:54
# Train 28 enters signalling block 2 at 09:11:54
# Train 27 arrives in Block6 at 09:16:40
# Train 27 leaves Block6 at 09:16:40
# Train 28 reaches end of signalling block 2 at 09:16:55
# Train 28 enters signalling block 3 at 09:16:55
# Train 29 leaves London Old Oak  common at 09:19:59
# Train 27 is at Block number7 Block 09:21:10
# Train 28 reaches end of signalling block 3 at 09:23:22
# Train 28 enters signalling block 4 at 09:23:22
# Train 29 arrives in Block0  at 09:25:00
# Train 29 leaves Block0 at 09:25:00
# Train 29 enters signalling block 1 at 09:25:00
# Train 27 arrives in Birmingham  Interchange at 09:25:40
# Train 28 reaches end of signalling block 4 at 09:28:51
# Train 28 enters signalling block 5 at 09:28:51
# Train 29 reaches end of signalling block 1 at 09:31:51
# Train 29 enters signalling block 2 at 09:31:51
# Train 28 arrives in Block6 at 09:35:27
# Train 28 leaves Block6 at 09:35:27
# Train 29 reaches end of signalling block 2 at 09:38:06
# Train 29 enters signalling block 3 at 09:38:06
# Train 28 is at Block number7 Block 09:39:57
# Train 30 leaves London Old Oak  common at 09:40:00
# Train 29 reaches end of signalling block 3 at 09:43:33
# Train 29 enters signalling block 4 at 09:43:33
# Train 28 arrives in Birmingham  Interchange at 09:44:27
# Train 30 arrives in Block0  at 09:45:00
# Train 30 leaves Block0 at 09:45:00
# Train 30 enters signalling block 1 at 09:45:00
# Train 29 reaches end of signalling block 4 at 09:50:04
# Train 29 enters signalling block 5 at 09:50:04
# Train 30 reaches end of signalling block 1 at 09:51:15
# Train 30 enters signalling block 2 at 09:51:15
# Train 30 reaches end of signalling block 2 at 09:57:18
# Train 30 enters signalling block 3 at 09:57:18
# Train 29 arrives in Block6 at 09:58:05
# Train 29 leaves Block6 at 09:58:05
# Train 31 leaves London Old Oak  common at 10:00:00
# Train 30 reaches end of signalling block 3 at 10:02:34
# Train 30 enters signalling block 4 at 10:02:34
# Train 29 is at Block number7 Block 10:02:35
# Train 31 arrives in Block0  at 10:05:00
# Train 31 leaves Block0 at 10:05:00
# Train 31 enters signalling block 1 at 10:05:00
# Train 29 arrives in Birmingham  Interchange at 10:07:05
# Train 30 reaches end of signalling block 4 at 10:08:52
# Train 30 enters signalling block 5 at 10:08:52
# Train 31 reaches end of signalling block 1 at 10:11:00
# Train 31 enters signalling block 2 at 10:11:00
# Train 30 arrives in Block6 at 10:15:30
# Train 30 leaves Block6 at 10:15:30
# Train 31 reaches end of signalling block 2 at 10:17:05
# Train 31 enters signalling block 3 at 10:17:05
# Train 32 leaves London Old Oak  common at 10:20:00
# Train 30 is at Block number7 Block 10:20:00
# Train 31 reaches end of signalling block 3 at 10:22:25
# Train 31 enters signalling block 4 at 10:22:25
# Train 30 arrives in Birmingham  Interchange at 10:24:30
# Train 32 arrives in Block0  at 10:25:00
# Train 32 leaves Block0 at 10:25:00
# Train 32 enters signalling block 1 at 10:25:00
# Train 31 reaches end of signalling block 4 at 10:27:45
# Train 31 enters signalling block 5 at 10:27:45
# Train 32 reaches end of signalling block 1 at 10:31:22
# Train 32 enters signalling block 2 at 10:31:22
# Train 31 arrives in Block6 at 10:34:15
# Train 31 leaves Block6 at 10:34:15
# Train 32 reaches end of signalling block 2 at 10:37:39
# Train 32 enters signalling block 3 at 10:37:39
# Train 31 is at Block number7 Block 10:38:45
# Train 33 leaves London Old Oak  common at 10:40:00
# Train 31 arrives in Birmingham  Interchange at 10:43:15
# Train 32 reaches end of signalling block 3 at 10:43:40
# Train 32 enters signalling block 4 at 10:43:40
# Train 33 arrives in Block0  at 10:45:00
# Train 33 leaves Block0 at 10:45:00
# Train 33 enters signalling block 1 at 10:45:00
# Train 32 reaches end of signalling block 4 at 10:49:18
# Train 32 enters signalling block 5 at 10:49:18
# Train 33 reaches end of signalling block 1 at 10:51:32
# Train 33 enters signalling block 2 at 10:51:32
# Train 32 arrives in Block6 at 10:56:51
# Train 32 leaves Block6 at 10:56:51
# Train 33 reaches end of signalling block 2 at 10:58:12
# Train 33 enters signalling block 3 at 10:58:12
# Train 34 leaves London Old Oak  common at 11:00:00
# Train 32 is at Block number7 Block 11:01:21
# Train 33 reaches end of signalling block 3 at 11:04:23
# Train 33 enters signalling block 4 at 11:04:23
# Train 34 arrives in Block0  at 11:05:00
# Train 34 leaves Block0 at 11:05:00
# Train 34 enters signalling block 1 at 11:05:00
# Train 32 arrives in Birmingham  Interchange at 11:05:51
# Train 33 reaches end of signalling block 4 at 11:09:46
# Train 33 enters signalling block 5 at 11:09:46
# Train 34 reaches end of signalling block 1 at 11:12:07
# Train 34 enters signalling block 2 at 11:12:07
# Train 33 arrives in Block6 at 11:16:54
# Train 33 leaves Block6 at 11:16:54
# Train 34 reaches end of signalling block 2 at 11:17:41
# Train 34 enters signalling block 3 at 11:17:41
# Train 35 leaves London Old Oak  common at 11:20:00
# Train 33 is at Block number7 Block 11:21:24
# Train 34 reaches end of signalling block 3 at 11:24:25
# Train 34 enters signalling block 4 at 11:24:25
# Train 35 arrives in Block0  at 11:25:00
# Train 35 leaves Block0 at 11:25:00
# Train 35 enters signalling block 1 at 11:25:00
# Train 33 arrives in Birmingham  Interchange at 11:25:54
# Train 34 reaches end of signalling block 4 at 11:29:51
# Train 34 enters signalling block 5 at 11:29:51
# Train 35 reaches end of signalling block 1 at 11:31:17
# Train 35 enters signalling block 2 at 11:31:17
# Train 34 arrives in Block6 at 11:35:40
# Train 34 leaves Block6 at 11:35:40
# Train 35 reaches end of signalling block 2 at 11:36:10
# Train 35 enters signalling block 3 at 11:36:10
# Train 36 leaves London Old Oak  common at 11:40:00
# Train 34 is at Block number7 Block 11:40:10
# Train 35 reaches end of signalling block 3 at 11:42:06
# Train 35 enters signalling block 4 at 11:42:06
# Train 34 arrives in Birmingham  Interchange at 11:44:40
# Train 36 arrives in Block0  at 11:45:00
# Train 36 leaves Block0 at 11:45:00
# Train 36 enters signalling block 1 at 11:45:00
# Train 35 reaches end of signalling block 4 at 11:47:23
# Train 35 enters signalling block 5 at 11:47:23
# Train 36 reaches end of signalling block 1 at 11:51:57
# Train 36 enters signalling block 2 at 11:51:57
# Train 35 arrives in Block6 at 11:53:47
# Train 35 leaves Block6 at 11:53:47
# Train 36 reaches end of signalling block 2 at 11:57:11
# Train 36 enters signalling block 3 at 11:57:11
# Train 35 is at Block number7 Block 11:58:17
# Train 37 leaves London Old Oak  common at 12:00:00
# Train 35 arrives in Birmingham  Interchange at 12:02:47
# Train 36 reaches end of signalling block 3 at 12:03:14
# Train 36 enters signalling block 4 at 12:03:14
# Train 37 arrives in Block0  at 12:05:00
# Train 37 leaves Block0 at 12:05:00
# Train 37 enters signalling block 1 at 12:05:00
# Train 36 reaches end of signalling block 4 at 12:09:45
# Train 36 enters signalling block 5 at 12:09:45
# Train 37 reaches end of signalling block 1 at 12:12:00
# Train 37 enters signalling block 2 at 12:12:00
# Train 36 arrives in Block6 at 12:17:50
# Train 36 leaves Block6 at 12:17:50
# Train 37 reaches end of signalling block 2 at 12:18:38
# Train 37 enters signalling block 3 at 12:18:38
# Train 38 leaves London Old Oak  common at 12:20:00
# Train 36 is at Block number7 Block 12:22:20
# Train 37 reaches end of signalling block 3 at 12:24:54
# Train 37 enters signalling block 4 at 12:24:54
# Train 38 arrives in Block0  at 12:25:00
# Train 38 leaves Block0 at 12:25:00
# Train 38 enters signalling block 1 at 12:25:00
# Train 36 arrives in Birmingham  Interchange at 12:26:50
# Train 37 reaches end of signalling block 4 at 12:30:03
# Train 37 enters signalling block 5 at 12:30:03
# Train 38 reaches end of signalling block 1 at 12:31:32
# Train 38 enters signalling block 2 at 12:31:32
# Train 38 reaches end of signalling block 2 at 12:36:58
# Train 38 enters signalling block 3 at 12:36:58
# Train 37 arrives in Block6 at 12:37:44
# Train 37 leaves Block6 at 12:37:44
# Train 39 leaves London Old Oak  common at 12:40:00
# Train 37 is at Block number7 Block 12:42:14
# Train 38 reaches end of signalling block 3 at 12:42:54
# Train 38 enters signalling block 4 at 12:42:54
# Train 39 arrives in Block0  at 12:45:00
# Train 39 leaves Block0 at 12:45:00
# Train 39 enters signalling block 1 at 12:45:00
# Train 37 arrives in Birmingham  Interchange at 12:46:44
# Train 38 reaches end of signalling block 4 at 12:47:41
# Train 38 enters signalling block 5 at 12:47:41
# Train 39 reaches end of signalling block 1 at 12:51:03
# Train 39 enters signalling block 2 at 12:51:03
# Train 38 arrives in Block6 at 12:55:17
# Train 38 leaves Block6 at 12:55:17
# Train 39 reaches end of signalling block 2 at 12:55:28
# Train 39 enters signalling block 3 at 12:55:28
# Train 38 is at Block number7 Block 12:59:47
# Train 40 leaves London Old Oak  common at 13:00:00
# Train 39 reaches end of signalling block 3 at 13:00:30
# Train 39 enters signalling block 4 at 13:00:30
# Train 38 arrives in Birmingham  Interchange at 13:04:17
# Train 40 arrives in Block0  at 13:05:00
# Train 40 leaves Block0 at 13:05:00
# Train 40 enters signalling block 1 at 13:05:00
# Train 39 reaches end of signalling block 4 at 13:06:10
# Train 39 enters signalling block 5 at 13:06:10
# Train 40 reaches end of signalling block 1 at 13:10:28
# Train 40 enters signalling block 2 at 13:10:28
# Train 39 arrives in Block6 at 13:13:26
# Train 39 leaves Block6 at 13:13:26
# Train 40 reaches end of signalling block 2 at 13:15:41
# Train 40 enters signalling block 3 at 13:15:41
# Train 39 is at Block number7 Block 13:17:56
# Train 41 leaves London Old Oak  common at 13:20:00
# Train 40 reaches end of signalling block 3 at 13:21:12
# Train 40 enters signalling block 4 at 13:21:12
# Train 39 arrives in Birmingham  Interchange at 13:22:26
# Train 41 arrives in Block0  at 13:25:00
# Train 41 leaves Block0 at 13:25:00
# Train 41 enters signalling block 1 at 13:25:00
# Train 40 reaches end of signalling block 4 at 13:26:44
# Train 40 enters signalling block 5 at 13:26:44
# Train 41 reaches end of signalling block 1 at 13:31:44
# Train 41 enters signalling block 2 at 13:31:44
# Train 40 arrives in Block6 at 13:33:32
# Train 40 leaves Block6 at 13:33:32
# Train 41 reaches end of signalling block 2 at 13:37:27
# Train 41 enters signalling block 3 at 13:37:27
# Train 40 is at Block number7 Block 13:38:02
# Train 42 leaves London Old Oak  common at 13:40:00
# Train 40 arrives in Birmingham  Interchange at 13:42:32
# Train 41 reaches end of signalling block 3 at 13:42:47
# Train 41 enters signalling block 4 at 13:42:47
# Train 42 arrives in Block0  at 13:45:00
# Train 42 leaves Block0 at 13:45:00
# Train 42 enters signalling block 1 at 13:45:00
# Train 41 reaches end of signalling block 4 at 13:48:47
# Train 41 enters signalling block 5 at 13:48:47
# Train 42 reaches end of signalling block 1 at 13:52:43
# Train 42 enters signalling block 2 at 13:52:43
# Train 41 arrives in Block6 at 13:56:08
# Train 41 leaves Block6 at 13:56:08
# Train 42 reaches end of signalling block 2 at 13:58:30
# Train 42 enters signalling block 3 at 13:58:30
# Train 43 leaves London Old Oak  common at 14:00:00
# Train 41 is at Block number7 Block 14:00:38
# Train 42 reaches end of signalling block 3 at 14:03:30
# Train 42 enters signalling block 4 at 14:03:30
# Train 43 arrives in Block0  at 14:05:00
# Train 43 leaves Block0 at 14:05:00
# Train 43 enters signalling block 1 at 14:05:00
# Train 41 arrives in Birmingham  Interchange at 14:05:08
# Train 42 reaches end of signalling block 4 at 14:09:35
# Train 42 enters signalling block 5 at 14:09:35
# Train 43 reaches end of signalling block 1 at 14:11:06
# Train 43 enters signalling block 2 at 14:11:06
# Train 42 arrives in Block6 at 14:16:13
# Train 42 leaves Block6 at 14:16:13
# Train 43 reaches end of signalling block 2 at 14:17:06
# Train 43 enters signalling block 3 at 14:17:06
# Train 44 leaves London Old Oak  common at 14:20:00
# Train 42 is at Block number7 Block 14:20:43
# Train 43 reaches end of signalling block 3 at 14:22:52
# Train 43 enters signalling block 4 at 14:22:52
# Train 44 arrives in Block0  at 14:25:00
# Train 44 leaves Block0 at 14:25:00
# Train 44 enters signalling block 1 at 14:25:00
# Train 42 arrives in Birmingham  Interchange at 14:25:13
# Train 43 reaches end of signalling block 4 at 14:29:10
# Train 43 enters signalling block 5 at 14:29:10
# Train 44 reaches end of signalling block 1 at 14:32:33
# Train 44 enters signalling block 2 at 14:32:33
# Train 43 arrives in Block6 at 14:36:00
# Train 43 leaves Block6 at 14:36:00
# Train 44 reaches end of signalling block 2 at 14:38:18
# Train 44 enters signalling block 3 at 14:38:18
# Train 45 leaves London Old Oak  common at 14:40:00
# Train 43 is at Block number7 Block 14:40:30
# Train 44 reaches end of signalling block 3 at 14:44:59
# Train 44 enters signalling block 4 at 14:44:59
# Train 45 arrives in Block0  at 14:45:00
# Train 45 leaves Block0 at 14:45:00
# Train 45 enters signalling block 1 at 14:45:00
# Train 43 arrives in Birmingham  Interchange at 14:45:00
# Train 44 reaches end of signalling block 4 at 14:51:12
# Train 44 enters signalling block 5 at 14:51:12
# Train 45 reaches end of signalling block 1 at 14:52:04
# Train 45 enters signalling block 2 at 14:52:04
# Train 45 reaches end of signalling block 2 at 14:57:24
# Train 45 enters signalling block 3 at 14:57:24
# Train 44 arrives in Block6 at 14:59:22
# Train 44 leaves Block6 at 14:59:22
# Train 46 leaves London Old Oak  common at 15:00:00
# Train 45 reaches end of signalling block 3 at 15:03:27
# Train 45 enters signalling block 4 at 15:03:27
# Train 44 is at Block number7 Block 15:03:52
# Train 46 arrives in Block0  at 15:05:00
# Train 46 leaves Block0 at 15:05:00
# Train 46 enters signalling block 1 at 15:05:00
# Train 44 arrives in Birmingham  Interchange at 15:08:22
# Train 45 reaches end of signalling block 4 at 15:09:55
# Train 45 enters signalling block 5 at 15:09:55
# Train 46 reaches end of signalling block 1 at 15:12:40
# Train 46 enters signalling block 2 at 15:12:40
# Train 45 arrives in Block6 at 15:16:33
# Train 45 leaves Block6 at 15:16:33
# Train 46 reaches end of signalling block 2 at 15:18:12
# Train 46 enters signalling block 3 at 15:18:12
# Train 47 leaves London Old Oak  common at 15:20:00
# Train 45 is at Block number7 Block 15:21:03
# Train 46 reaches end of signalling block 3 at 15:24:06
# Train 46 enters signalling block 4 at 15:24:06
# Train 47 arrives in Block0  at 15:25:00
# Train 47 leaves Block0 at 15:25:00
# Train 47 enters signalling block 1 at 15:25:00
# Train 45 arrives in Birmingham  Interchange at 15:25:33
# Train 46 reaches end of signalling block 4 at 15:29:37
# Train 46 enters signalling block 5 at 15:29:37
# Train 47 reaches end of signalling block 1 at 15:31:21
# Train 47 enters signalling block 2 at 15:31:21
# Train 47 reaches end of signalling block 2 at 15:36:49
# Train 47 enters signalling block 3 at 15:36:49
# Train 46 arrives in Block6 at 15:37:19
# Train 46 leaves Block6 at 15:37:19
# Train 48 leaves London Old Oak  common at 15:40:00
# Train 47 reaches end of signalling block 3 at 15:41:29
# Train 47 enters signalling block 4 at 15:41:29
# Train 46 is at Block number7 Block 15:41:49
# Train 48 arrives in Block0  at 15:45:00
# Train 48 leaves Block0 at 15:45:00
# Train 48 enters signalling block 1 at 15:45:00
# Train 46 arrives in Birmingham  Interchange at 15:46:19
# Train 47 reaches end of signalling block 4 at 15:47:22
# Train 47 enters signalling block 5 at 15:47:22
# Train 48 reaches end of signalling block 1 at 15:51:19
# Train 48 enters signalling block 2 at 15:51:19
# Train 47 arrives in Block6 at 15:54:03
# Train 47 leaves Block6 at 15:54:03
# Train 48 reaches end of signalling block 2 at 15:56:06
# Train 48 enters signalling block 3 at 15:56:06
# Train 47 is at Block number7 Block 15:58:33
# Train 49 leaves London Old Oak  common at 16:00:00
# Train 48 reaches end of signalling block 3 at 16:02:22
# Train 48 enters signalling block 4 at 16:02:22
# Train 47 arrives in Birmingham  Interchange at 16:03:03
# Train 49 arrives in Block0  at 16:05:00
# Train 49 leaves Block0 at 16:05:00
# Train 49 enters signalling block 1 at 16:05:00
# Train 48 reaches end of signalling block 4 at 16:06:46
# Train 48 enters signalling block 5 at 16:06:46
# Train 49 reaches end of signalling block 1 at 16:10:29
# Train 49 enters signalling block 2 at 16:10:29
# Train 48 arrives in Block6 at 16:13:47
# Train 48 leaves Block6 at 16:13:47
# Train 49 reaches end of signalling block 2 at 16:16:51
# Train 49 enters signalling block 3 at 16:16:51
# Train 48 is at Block number7 Block 16:18:17
# Train 50 leaves London Old Oak  common at 16:20:00
# Train 48 arrives in Birmingham  Interchange at 16:22:47
# Train 49 reaches end of signalling block 3 at 16:23:16
# Train 49 enters signalling block 4 at 16:23:16
# Train 50 arrives in Block0  at 16:25:00
# Train 50 leaves Block0 at 16:25:00
# Train 50 enters signalling block 1 at 16:25:00
# Train 49 reaches end of signalling block 4 at 16:28:17
# Train 49 enters signalling block 5 at 16:28:17
# Train 50 reaches end of signalling block 1 at 16:31:29
# Train 50 enters signalling block 2 at 16:31:29
# Train 49 arrives in Block6 at 16:34:25
# Train 49 leaves Block6 at 16:34:25
# Train 50 reaches end of signalling block 2 at 16:37:44
# Train 50 enters signalling block 3 at 16:37:44
# Train 49 is at Block number7 Block 16:38:55
# Train 51 leaves London Old Oak  common at 16:40:00
# Train 50 reaches end of signalling block 3 at 16:42:34
# Train 50 enters signalling block 4 at 16:42:34
# Train 49 arrives in Birmingham  Interchange at 16:43:25
# Train 51 arrives in Block0  at 16:45:00
# Train 51 leaves Block0 at 16:45:00
# Train 51 enters signalling block 1 at 16:45:00
# Train 50 reaches end of signalling block 4 at 16:48:10
# Train 50 enters signalling block 5 at 16:48:10
# Train 51 reaches end of signalling block 1 at 16:52:17
# Train 51 enters signalling block 2 at 16:52:17
# Train 50 arrives in Block6 at 16:55:13
# Train 50 leaves Block6 at 16:55:13
# Train 51 reaches end of signalling block 2 at 16:58:48
# Train 51 enters signalling block 3 at 16:58:48
# Train 50 is at Block number7 Block 16:59:43
# Train 52 leaves London Old Oak  common at 17:00:00
# Train 51 reaches end of signalling block 3 at 17:03:59
# Train 51 enters signalling block 4 at 17:03:59
# Train 50 arrives in Birmingham  Interchange at 17:04:13
# Train 52 arrives in Block0  at 17:05:00
# Train 52 leaves Block0 at 17:05:00
# Train 52 enters signalling block 1 at 17:05:00
# Train 51 reaches end of signalling block 4 at 17:09:52
# Train 51 enters signalling block 5 at 17:09:52
# Train 52 reaches end of signalling block 1 at 17:12:10
# Train 52 enters signalling block 2 at 17:12:10
# Train 51 arrives in Block6 at 17:16:59
# Train 51 leaves Block6 at 17:16:59
# Train 52 reaches end of signalling block 2 at 17:18:38
# Train 52 enters signalling block 3 at 17:18:38
# Train 53 leaves London Old Oak  common at 17:20:00
# Train 51 is at Block number7 Block 17:21:29
# Train 52 reaches end of signalling block 3 at 17:24:37
# Train 52 enters signalling block 4 at 17:24:37
# Train 53 arrives in Block0  at 17:25:00
# Train 53 leaves Block0 at 17:25:00
# Train 53 enters signalling block 1 at 17:25:00
# Train 51 arrives in Birmingham  Interchange at 17:25:59
# Train 52 reaches end of signalling block 4 at 17:29:22
# Train 52 enters signalling block 5 at 17:29:22
# Train 53 reaches end of signalling block 1 at 17:34:13
# Train 53 enters signalling block 2 at 17:34:13
# Train 52 arrives in Block6 at 17:37:03
# Train 52 leaves Block6 at 17:37:03
# Train 53 reaches end of signalling block 2 at 17:39:57
# Train 53 enters signalling block 3 at 17:39:57
# Train 54 leaves London Old Oak  common at 17:40:00
# Train 52 is at Block number7 Block 17:41:33
# Train 53 reaches end of signalling block 3 at 17:44:50
# Train 53 enters signalling block 4 at 17:44:50
# Train 54 arrives in Block0  at 17:45:00
# Train 54 leaves Block0 at 17:45:00
# Train 54 enters signalling block 1 at 17:45:00
# Train 52 arrives in Birmingham  Interchange at 17:46:03
# Train 53 reaches end of signalling block 4 at 17:50:33
# Train 53 enters signalling block 5 at 17:50:33
# Train 54 reaches end of signalling block 1 at 17:51:18
# Train 54 enters signalling block 2 at 17:51:18
# Train 54 reaches end of signalling block 2 at 17:57:11
# Train 54 enters signalling block 3 at 17:57:11
# Train 53 arrives in Block6 at 17:58:14
# Train 53 leaves Block6 at 17:58:14
# Train 55 leaves London Old Oak  common at 18:00:00
# Train 53 is at Block number7 Block 18:02:44
# Train 54 reaches end of signalling block 3 at 18:03:55
# Train 54 enters signalling block 4 at 18:03:55
# Train 55 arrives in Block0  at 18:05:00
# Train 55 leaves Block0 at 18:05:00
# Train 55 enters signalling block 1 at 18:05:00
# Train 53 arrives in Birmingham  Interchange at 18:07:14
# Train 54 reaches end of signalling block 4 at 18:09:40
# Train 54 enters signalling block 5 at 18:09:40
# Train 55 reaches end of signalling block 1 at 18:11:56
# Train 55 enters signalling block 2 at 18:11:56
# Train 54 arrives in Block6 at 18:17:09
# Train 54 leaves Block6 at 18:17:09
# Train 55 reaches end of signalling block 2 at 18:17:32
# Train 55 enters signalling block 3 at 18:17:32
# Train 56 leaves London Old Oak  common at 18:20:00
# Train 54 is at Block number7 Block 18:21:39
# Train 55 reaches end of signalling block 3 at 18:23:06
# Train 55 enters signalling block 4 at 18:23:06
# Train 56 arrives in Block0  at 18:25:00
# Train 56 leaves Block0 at 18:25:00
# Train 56 enters signalling block 1 at 18:25:00
# Train 54 arrives in Birmingham  Interchange at 18:26:09
# Train 55 reaches end of signalling block 4 at 18:29:24
# Train 55 enters signalling block 5 at 18:29:24
# Train 56 reaches end of signalling block 1 at 18:32:07
# Train 56 enters signalling block 2 at 18:32:07
# Train 55 arrives in Block6 at 18:36:10
# Train 55 leaves Block6 at 18:36:10
# Train 56 reaches end of signalling block 2 at 18:37:10
# Train 56 enters signalling block 3 at 18:37:10
# Train 57 leaves London Old Oak  common at 18:40:00
# Train 55 is at Block number7 Block 18:40:40
# Train 56 reaches end of signalling block 3 at 18:42:48
# Train 56 enters signalling block 4 at 18:42:48
# Train 57 arrives in Block0  at 18:45:00
# Train 57 leaves Block0 at 18:45:00
# Train 57 enters signalling block 1 at 18:45:00
# Train 55 arrives in Birmingham  Interchange at 18:45:10
# Train 56 reaches end of signalling block 4 at 18:49:08
# Train 56 enters signalling block 5 at 18:49:08
# Train 57 reaches end of signalling block 1 at 18:51:35
# Train 57 enters signalling block 2 at 18:51:35
# Train 57 reaches end of signalling block 2 at 18:56:49
# Train 57 enters signalling block 3 at 18:56:49
# Train 56 arrives in Block6 at 18:57:37
# Train 56 leaves Block6 at 18:57:37
# Train 58 leaves London Old Oak  common at 19:00:00
# Train 56 is at Block number7 Block 19:02:07
# Train 57 reaches end of signalling block 3 at 19:02:34
# Train 57 enters signalling block 4 at 19:02:34
# Train 58 arrives in Block0  at 19:05:00
# Train 58 leaves Block0 at 19:05:00
# Train 58 enters signalling block 1 at 19:05:00
# Train 56 arrives in Birmingham  Interchange at 19:06:37
# Train 57 reaches end of signalling block 4 at 19:06:49
# Train 57 enters signalling block 5 at 19:06:49
# Train 58 reaches end of signalling block 1 at 19:11:12
# Train 58 enters signalling block 2 at 19:11:12
# Train 57 arrives in Block6 at 19:13:49
# Train 57 leaves Block6 at 19:13:49
# Train 58 reaches end of signalling block 2 at 19:17:10
# Train 58 enters signalling block 3 at 19:17:10
# Train 57 is at Block number7 Block 19:18:19
# Train 59 leaves London Old Oak  common at 19:20:00
# Train 57 arrives in Birmingham  Interchange at 19:22:49
# Train 58 reaches end of signalling block 3 at 19:23:49
# Train 58 enters signalling block 4 at 19:23:49
# Train 59 arrives in Block0  at 19:24:59
# Train 59 leaves Block0 at 19:24:59
# Train 59 enters signalling block 1 at 19:24:59
# Train 58 reaches end of signalling block 4 at 19:29:31
# Train 58 enters signalling block 5 at 19:29:31
# Train 59 reaches end of signalling block 1 at 19:32:34
# Train 59 enters signalling block 2 at 19:32:34
# Train 58 arrives in Block6 at 19:37:13
# Train 58 leaves Block6 at 19:37:13
# Train 59 reaches end of signalling block 2 at 19:38:48
# Train 59 enters signalling block 3 at 19:38:48
# Train 60 leaves London Old Oak  common at 19:39:59
# Train 58 is at Block number7 Block 19:41:43
# Train 59 reaches end of signalling block 3 at 19:44:13
# Train 59 enters signalling block 4 at 19:44:13
# Train 60 arrives in Block0  at 19:44:59
# Train 60 leaves Block0 at 19:44:59
# Train 60 enters signalling block 1 at 19:44:59
# Train 58 arrives in Birmingham  Interchange at 19:46:13
# Train 59 reaches end of signalling block 4 at 19:50:40
# Train 59 enters signalling block 5 at 19:50:40
# Train 60 reaches end of signalling block 1 at 19:50:54
# Train 60 enters signalling block 2 at 19:50:54
# Train 60 reaches end of signalling block 2 at 19:56:02
# Train 60 enters signalling block 3 at 19:56:02
# Train 59 arrives in Block6 at 19:58:15
# Train 59 leaves Block6 at 19:58:15
# Train 61 leaves London Old Oak  common at 19:59:59
# Train 60 reaches end of signalling block 3 at 20:01:25
# Train 60 enters signalling block 4 at 20:01:25
# Train 59 is at Block number7 Block 20:02:45
# Train 61 arrives in Block0  at 20:04:59
# Train 61 leaves Block0 at 20:04:59
# Train 61 enters signalling block 1 at 20:04:59
# Train 60 reaches end of signalling block 4 at 20:06:15
# Train 60 enters signalling block 5 at 20:06:15
# Train 59 arrives in Birmingham  Interchange at 20:07:15
# Train 61 reaches end of signalling block 1 at 20:11:16
# Train 61 enters signalling block 2 at 20:11:16
# Train 60 arrives in Block6 at 20:13:44
# Train 60 leaves Block6 at 20:13:44
# Train 61 reaches end of signalling block 2 at 20:16:54
# Train 61 enters signalling block 3 at 20:16:54
# Train 60 is at Block number7 Block 20:18:14
# Train 62 leaves London Old Oak  common at 20:19:59
# Train 61 reaches end of signalling block 3 at 20:21:48
# Train 61 enters signalling block 4 at 20:21:48
# Train 60 arrives in Birmingham  Interchange at 20:22:44
# Train 62 arrives in Block0  at 20:24:59
# Train 62 leaves Block0 at 20:24:59
# Train 62 enters signalling block 1 at 20:24:59
# Train 61 reaches end of signalling block 4 at 20:28:19
# Train 61 enters signalling block 5 at 20:28:19
# Train 62 reaches end of signalling block 1 at 20:31:49
# Train 62 enters signalling block 2 at 20:31:49
# Train 61 arrives in Block6 at 20:36:16
# Train 61 leaves Block6 at 20:36:16
# Train 62 reaches end of signalling block 2 at 20:37:57
# Train 62 enters signalling block 3 at 20:37:57
# Train 63 leaves London Old Oak  common at 20:39:59
# Train 61 is at Block number7 Block 20:40:46
# Train 62 reaches end of signalling block 3 at 20:43:15
# Train 62 enters signalling block 4 at 20:43:15
# Train 63 arrives in Block0  at 20:44:59
# Train 63 leaves Block0 at 20:44:59
# Train 63 enters signalling block 1 at 20:44:59
# Train 61 arrives in Birmingham  Interchange at 20:45:16
# Train 62 reaches end of signalling block 4 at 20:47:49
# Train 62 enters signalling block 5 at 20:47:49
# Train 63 reaches end of signalling block 1 at 20:51:00
# Train 63 enters signalling block 2 at 20:51:00
# Train 62 arrives in Block6 at 20:55:55
# Train 62 leaves Block6 at 20:55:55
# Train 63 reaches end of signalling block 2 at 20:56:04
# Train 63 enters signalling block 3 at 20:56:04
# Train 64 leaves London Old Oak  common at 20:59:59
# Train 62 is at Block number7 Block 21:00:25
# Train 63 reaches end of signalling block 3 at 21:02:13
# Train 63 enters signalling block 4 at 21:02:13
# Train 62 arrives in Birmingham  Interchange at 21:04:55
# Train 64 arrives in Block0  at 21:04:59
# Train 64 leaves Block0 at 21:04:59
# Train 64 enters signalling block 1 at 21:04:59
# Train 63 reaches end of signalling block 4 at 21:07:32
# Train 63 enters signalling block 5 at 21:07:32
# Train 64 reaches end of signalling block 1 at 21:11:52
# Train 64 enters signalling block 2 at 21:11:52
# Train 63 arrives in Block6 at 21:13:27
# Train 63 leaves Block6 at 21:13:27
# Train 63 is at Block number7 Block 21:17:57
# Train 64 reaches end of signalling block 2 at 21:18:12
# Train 64 enters signalling block 3 at 21:18:12
# Train 65 leaves London Old Oak  common at 21:19:59
# Train 63 arrives in Birmingham  Interchange at 21:22:27
# Train 64 reaches end of signalling block 3 at 21:23:51
# Train 64 enters signalling block 4 at 21:23:51
# Train 65 arrives in Block0  at 21:24:59
# Train 65 leaves Block0 at 21:24:59
# Train 65 enters signalling block 1 at 21:24:59
# Train 64 reaches end of signalling block 4 at 21:30:02
# Train 64 enters signalling block 5 at 21:30:02
# Train 65 reaches end of signalling block 1 at 21:31:44
# Train 65 enters signalling block 2 at 21:31:44
# Train 65 reaches end of signalling block 2 at 21:37:21
# Train 65 enters signalling block 3 at 21:37:21
# Train 64 arrives in Block6 at 21:37:49
# Train 64 leaves Block6 at 21:37:49
# Train 66 leaves London Old Oak  common at 21:39:59
# Train 64 is at Block number7 Block 21:42:19
# Train 65 reaches end of signalling block 3 at 21:43:27
# Train 65 enters signalling block 4 at 21:43:27
# Train 66 arrives in Block0  at 21:44:59
# Train 66 leaves Block0 at 21:44:59
# Train 66 enters signalling block 1 at 21:44:59
# Train 64 arrives in Birmingham  Interchange at 21:46:49
# Train 65 reaches end of signalling block 4 at 21:48:16
# Train 65 enters signalling block 5 at 21:48:16
# Train 66 reaches end of signalling block 1 at 21:50:53
# Train 66 enters signalling block 2 at 21:50:53
# Train 65 arrives in Block6 at 21:56:00
# Train 65 leaves Block6 at 21:56:00
# Train 66 reaches end of signalling block 2 at 21:56:32
# Train 66 enters signalling block 3 at 21:56:32
# Train 67 leaves London Old Oak  common at 21:59:59

# %%
Trains_PH = [2]
Sig_blocks = [2]

Sim_Data_3 = Full_Simulation(Trains_PH,Sig_blocks,1)
# Out:
# 0
# Train 1 leaves London Old Oak  common at 00:00:00
# Train 1 arrives in Block0  at 00:05:00
# Train 1 leaves Block0 at 00:05:00
# Train 1 enters signalling block 1 at 00:05:00
# Train 1 reaches end of signalling block 1 at 00:19:45
# Train 1 enters signalling block 2 at 00:19:45
# Train 2 leaves London Old Oak  common at 00:30:00
# Train 2 arrives in Block0  at 00:35:00
# Train 2 leaves Block0 at 00:35:00
# Train 2 enters signalling block 1 at 00:35:00
# Train 1 arrives in Block3 at 00:37:09
# Train 1 leaves Block3 at 00:37:09
# Train 1 is at Block number4 Block 00:41:39
# Train 1 arrives in Birmingham  Interchange at 00:46:09
# Train 2 reaches end of signalling block 1 at 00:50:35
# Train 2 enters signalling block 2 at 00:50:35
# Train 3 leaves London Old Oak  common at 01:00:00
# Train 3 arrives in Block0  at 01:04:59
# Train 3 leaves Block0 at 01:04:59
# Train 3 enters signalling block 1 at 01:04:59
# Train 2 arrives in Block3 at 01:08:00
# Train 2 leaves Block3 at 01:08:00
# Train 2 is at Block number4 Block 01:12:30
# Train 2 arrives in Birmingham  Interchange at 01:17:00
# Train 3 reaches end of signalling block 1 at 01:20:03
# Train 3 enters signalling block 2 at 01:20:03
# Train 4 leaves London Old Oak  common at 01:30:00
# Train 4 arrives in Block0  at 01:35:00
# Train 4 leaves Block0 at 01:35:00
# Train 4 enters signalling block 1 at 01:35:00
# Train 3 arrives in Block3 at 01:35:57
# Train 3 leaves Block3 at 01:35:57
# Train 3 is at Block number4 Block 01:40:27
# Train 3 arrives in Birmingham  Interchange at 01:44:57
# Train 4 reaches end of signalling block 1 at 01:53:12
# Train 4 enters signalling block 2 at 01:53:12
# Train 5 leaves London Old Oak  common at 02:00:00
# Train 5 arrives in Block0  at 02:05:00
# Train 5 leaves Block0 at 02:05:00
# Train 5 enters signalling block 1 at 02:05:00
# Train 4 arrives in Block3 at 02:11:33
# Train 4 leaves Block3 at 02:11:33
# Train 4 is at Block number4 Block 02:16:03
# Train 5 reaches end of signalling block 1 at 02:19:45
# Train 5 enters signalling block 2 at 02:19:45
# Train 4 arrives in Birmingham  Interchange at 02:20:33
# Train 6 leaves London Old Oak  common at 02:30:00
# Train 6 arrives in Block0  at 02:35:00
# Train 6 leaves Block0 at 02:35:00
# Train 6 enters signalling block 1 at 02:35:00
# Train 5 arrives in Block3 at 02:37:42
# Train 5 leaves Block3 at 02:37:42
# Train 5 is at Block number4 Block 02:42:12
# Train 5 arrives in Birmingham  Interchange at 02:46:42
# Train 6 reaches end of signalling block 1 at 02:49:50
# Train 6 enters signalling block 2 at 02:49:50
# Train 7 leaves London Old Oak  common at 03:00:00
# Train 7 arrives in Block0  at 03:05:00
# Train 7 leaves Block0 at 03:05:00
# Train 7 enters signalling block 1 at 03:05:00
# Train 6 arrives in Block3 at 03:07:38
# Train 6 leaves Block3 at 03:07:38
# Train 6 is at Block number4 Block 03:12:08
# Train 6 arrives in Birmingham  Interchange at 03:16:38
# Train 7 reaches end of signalling block 1 at 03:18:25
# Train 7 enters signalling block 2 at 03:18:25
# Train 8 leaves London Old Oak  common at 03:30:00
# Train 7 arrives in Block3 at 03:33:08
# Train 7 leaves Block3 at 03:33:08
# Train 8 arrives in Block0  at 03:35:00
# Train 8 leaves Block0 at 03:35:00
# Train 8 enters signalling block 1 at 03:35:00
# Train 7 is at Block number4 Block 03:37:38
# Train 7 arrives in Birmingham  Interchange at 03:42:08
# Train 8 reaches end of signalling block 1 at 03:49:15
# Train 8 enters signalling block 2 at 03:49:15
# Train 9 leaves London Old Oak  common at 04:00:00
# Train 9 arrives in Block0  at 04:04:59
# Train 9 leaves Block0 at 04:04:59
# Train 9 enters signalling block 1 at 04:04:59
# Train 8 arrives in Block3 at 04:05:33
# Train 8 leaves Block3 at 04:05:33
# Train 8 is at Block number4 Block 04:10:03
# Train 8 arrives in Birmingham  Interchange at 04:14:33
# Train 9 reaches end of signalling block 1 at 04:23:55
# Train 9 enters signalling block 2 at 04:23:55
# Train 10 leaves London Old Oak  common at 04:30:00
# Train 10 arrives in Block0  at 04:35:00
# Train 10 leaves Block0 at 04:35:00
# Train 10 enters signalling block 1 at 04:35:00
# Train 9 arrives in Block3 at 04:42:00
# Train 9 leaves Block3 at 04:42:00
# Train 9 is at Block number4 Block 04:46:30
# Train 9 arrives in Birmingham  Interchange at 04:51:00
# Train 10 reaches end of signalling block 1 at 04:54:10
# Train 10 enters signalling block 2 at 04:54:10
# Train 11 leaves London Old Oak  common at 05:00:00
# Train 11 arrives in Block0  at 05:05:00
# Train 11 leaves Block0 at 05:05:00
# Train 11 enters signalling block 1 at 05:05:00
# Train 10 arrives in Block3 at 05:12:45
# Train 10 leaves Block3 at 05:12:45
# Train 10 is at Block number4 Block 05:17:15
# Train 11 reaches end of signalling block 1 at 05:21:06
# Train 11 enters signalling block 2 at 05:21:06
# Train 10 arrives in Birmingham  Interchange at 05:21:45
# Train 12 leaves London Old Oak  common at 05:30:00
# Train 12 arrives in Block0  at 05:35:00
# Train 12 leaves Block0 at 05:35:00
# Train 12 enters signalling block 1 at 05:35:00
# Train 11 arrives in Block3 at 05:37:14
# Train 11 leaves Block3 at 05:37:14
# Train 11 is at Block number4 Block 05:41:44
# Train 11 arrives in Birmingham  Interchange at 05:46:14
# Train 12 reaches end of signalling block 1 at 05:53:20
# Train 12 enters signalling block 2 at 05:53:20
# Train 13 leaves London Old Oak  common at 06:00:00
# Train 13 arrives in Block0  at 06:05:00
# Train 13 leaves Block0 at 06:05:00
# Train 13 enters signalling block 1 at 06:05:00
# Train 12 arrives in Block3 at 06:09:58
# Train 12 leaves Block3 at 06:09:58
# Train 12 is at Block number4 Block 06:14:28
# Train 12 arrives in Birmingham  Interchange at 06:18:58
# Train 13 reaches end of signalling block 1 at 06:21:18
# Train 13 enters signalling block 2 at 06:21:18
# Train 14 leaves London Old Oak  common at 06:30:00
# Train 14 arrives in Block0  at 06:35:00
# Train 14 leaves Block0 at 06:35:00
# Train 14 enters signalling block 1 at 06:35:00
# Train 13 arrives in Block3 at 06:35:40
# Train 13 leaves Block3 at 06:35:40
# Train 13 is at Block number4 Block 06:40:10
# Train 13 arrives in Birmingham  Interchange at 06:44:40
# Train 14 reaches end of signalling block 1 at 06:51:23
# Train 14 enters signalling block 2 at 06:51:23
# Train 15 leaves London Old Oak  common at 07:00:00
# Train 14 arrives in Block3 at 07:03:20
# Train 14 leaves Block3 at 07:03:20
# Train 15 arrives in Block0  at 07:05:00
# Train 15 leaves Block0 at 07:05:00
# Train 15 enters signalling block 1 at 07:05:00
# Train 14 is at Block number4 Block 07:07:50
# Train 14 arrives in Birmingham  Interchange at 07:12:20
# Train 15 reaches end of signalling block 1 at 07:19:20
# Train 15 enters signalling block 2 at 07:19:20
# Train 16 leaves London Old Oak  common at 07:30:00
# Train 15 arrives in Block3 at 07:34:17
# Train 15 leaves Block3 at 07:34:17
# Train 16 arrives in Block0  at 07:35:00
# Train 16 leaves Block0 at 07:35:00
# Train 16 enters signalling block 1 at 07:35:00
# Train 15 is at Block number4 Block 07:38:47
# Train 15 arrives in Birmingham  Interchange at 07:43:17
# Train 16 reaches end of signalling block 1 at 07:51:04
# Train 16 enters signalling block 2 at 07:51:04
# Train 17 leaves London Old Oak  common at 08:00:00
# Train 17 arrives in Block0  at 08:05:00
# Train 17 leaves Block0 at 08:05:00
# Train 17 enters signalling block 1 at 08:05:00
# Train 16 arrives in Block3 at 08:06:50
# Train 16 leaves Block3 at 08:06:50
# Train 16 is at Block number4 Block 08:11:20
# Train 16 arrives in Birmingham  Interchange at 08:15:50
# Train 17 reaches end of signalling block 1 at 08:21:01
# Train 17 enters signalling block 2 at 08:21:01
# Train 18 leaves London Old Oak  common at 08:30:00
# Train 18 arrives in Block0  at 08:35:00
# Train 18 leaves Block0 at 08:35:00
# Train 18 enters signalling block 1 at 08:35:00
# Train 17 arrives in Block3 at 08:39:49
# Train 17 leaves Block3 at 08:39:49
# Train 17 is at Block number4 Block 08:44:19
# Train 17 arrives in Birmingham  Interchange at 08:48:49
# Train 18 reaches end of signalling block 1 at 08:49:49
# Train 18 enters signalling block 2 at 08:49:49
# Train 19 leaves London Old Oak  common at 09:00:00
# Train 19 arrives in Block0  at 09:05:00
# Train 19 leaves Block0 at 09:05:00
# Train 19 enters signalling block 1 at 09:05:00
# Train 18 arrives in Block3 at 09:06:55
# Train 18 leaves Block3 at 09:06:55
# Train 18 is at Block number4 Block 09:11:25
# Train 18 arrives in Birmingham  Interchange at 09:15:55
# Train 19 reaches end of signalling block 1 at 09:18:25
# Train 19 enters signalling block 2 at 09:18:25
# Train 20 leaves London Old Oak  common at 09:30:00
# Train 20 arrives in Block0  at 09:35:00
# Train 20 leaves Block0 at 09:35:00
# Train 20 enters signalling block 1 at 09:35:00
# Train 19 arrives in Block3 at 09:35:09
# Train 19 leaves Block3 at 09:35:09
# Train 19 is at Block number4 Block 09:39:39
# Train 19 arrives in Birmingham  Interchange at 09:44:09
# Train 20 reaches end of signalling block 1 at 09:52:15
# Train 20 enters signalling block 2 at 09:52:15
# Train 21 leaves London Old Oak  common at 10:00:00
# Train 21 arrives in Block0  at 10:05:00
# Train 21 leaves Block0 at 10:05:00
# Train 21 enters signalling block 1 at 10:05:00
# Train 20 arrives in Block3 at 10:10:14
# Train 20 leaves Block3 at 10:10:14
# Train 20 is at Block number4 Block 10:14:44
# Train 20 arrives in Birmingham  Interchange at 10:19:14
# Train 21 reaches end of signalling block 1 at 10:20:04
# Train 21 enters signalling block 2 at 10:20:04
# Train 22 leaves London Old Oak  common at 10:30:00
# Train 22 arrives in Block0  at 10:35:00
# Train 22 leaves Block0 at 10:35:00
# Train 22 enters signalling block 1 at 10:35:00
# Train 21 arrives in Block3 at 10:37:11
# Train 21 leaves Block3 at 10:37:11
# Train 21 is at Block number4 Block 10:41:41
# Train 21 arrives in Birmingham  Interchange at 10:46:11
# Train 22 reaches end of signalling block 1 at 10:52:05
# Train 22 enters signalling block 2 at 10:52:05
# Train 23 leaves London Old Oak  common at 11:00:00
# Train 23 arrives in Block0  at 11:05:00
# Train 23 leaves Block0 at 11:05:00
# Train 23 enters signalling block 1 at 11:05:00
# Train 22 arrives in Block3 at 11:08:38
# Train 22 leaves Block3 at 11:08:38
# Train 22 is at Block number4 Block 11:13:08
# Train 22 arrives in Birmingham  Interchange at 11:17:38
# Train 23 reaches end of signalling block 1 at 11:21:49
# Train 23 enters signalling block 2 at 11:21:49
# Train 24 leaves London Old Oak  common at 11:30:00
# Train 24 arrives in Block0  at 11:35:00
# Train 24 leaves Block0 at 11:35:00
# Train 24 enters signalling block 1 at 11:35:00
# Train 23 arrives in Block3 at 11:39:09
# Train 23 leaves Block3 at 11:39:09
# Train 23 is at Block number4 Block 11:43:39
# Train 23 arrives in Birmingham  Interchange at 11:48:09
# Train 24 reaches end of signalling block 1 at 11:52:13
# Train 24 enters signalling block 2 at 11:52:13
# Train 25 leaves London Old Oak  common at 12:00:00
# Train 25 arrives in Block0  at 12:05:00
# Train 25 leaves Block0 at 12:05:00
# Train 25 enters signalling block 1 at 12:05:00
# Train 24 arrives in Block3 at 12:07:09
# Train 24 leaves Block3 at 12:07:09
# Train 24 is at Block number4 Block 12:11:39
# Train 24 arrives in Birmingham  Interchange at 12:16:09
# Train 25 reaches end of signalling block 1 at 12:19:35
# Train 25 enters signalling block 2 at 12:19:35
# Train 26 leaves London Old Oak  common at 12:30:00
# Train 26 arrives in Block0  at 12:35:00
# Train 26 leaves Block0 at 12:35:00
# Train 26 enters signalling block 1 at 12:35:00
# Train 25 arrives in Block3 at 12:40:18
# Train 25 leaves Block3 at 12:40:18
# Train 25 is at Block number4 Block 12:44:48
# Train 25 arrives in Birmingham  Interchange at 12:49:18
# Train 26 reaches end of signalling block 1 at 12:54:45
# Train 26 enters signalling block 2 at 12:54:45
# Train 27 leaves London Old Oak  common at 13:00:00
# Train 27 arrives in Block0  at 13:05:00
# Train 27 leaves Block0 at 13:05:00
# Train 27 enters signalling block 1 at 13:05:00
# Train 26 arrives in Block3 at 13:09:01
# Train 26 leaves Block3 at 13:09:01
# Train 26 is at Block number4 Block 13:13:31
# Train 26 arrives in Birmingham  Interchange at 13:18:01
# Train 27 reaches end of signalling block 1 at 13:22:19
# Train 27 enters signalling block 2 at 13:22:19
# Train 28 leaves London Old Oak  common at 13:30:00
# Train 28 arrives in Block0  at 13:35:00
# Train 28 leaves Block0 at 13:35:00
# Train 28 enters signalling block 1 at 13:35:00
# Train 27 arrives in Block3 at 13:39:55
# Train 27 leaves Block3 at 13:39:55
# Train 27 is at Block number4 Block 13:44:25
# Train 27 arrives in Birmingham  Interchange at 13:48:55
# Train 28 reaches end of signalling block 1 at 13:52:49
# Train 28 enters signalling block 2 at 13:52:49
# Train 29 leaves London Old Oak  common at 14:00:00
# Train 29 arrives in Block0  at 14:05:00
# Train 29 leaves Block0 at 14:05:00
# Train 29 enters signalling block 1 at 14:05:00
# Train 28 arrives in Block3 at 14:09:37
# Train 28 leaves Block3 at 14:09:37
# Train 28 is at Block number4 Block 14:14:07
# Train 28 arrives in Birmingham  Interchange at 14:18:37
# Train 29 reaches end of signalling block 1 at 14:20:02
# Train 29 enters signalling block 2 at 14:20:02
# Train 30 leaves London Old Oak  common at 14:30:00
# Train 30 arrives in Block0  at 14:35:00
# Train 30 leaves Block0 at 14:35:00
# Train 30 enters signalling block 1 at 14:35:00
# Train 29 arrives in Block3 at 14:36:18
# Train 29 leaves Block3 at 14:36:18
# Train 29 is at Block number4 Block 14:40:48
# Train 29 arrives in Birmingham  Interchange at 14:45:18
# Train 30 reaches end of signalling block 1 at 14:50:45
# Train 30 enters signalling block 2 at 14:50:45
# Train 31 leaves London Old Oak  common at 15:00:00
# Train 31 arrives in Block0  at 15:05:00
# Train 31 leaves Block0 at 15:05:00
# Train 31 enters signalling block 1 at 15:05:00
# Train 30 arrives in Block3 at 15:07:33
# Train 30 leaves Block3 at 15:07:33
# Train 30 is at Block number4 Block 15:12:03
# Train 30 arrives in Birmingham  Interchange at 15:16:33
# Train 31 reaches end of signalling block 1 at 15:21:07
# Train 31 enters signalling block 2 at 15:21:07
# Train 32 leaves London Old Oak  common at 15:30:00
# Train 32 arrives in Block0  at 15:35:00
# Train 32 leaves Block0 at 15:35:00
# Train 32 enters signalling block 1 at 15:35:00
# Train 31 arrives in Block3 at 15:37:28
# Train 31 leaves Block3 at 15:37:28
# Train 31 is at Block number4 Block 15:41:58
# Train 31 arrives in Birmingham  Interchange at 15:46:28
# Train 32 reaches end of signalling block 1 at 15:53:15
# Train 32 enters signalling block 2 at 15:53:15
# Train 33 leaves London Old Oak  common at 16:00:00
# Train 33 arrives in Block0  at 16:04:59
# Train 33 leaves Block0 at 16:04:59
# Train 33 enters signalling block 1 at 16:04:59
# Train 32 arrives in Block3 at 16:11:52
# Train 32 leaves Block3 at 16:11:52
# Train 32 is at Block number4 Block 16:16:22
# Train 33 reaches end of signalling block 1 at 16:19:36
# Train 33 enters signalling block 2 at 16:19:36
# Train 32 arrives in Birmingham  Interchange at 16:20:52
# Train 34 leaves London Old Oak  common at 16:30:00
# Train 34 arrives in Block0  at 16:34:59
# Train 34 leaves Block0 at 16:34:59
# Train 34 enters signalling block 1 at 16:34:59
# Train 33 arrives in Block3 at 16:35:25
# Train 33 leaves Block3 at 16:35:25
# Train 33 is at Block number4 Block 16:39:55
# Train 33 arrives in Birmingham  Interchange at 16:44:25
# Train 34 reaches end of signalling block 1 at 16:50:15
# Train 34 enters signalling block 2 at 16:50:15
# Train 35 leaves London Old Oak  common at 17:00:00
# Train 35 arrives in Block0  at 17:04:59
# Train 35 leaves Block0 at 17:04:59
# Train 35 enters signalling block 1 at 17:04:59
# Train 34 arrives in Block3 at 17:08:51
# Train 34 leaves Block3 at 17:08:51
# Train 34 is at Block number4 Block 17:13:21
# Train 34 arrives in Birmingham  Interchange at 17:17:51
# Train 35 reaches end of signalling block 1 at 17:21:28
# Train 35 enters signalling block 2 at 17:21:28
# Train 36 leaves London Old Oak  common at 17:30:00
# Train 36 arrives in Block0  at 17:34:59
# Train 36 leaves Block0 at 17:34:59
# Train 36 enters signalling block 1 at 17:34:59
# Train 35 arrives in Block3 at 17:40:26
# Train 35 leaves Block3 at 17:40:26
# Train 35 is at Block number4 Block 17:44:56
# Train 35 arrives in Birmingham  Interchange at 17:49:26
# Train 36 reaches end of signalling block 1 at 17:50:46
# Train 36 enters signalling block 2 at 17:50:46
# Train 37 leaves London Old Oak  common at 18:00:00
# Train 37 arrives in Block0  at 18:04:59
# Train 37 leaves Block0 at 18:04:59
# Train 37 enters signalling block 1 at 18:04:59
# Train 36 arrives in Block3 at 18:07:23
# Train 36 leaves Block3 at 18:07:23
# Train 36 is at Block number4 Block 18:11:53
# Train 36 arrives in Birmingham  Interchange at 18:16:23
# Train 37 reaches end of signalling block 1 at 18:19:20
# Train 37 enters signalling block 2 at 18:19:20
# Train 38 leaves London Old Oak  common at 18:30:00
# Train 38 arrives in Block0  at 18:35:00
# Train 38 leaves Block0 at 18:35:00
# Train 38 enters signalling block 1 at 18:35:00
# Train 37 arrives in Block3 at 18:38:04
# Train 37 leaves Block3 at 18:38:04
# Train 37 is at Block number4 Block 18:42:34
# Train 37 arrives in Birmingham  Interchange at 18:47:04
# Train 38 reaches end of signalling block 1 at 18:50:58
# Train 38 enters signalling block 2 at 18:50:58
# Train 39 leaves London Old Oak  common at 19:00:00
# Train 39 arrives in Block0  at 19:05:00
# Train 39 leaves Block0 at 19:05:00
# Train 39 enters signalling block 1 at 19:05:00
# Train 38 arrives in Block3 at 19:05:04
# Train 38 leaves Block3 at 19:05:04
# Train 38 is at Block number4 Block 19:09:34
# Train 38 arrives in Birmingham  Interchange at 19:14:04
# Train 39 reaches end of signalling block 1 at 19:20:35
# Train 39 enters signalling block 2 at 19:20:35
# Train 40 leaves London Old Oak  common at 19:30:00
# Train 39 arrives in Block3 at 19:33:20
# Train 39 leaves Block3 at 19:33:20
# Train 40 arrives in Block0  at 19:35:00
# Train 40 leaves Block0 at 19:35:00
# Train 40 enters signalling block 1 at 19:35:00
# Train 39 is at Block number4 Block 19:37:50
# Train 39 arrives in Birmingham  Interchange at 19:42:20
# Train 40 reaches end of signalling block 1 at 19:49:58
# Train 40 enters signalling block 2 at 19:49:58
# Train 41 leaves London Old Oak  common at 20:00:00
# Train 41 arrives in Block0  at 20:05:00
# Train 41 leaves Block0 at 20:05:00
# Train 41 enters signalling block 1 at 20:05:00
# Train 40 arrives in Block3 at 20:06:44
# Train 40 leaves Block3 at 20:06:44
# Train 40 is at Block number4 Block 20:11:14
# Train 40 arrives in Birmingham  Interchange at 20:15:44
# Train 41 reaches end of signalling block 1 at 20:22:02
# Train 41 enters signalling block 2 at 20:22:02
# Train 42 leaves London Old Oak  common at 20:30:00
# Train 42 arrives in Block0  at 20:35:00
# Train 42 leaves Block0 at 20:35:00
# Train 42 enters signalling block 1 at 20:35:00
# Train 41 arrives in Block3 at 20:41:06
# Train 41 leaves Block3 at 20:41:06
# Train 41 is at Block number4 Block 20:45:36
# Train 41 arrives in Birmingham  Interchange at 20:50:06
# Train 42 reaches end of signalling block 1 at 20:51:04
# Train 42 enters signalling block 2 at 20:51:04
# Train 43 leaves London Old Oak  common at 21:00:00
# Train 43 arrives in Block0  at 21:05:00
# Train 43 leaves Block0 at 21:05:00
# Train 43 enters signalling block 1 at 21:05:00
# Train 42 arrives in Block3 at 21:08:58
# Train 42 leaves Block3 at 21:08:58
# Train 42 is at Block number4 Block 21:13:28
# Train 42 arrives in Birmingham  Interchange at 21:17:58
# Train 43 reaches end of signalling block 1 at 21:22:05
# Train 43 enters signalling block 2 at 21:22:05
# Train 44 leaves London Old Oak  common at 21:30:00
# Train 44 arrives in Block0  at 21:35:00
# Train 44 leaves Block0 at 21:35:00
# Train 44 enters signalling block 1 at 21:35:00
# Train 43 arrives in Block3 at 21:38:20
# Train 43 leaves Block3 at 21:38:20
# Train 43 is at Block number4 Block 21:42:50
# Train 43 arrives in Birmingham  Interchange at 21:47:20
# Train 44 reaches end of signalling block 1 at 21:48:07
# Train 44 enters signalling block 2 at 21:48:07

# %%
Trains_PH = [9]
Sig_blocks = [4]

Sim_Data_4 = Full_Simulation(Trains_PH,Sig_blocks,1)
# Out:
# 0
# Train 1 leaves London Old Oak  common at 00:00:00
# Train 1 arrives in Block0  at 00:05:00
# Train 1 leaves Block0 at 00:05:00
# Train 1 enters signalling block 1 at 00:05:00
# Train 2 leaves London Old Oak  common at 00:06:40
# Train 2 arrives in Block0  at 00:11:39
# Train 2 leaves Block0 at 00:11:39
# Train 1 reaches end of signalling block 1 at 00:12:36
# Train 1 enters signalling block 2 at 00:12:36
# Train 2 enters signalling block 1 at 00:12:36
# Train 3 leaves London Old Oak  common at 00:13:20
# Train 3 arrives in Block0  at 00:18:20
# Train 3 leaves Block0 at 00:18:20
# Train 1 reaches end of signalling block 2 at 00:19:42
# Train 1 enters signalling block 3 at 00:19:42
# Train 2 reaches end of signalling block 1 at 00:20:57
# Train 2 enters signalling block 2 at 00:20:57
# Train 3 enters signalling block 1 at 00:20:57
# Train 4 leaves London Old Oak  common at 00:20:57
# Train 4 arrives in Block0  at 00:25:57
# Train 4 leaves Block0 at 00:25:57
# Train 1 reaches end of signalling block 3 at 00:26:58
# Train 1 enters signalling block 4 at 00:26:58
# Train 3 reaches end of signalling block 1 at 00:30:32
# Train 2 reaches end of signalling block 2 at 00:30:36
# Train 2 enters signalling block 3 at 00:30:36
# Train 3 enters signalling block 2 at 00:30:36
# Train 4 enters signalling block 1 at 00:30:36
# Train 5 leaves London Old Oak  common at 00:30:36
# Train 1 arrives in Block5 at 00:35:29
# Train 1 leaves Block5 at 00:35:29
# Train 5 arrives in Block0  at 00:35:36
# Train 5 leaves Block0 at 00:35:36
# Train 1 is at Block number6 Block 00:39:59
# Train 4 reaches end of signalling block 1 at 00:40:51
# Train 3 reaches end of signalling block 2 at 00:41:05
# Train 2 reaches end of signalling block 3 at 00:41:10
# Train 2 enters signalling block 4 at 00:41:10
# Train 3 enters signalling block 3 at 00:41:10
# Train 4 enters signalling block 2 at 00:41:10
# Train 5 enters signalling block 1 at 00:41:10
# Train 6 leaves London Old Oak  common at 00:41:10
# Train 1 arrives in Birmingham  Interchange at 00:44:29
# Train 6 arrives in Block0  at 00:46:10
# Train 6 leaves Block0 at 00:46:10
# Train 5 reaches end of signalling block 1 at 00:49:45
# Train 3 reaches end of signalling block 3 at 00:50:08
# Train 4 reaches end of signalling block 2 at 00:50:21
# Train 2 arrives in Block5 at 00:53:53
# Train 2 leaves Block5 at 00:53:53
# Train 3 enters signalling block 4 at 00:53:53
# Train 4 enters signalling block 3 at 00:53:53
# Train 5 enters signalling block 2 at 00:53:53
# Train 6 enters signalling block 1 at 00:53:53
# Train 7 leaves London Old Oak  common at 00:53:53
# Train 2 is at Block number6 Block 00:58:23
# Train 7 arrives in Block0  at 00:58:53
# Train 7 leaves Block0 at 00:58:53
# Train 5 reaches end of signalling block 2 at 01:00:52
# Train 6 reaches end of signalling block 1 at 01:02:17
# Train 4 reaches end of signalling block 3 at 01:02:47
# Train 2 arrives in Birmingham  Interchange at 01:02:53
# Train 3 arrives in Block5 at 01:03:52
# Train 3 leaves Block5 at 01:03:52
# Train 4 enters signalling block 4 at 01:03:52
# Train 5 enters signalling block 3 at 01:03:52
# Train 6 enters signalling block 2 at 01:03:52
# Train 7 enters signalling block 1 at 01:03:52
# Train 8 leaves London Old Oak  common at 01:03:52
# Train 3 is at Block number6 Block 01:08:22
# Train 8 arrives in Block0  at 01:08:52
# Train 8 leaves Block0 at 01:08:52
# Train 6 reaches end of signalling block 2 at 01:11:56
# Train 7 reaches end of signalling block 1 at 01:12:50
# Train 3 arrives in Birmingham  Interchange at 01:12:52
# Train 4 arrives in Block5 at 01:13:29
# Train 4 leaves Block5 at 01:13:29
# Train 5 reaches end of signalling block 3 at 01:14:23
# Train 5 enters signalling block 4 at 01:14:23
# Train 6 enters signalling block 3 at 01:14:23
# Train 7 enters signalling block 2 at 01:14:23
# Train 8 enters signalling block 1 at 01:14:23
# Train 9 leaves London Old Oak  common at 01:14:23
# Train 4 is at Block number6 Block 01:17:59
# Train 9 arrives in Block0  at 01:19:23
# Train 9 leaves Block0 at 01:19:23
# Train 4 arrives in Birmingham  Interchange at 01:22:29
# Train 6 reaches end of signalling block 3 at 01:23:14
# Train 5 arrives in Block5 at 01:23:48
# Train 5 leaves Block5 at 01:23:48
# Train 6 enters signalling block 4 at 01:23:48
# Train 8 reaches end of signalling block 1 at 01:23:56
# Train 7 reaches end of signalling block 2 at 01:24:27
# Train 7 enters signalling block 3 at 01:24:27
# Train 8 enters signalling block 2 at 01:24:27
# Train 9 enters signalling block 1 at 01:24:27
# Train 10 leaves London Old Oak  common at 01:24:27
# Train 5 is at Block number6 Block 01:28:18
# Train 10 arrives in Block0  at 01:29:27
# Train 10 leaves Block0 at 01:29:27
# Train 5 arrives in Birmingham  Interchange at 01:32:48
# Train 7 reaches end of signalling block 3 at 01:33:18
# Train 6 arrives in Block5 at 01:33:40
# Train 6 leaves Block5 at 01:33:40
# Train 7 enters signalling block 4 at 01:33:40
# Train 9 reaches end of signalling block 1 at 01:34:00
# Train 8 reaches end of signalling block 2 at 01:35:28
# Train 8 enters signalling block 3 at 01:35:28
# Train 9 enters signalling block 2 at 01:35:28
# Train 10 enters signalling block 1 at 01:35:28
# Train 11 leaves London Old Oak  common at 01:35:28
# Train 6 is at Block number6 Block 01:38:10
# Train 11 arrives in Block0  at 01:40:28
# Train 11 leaves Block0 at 01:40:28
# Train 6 arrives in Birmingham  Interchange at 01:42:40
# Train 10 reaches end of signalling block 1 at 01:44:22
# Train 7 arrives in Block5 at 01:44:27
# Train 7 leaves Block5 at 01:44:27
# Train 8 reaches end of signalling block 3 at 01:44:36
# Train 8 enters signalling block 4 at 01:44:36
# Train 9 reaches end of signalling block 2 at 01:45:35
# Train 9 enters signalling block 3 at 01:45:35
# Train 10 enters signalling block 2 at 01:45:35
# Train 11 enters signalling block 1 at 01:45:35
# Train 12 leaves London Old Oak  common at 01:45:35
# Train 7 is at Block number6 Block 01:48:57
# Train 12 arrives in Block0  at 01:50:35
# Train 12 leaves Block0 at 01:50:35
# Train 8 arrives in Block5 at 01:53:15
# Train 8 leaves Block5 at 01:53:15
# Train 7 arrives in Birmingham  Interchange at 01:53:27
# Train 9 reaches end of signalling block 3 at 01:54:28
# Train 9 enters signalling block 4 at 01:54:28
# Train 11 reaches end of signalling block 1 at 01:54:56
# Train 10 reaches end of signalling block 2 at 01:55:06
# Train 10 enters signalling block 3 at 01:55:06
# Train 11 enters signalling block 2 at 01:55:06
# Train 12 enters signalling block 1 at 01:55:06
# Train 13 leaves London Old Oak  common at 01:55:06
# Train 8 is at Block number6 Block 01:57:45
# Train 13 arrives in Block0  at 02:00:06
# Train 13 leaves Block0 at 02:00:06
# Train 8 arrives in Birmingham  Interchange at 02:02:15
# Train 10 reaches end of signalling block 3 at 02:03:33
# Train 11 reaches end of signalling block 2 at 02:03:37
# Train 9 arrives in Block5 at 02:05:30
# Train 9 leaves Block5 at 02:05:30
# Train 10 enters signalling block 4 at 02:05:30
# Train 11 enters signalling block 3 at 02:05:30
# Train 12 reaches end of signalling block 1 at 02:06:17
# Train 12 enters signalling block 2 at 02:06:17
# Train 13 enters signalling block 1 at 02:06:17
# Train 14 leaves London Old Oak  common at 02:06:17
# Train 9 is at Block number6 Block 02:10:00
# Train 14 arrives in Block0  at 02:11:17
# Train 14 leaves Block0 at 02:11:17
# Train 11 reaches end of signalling block 3 at 02:13:15
# Train 9 arrives in Birmingham  Interchange at 02:14:30
# Train 10 arrives in Block5 at 02:15:38
# Train 10 leaves Block5 at 02:15:38
# Train 11 enters signalling block 4 at 02:15:38
# Train 13 reaches end of signalling block 1 at 02:16:04
# Train 12 reaches end of signalling block 2 at 02:16:19
# Train 12 enters signalling block 3 at 02:16:19
# Train 13 enters signalling block 2 at 02:16:19
# Train 14 enters signalling block 1 at 02:16:19
# Train 15 leaves London Old Oak  common at 02:16:19
# Train 10 is at Block number6 Block 02:20:08
# Train 15 arrives in Block0  at 02:21:19
# Train 15 leaves Block0 at 02:21:19
# Train 11 arrives in Block5 at 02:23:08
# Train 11 leaves Block5 at 02:23:08
# Train 10 arrives in Birmingham  Interchange at 02:24:38
# Train 12 reaches end of signalling block 3 at 02:25:31
# Train 12 enters signalling block 4 at 02:25:31
# Train 13 reaches end of signalling block 2 at 02:25:51
# Train 13 enters signalling block 3 at 02:25:51
# Train 14 reaches end of signalling block 1 at 02:26:34
# Train 14 enters signalling block 2 at 02:26:34
# Train 15 enters signalling block 1 at 02:26:34
# Train 16 leaves London Old Oak  common at 02:26:34
# Train 11 is at Block number6 Block 02:27:38
# Train 16 arrives in Block0  at 02:31:34
# Train 16 leaves Block0 at 02:31:34
# Train 11 arrives in Birmingham  Interchange at 02:32:08
# Train 13 reaches end of signalling block 3 at 02:35:30
# Train 12 arrives in Block5 at 02:35:59
# Train 12 leaves Block5 at 02:35:59
# Train 13 enters signalling block 4 at 02:35:59
# Train 15 reaches end of signalling block 1 at 02:35:59
# Train 14 reaches end of signalling block 2 at 02:37:06
# Train 14 enters signalling block 3 at 02:37:06
# Train 15 enters signalling block 2 at 02:37:06
# Train 16 enters signalling block 1 at 02:37:06
# Train 17 leaves London Old Oak  common at 02:37:06
# Train 12 is at Block number6 Block 02:40:29
# Train 17 arrives in Block0  at 02:42:06
# Train 17 leaves Block0 at 02:42:06
# Train 13 arrives in Block5 at 02:44:43
# Train 13 leaves Block5 at 02:44:43
# Train 16 reaches end of signalling block 1 at 02:44:48
# Train 12 arrives in Birmingham  Interchange at 02:44:59
# Train 14 reaches end of signalling block 3 at 02:45:46
# Train 14 enters signalling block 4 at 02:45:46
# Train 15 reaches end of signalling block 2 at 02:47:11
# Train 15 enters signalling block 3 at 02:47:11
# Train 16 enters signalling block 2 at 02:47:11
# Train 17 enters signalling block 1 at 02:47:11
# Train 18 leaves London Old Oak  common at 02:47:11
# Train 13 is at Block number6 Block 02:49:13
# Train 18 arrives in Block0  at 02:52:11
# Train 18 leaves Block0 at 02:52:11
# Train 13 arrives in Birmingham  Interchange at 02:53:43
# Train 15 reaches end of signalling block 3 at 02:55:41
# Train 14 arrives in Block5 at 02:55:58
# Train 14 leaves Block5 at 02:55:58
# Train 15 enters signalling block 4 at 02:55:58
# Train 16 reaches end of signalling block 2 at 02:56:24
# Train 16 enters signalling block 3 at 02:56:24
# Train 17 reaches end of signalling block 1 at 02:57:13
# Train 17 enters signalling block 2 at 02:57:13
# Train 18 enters signalling block 1 at 02:57:13
# Train 19 leaves London Old Oak  common at 02:57:13
# Train 14 is at Block number6 Block 03:00:28
# Train 19 arrives in Block0  at 03:02:13
# Train 19 leaves Block0 at 03:02:13
# Train 16 reaches end of signalling block 3 at 03:04:06
# Train 14 arrives in Birmingham  Interchange at 03:04:58
# Train 17 reaches end of signalling block 2 at 03:06:00
# Train 15 arrives in Block5 at 03:06:42
# Train 15 leaves Block5 at 03:06:42
# Train 16 enters signalling block 4 at 03:06:42
# Train 17 enters signalling block 3 at 03:06:42
# Train 18 reaches end of signalling block 1 at 03:06:49
# Train 18 enters signalling block 2 at 03:06:49
# Train 19 enters signalling block 1 at 03:06:49
# Train 20 leaves London Old Oak  common at 03:06:49
# Train 15 is at Block number6 Block 03:11:12
# Train 20 arrives in Block0  at 03:11:49
# Train 20 leaves Block0 at 03:11:49
# Train 18 reaches end of signalling block 2 at 03:14:23
# Train 16 arrives in Block5 at 03:15:41
# Train 16 leaves Block5 at 03:15:41
# Train 15 arrives in Birmingham  Interchange at 03:15:42
# Train 19 reaches end of signalling block 1 at 03:16:43
# Train 17 reaches end of signalling block 3 at 03:17:04
# Train 17 enters signalling block 4 at 03:17:04
# Train 18 enters signalling block 3 at 03:17:04
# Train 19 enters signalling block 2 at 03:17:04
# Train 20 enters signalling block 1 at 03:17:04
# Train 21 leaves London Old Oak  common at 03:17:04
# Train 16 is at Block number6 Block 03:20:11
# Train 21 arrives in Block0  at 03:22:04
# Train 21 leaves Block0 at 03:22:04
# Train 16 arrives in Birmingham  Interchange at 03:24:41
# Train 20 reaches end of signalling block 1 at 03:25:27
# Train 18 reaches end of signalling block 3 at 03:26:40
# Train 17 arrives in Block5 at 03:27:02
# Train 17 leaves Block5 at 03:27:02
# Train 18 enters signalling block 4 at 03:27:02
# Train 19 reaches end of signalling block 2 at 03:27:41
# Train 19 enters signalling block 3 at 03:27:41
# Train 20 enters signalling block 2 at 03:27:41
# Train 21 enters signalling block 1 at 03:27:41
# Train 22 leaves London Old Oak  common at 03:27:41
# Train 17 is at Block number6 Block 03:31:32
# Train 22 arrives in Block0  at 03:32:41
# Train 22 leaves Block0 at 03:32:41
# Train 17 arrives in Birmingham  Interchange at 03:36:02
# Train 19 reaches end of signalling block 3 at 03:36:34
# Train 21 reaches end of signalling block 1 at 03:36:56
# Train 18 arrives in Block5 at 03:37:39
# Train 18 leaves Block5 at 03:37:39
# Train 19 enters signalling block 4 at 03:37:39
# Train 20 reaches end of signalling block 2 at 03:37:56
# Train 20 enters signalling block 3 at 03:37:56
# Train 21 enters signalling block 2 at 03:37:56
# Train 22 enters signalling block 1 at 03:37:56
# Train 23 leaves London Old Oak  common at 03:37:56
# Train 18 is at Block number6 Block 03:42:09
# Train 23 arrives in Block0  at 03:42:56
# Train 23 leaves Block0 at 03:42:56
# Train 21 reaches end of signalling block 2 at 03:46:05
# Train 18 arrives in Birmingham  Interchange at 03:46:39
# Train 22 reaches end of signalling block 1 at 03:47:20
# Train 19 arrives in Block5 at 03:47:59
# Train 19 leaves Block5 at 03:47:59
# Train 20 reaches end of signalling block 3 at 03:48:14
# Train 20 enters signalling block 4 at 03:48:14
# Train 21 enters signalling block 3 at 03:48:14
# Train 22 enters signalling block 2 at 03:48:14
# Train 23 enters signalling block 1 at 03:48:14
# Train 24 leaves London Old Oak  common at 03:48:14
# Train 19 is at Block number6 Block 03:52:29
# Train 24 arrives in Block0  at 03:53:14
# Train 24 leaves Block0 at 03:53:14
# Train 19 arrives in Birmingham  Interchange at 03:56:59
# Train 22 reaches end of signalling block 2 at 03:57:04
# Train 21 reaches end of signalling block 3 at 03:57:34
# Train 20 arrives in Block5 at 03:57:42
# Train 20 leaves Block5 at 03:57:42
# Train 21 enters signalling block 4 at 03:57:42
# Train 22 enters signalling block 3 at 03:57:42
# Train 23 reaches end of signalling block 1 at 03:59:33
# Train 23 enters signalling block 2 at 03:59:33
# Train 24 enters signalling block 1 at 03:59:33
# Train 25 leaves London Old Oak  common at 03:59:33
# Train 20 is at Block number6 Block 04:02:12
# Train 25 arrives in Block0  at 04:04:33
# Train 25 leaves Block0 at 04:04:33
# Train 20 arrives in Birmingham  Interchange at 04:06:42
# Train 21 arrives in Block5 at 04:07:27
# Train 21 leaves Block5 at 04:07:27
# Train 24 reaches end of signalling block 1 at 04:08:06
# Train 23 reaches end of signalling block 2 at 04:08:34
# Train 22 reaches end of signalling block 3 at 04:08:44
# Train 22 enters signalling block 4 at 04:08:44
# Train 23 enters signalling block 3 at 04:08:44
# Train 24 enters signalling block 2 at 04:08:44
# Train 25 enters signalling block 1 at 04:08:44
# Train 26 leaves London Old Oak  common at 04:08:44
# Train 21 is at Block number6 Block 04:11:57
# Train 26 arrives in Block0  at 04:13:44
# Train 26 leaves Block0 at 04:13:44
# Train 21 arrives in Birmingham  Interchange at 04:16:27
# Train 23 reaches end of signalling block 3 at 04:17:45
# Train 22 arrives in Block5 at 04:18:25
# Train 22 leaves Block5 at 04:18:25
# Train 23 enters signalling block 4 at 04:18:25
# Train 25 reaches end of signalling block 1 at 04:18:32
# Train 24 reaches end of signalling block 2 at 04:20:35
# Train 24 enters signalling block 3 at 04:20:35
# Train 25 enters signalling block 2 at 04:20:35
# Train 26 enters signalling block 1 at 04:20:35
# Train 27 leaves London Old Oak  common at 04:20:35
# Train 22 is at Block number6 Block 04:22:55
# Train 27 arrives in Block0  at 04:25:35
# Train 27 leaves Block0 at 04:25:35
# Train 22 arrives in Birmingham  Interchange at 04:27:25
# Train 23 arrives in Block5 at 04:29:05
# Train 23 leaves Block5 at 04:29:05
# Train 25 reaches end of signalling block 2 at 04:29:49
# Train 24 reaches end of signalling block 3 at 04:29:55
# Train 24 enters signalling block 4 at 04:29:55
# Train 25 enters signalling block 3 at 04:29:55
# Train 26 reaches end of signalling block 1 at 04:30:06
# Train 26 enters signalling block 2 at 04:30:06
# Train 27 enters signalling block 1 at 04:30:06
# Train 28 leaves London Old Oak  common at 04:30:06
# Train 23 is at Block number6 Block 04:33:35
# Train 28 arrives in Block0  at 04:35:06
# Train 28 leaves Block0 at 04:35:06
# Train 23 arrives in Birmingham  Interchange at 04:38:05
# Train 27 reaches end of signalling block 1 at 04:39:01
# Train 26 reaches end of signalling block 2 at 04:39:33
# Train 24 arrives in Block5 at 04:39:49
# Train 24 leaves Block5 at 04:39:49
# Train 25 reaches end of signalling block 3 at 04:40:17
# Train 25 enters signalling block 4 at 04:40:17
# Train 26 enters signalling block 3 at 04:40:17
# Train 27 enters signalling block 2 at 04:40:17
# Train 28 enters signalling block 1 at 04:40:17
# Train 29 leaves London Old Oak  common at 04:40:17
# Train 24 is at Block number6 Block 04:44:19
# Train 29 arrives in Block0  at 04:45:17
# Train 29 leaves Block0 at 04:45:17
# Train 24 arrives in Birmingham  Interchange at 04:48:49
# Train 25 arrives in Block5 at 04:48:49
# Train 25 leaves Block5 at 04:48:49
# Train 26 reaches end of signalling block 3 at 04:49:46
# Train 26 enters signalling block 4 at 04:49:46
# Train 28 reaches end of signalling block 1 at 04:50:17
# Train 27 reaches end of signalling block 2 at 04:50:24
# Train 27 enters signalling block 3 at 04:50:24
# Train 28 enters signalling block 2 at 04:50:24
# Train 29 enters signalling block 1 at 04:50:24
# Train 30 leaves London Old Oak  common at 04:50:24
# Train 25 is at Block number6 Block 04:53:19
# Train 30 arrives in Block0  at 04:55:24
# Train 30 leaves Block0 at 04:55:24
# Train 25 arrives in Birmingham  Interchange at 04:57:49
# Train 26 arrives in Block5 at 04:59:19
# Train 26 leaves Block5 at 04:59:19
# Train 27 reaches end of signalling block 3 at 04:59:22
# Train 27 enters signalling block 4 at 04:59:22
# Train 28 reaches end of signalling block 2 at 05:00:05
# Train 28 enters signalling block 3 at 05:00:05
# Train 29 reaches end of signalling block 1 at 05:00:30
# Train 29 enters signalling block 2 at 05:00:30
# Train 30 enters signalling block 1 at 05:00:30
# Train 31 leaves London Old Oak  common at 05:00:30
# Train 26 is at Block number6 Block 05:03:49
# Train 31 arrives in Block0  at 05:05:30
# Train 31 leaves Block0 at 05:05:30
# Train 26 arrives in Birmingham  Interchange at 05:08:19
# Train 27 arrives in Block5 at 05:08:54
# Train 27 leaves Block5 at 05:08:54
# Train 28 reaches end of signalling block 3 at 05:09:45
# Train 28 enters signalling block 4 at 05:09:45
# Train 29 reaches end of signalling block 2 at 05:09:54
# Train 29 enters signalling block 3 at 05:09:54
# Train 30 reaches end of signalling block 1 at 05:10:55
# Train 30 enters signalling block 2 at 05:10:55
# Train 31 enters signalling block 1 at 05:10:55
# Train 32 leaves London Old Oak  common at 05:10:55
# Train 27 is at Block number6 Block 05:13:24
# Train 32 arrives in Block0  at 05:15:55
# Train 32 leaves Block0 at 05:15:55
# Train 27 arrives in Birmingham  Interchange at 05:17:54
# Train 28 arrives in Block5 at 05:18:53
# Train 28 leaves Block5 at 05:18:53
# Train 29 reaches end of signalling block 3 at 05:19:38
# Train 29 enters signalling block 4 at 05:19:38
# Train 30 reaches end of signalling block 2 at 05:20:51
# Train 30 enters signalling block 3 at 05:20:51
# Train 31 reaches end of signalling block 1 at 05:21:10
# Train 31 enters signalling block 2 at 05:21:10
# Train 32 enters signalling block 1 at 05:21:10
# Train 33 leaves London Old Oak  common at 05:21:10
# Train 28 is at Block number6 Block 05:23:23
# Train 33 arrives in Block0  at 05:26:10
# Train 33 leaves Block0 at 05:26:10
# Train 28 arrives in Birmingham  Interchange at 05:27:53
# Train 32 reaches end of signalling block 1 at 05:29:19
# Train 29 arrives in Block5 at 05:30:37
# Train 29 leaves Block5 at 05:30:37
# Train 30 reaches end of signalling block 3 at 05:31:03
# Train 30 enters signalling block 4 at 05:31:03
# Train 31 reaches end of signalling block 2 at 05:31:18
# Train 31 enters signalling block 3 at 05:31:18
# Train 32 enters signalling block 2 at 05:31:18
# Train 33 enters signalling block 1 at 05:31:18
# Train 34 leaves London Old Oak  common at 05:31:18
# Train 29 is at Block number6 Block 05:35:07
# Train 34 arrives in Block0  at 05:36:18
# Train 34 leaves Block0 at 05:36:18
# Train 29 arrives in Birmingham  Interchange at 05:39:37
# Train 33 reaches end of signalling block 1 at 05:39:53
# Train 32 reaches end of signalling block 2 at 05:40:04
# Train 30 arrives in Block5 at 05:41:12
# Train 30 leaves Block5 at 05:41:12
# Train 31 reaches end of signalling block 3 at 05:43:03
# Train 31 enters signalling block 4 at 05:43:03
# Train 32 enters signalling block 3 at 05:43:03
# Train 33 enters signalling block 2 at 05:43:03
# Train 34 enters signalling block 1 at 05:43:03
# Train 35 leaves London Old Oak  common at 05:43:03
# Train 30 is at Block number6 Block 05:45:42
# Train 35 arrives in Block0  at 05:48:03
# Train 35 leaves Block0 at 05:48:03
# Train 30 arrives in Birmingham  Interchange at 05:50:12
# Train 34 reaches end of signalling block 1 at 05:52:09
# Train 31 arrives in Block5 at 05:52:24
# Train 31 leaves Block5 at 05:52:24
# Train 33 reaches end of signalling block 2 at 05:53:06
# Train 32 reaches end of signalling block 3 at 05:53:35
# Train 32 enters signalling block 4 at 05:53:35
# Train 33 enters signalling block 3 at 05:53:35
# Train 34 enters signalling block 2 at 05:53:35
# Train 35 enters signalling block 1 at 05:53:35
# Train 36 leaves London Old Oak  common at 05:53:35
# Train 31 is at Block number6 Block 05:56:54
# Train 36 arrives in Block0  at 05:58:35
# Train 36 leaves Block0 at 05:58:35
# Train 31 arrives in Birmingham  Interchange at 06:01:24
# Train 32 arrives in Block5 at 06:03:06
# Train 32 leaves Block5 at 06:03:06
# Train 34 reaches end of signalling block 2 at 06:03:47
# Train 33 reaches end of signalling block 3 at 06:04:08
# Train 33 enters signalling block 4 at 06:04:08
# Train 34 enters signalling block 3 at 06:04:08
# Train 35 reaches end of signalling block 1 at 06:05:27
# Train 35 enters signalling block 2 at 06:05:27
# Train 36 enters signalling block 1 at 06:05:27
# Train 37 leaves London Old Oak  common at 06:05:27
# Train 32 is at Block number6 Block 06:07:36
# Train 37 arrives in Block0  at 06:10:27
# Train 37 leaves Block0 at 06:10:27
# Train 32 arrives in Birmingham  Interchange at 06:12:06
# Train 34 reaches end of signalling block 3 at 06:14:01
# Train 33 arrives in Block5 at 06:14:39
# Train 33 leaves Block5 at 06:14:39
# Train 34 enters signalling block 4 at 06:14:39
# Train 36 reaches end of signalling block 1 at 06:14:41
# Train 35 reaches end of signalling block 2 at 06:15:36
# Train 35 enters signalling block 3 at 06:15:36
# Train 36 enters signalling block 2 at 06:15:36
# Train 37 enters signalling block 1 at 06:15:36
# Train 38 leaves London Old Oak  common at 06:15:36
# Train 33 is at Block number6 Block 06:19:09
# Train 38 arrives in Block0  at 06:20:36
# Train 38 leaves Block0 at 06:20:36
# Train 34 arrives in Block5 at 06:23:16
# Train 34 leaves Block5 at 06:23:16
# Train 33 arrives in Birmingham  Interchange at 06:23:39
# Train 37 reaches end of signalling block 1 at 06:23:49
# Train 35 reaches end of signalling block 3 at 06:25:19
# Train 35 enters signalling block 4 at 06:25:19
# Train 36 reaches end of signalling block 2 at 06:25:37
# Train 36 enters signalling block 3 at 06:25:37
# Train 37 enters signalling block 2 at 06:25:37
# Train 38 enters signalling block 1 at 06:25:37
# Train 39 leaves London Old Oak  common at 06:25:37
# Train 34 is at Block number6 Block 06:27:46
# Train 39 arrives in Block0  at 06:30:37
# Train 39 leaves Block0 at 06:30:37
# Train 34 arrives in Birmingham  Interchange at 06:32:16
# Train 35 arrives in Block5 at 06:34:23
# Train 35 leaves Block5 at 06:34:23
# Train 36 reaches end of signalling block 3 at 06:34:50
# Train 36 enters signalling block 4 at 06:34:50
# Train 38 reaches end of signalling block 1 at 06:34:56
# Train 37 reaches end of signalling block 2 at 06:35:26
# Train 37 enters signalling block 3 at 06:35:26
# Train 38 enters signalling block 2 at 06:35:26
# Train 39 enters signalling block 1 at 06:35:26
# Train 40 leaves London Old Oak  common at 06:35:26
# Train 35 is at Block number6 Block 06:38:53
# Train 40 arrives in Block0  at 06:40:26
# Train 40 leaves Block0 at 06:40:26
# Train 39 reaches end of signalling block 1 at 06:43:21
# Train 35 arrives in Birmingham  Interchange at 06:43:23
# Train 36 arrives in Block5 at 06:44:48
# Train 36 leaves Block5 at 06:44:48
# Train 37 reaches end of signalling block 3 at 06:45:05
# Train 37 enters signalling block 4 at 06:45:05
# Train 38 reaches end of signalling block 2 at 06:46:00
# Train 38 enters signalling block 3 at 06:46:00
# Train 39 enters signalling block 2 at 06:46:00
# Train 40 enters signalling block 1 at 06:46:00
# Train 41 leaves London Old Oak  common at 06:46:00
# Train 36 is at Block number6 Block 06:49:18
# Train 41 arrives in Block0  at 06:51:00
# Train 41 leaves Block0 at 06:51:00
# Train 36 arrives in Birmingham  Interchange at 06:53:48
# Train 39 reaches end of signalling block 2 at 06:55:36
# Train 40 reaches end of signalling block 1 at 06:56:11
# Train 37 arrives in Block5 at 06:56:13
# Train 37 leaves Block5 at 06:56:13
# Train 38 reaches end of signalling block 3 at 06:56:55
# Train 38 enters signalling block 4 at 06:56:55
# Train 39 enters signalling block 3 at 06:56:55
# Train 40 enters signalling block 2 at 06:56:55
# Train 41 enters signalling block 1 at 06:56:55
# Train 42 leaves London Old Oak  common at 06:56:55
# Train 37 is at Block number6 Block 07:00:43
# Train 42 arrives in Block0  at 07:01:55
# Train 42 leaves Block0 at 07:01:55
# Train 37 arrives in Birmingham  Interchange at 07:05:13
# Train 39 reaches end of signalling block 3 at 07:05:46
# Train 40 reaches end of signalling block 2 at 07:06:38
# Train 38 arrives in Block5 at 07:07:03
# Train 38 leaves Block5 at 07:07:03
# Train 39 enters signalling block 4 at 07:07:03
# Train 40 enters signalling block 3 at 07:07:03
# Train 41 reaches end of signalling block 1 at 07:07:13
# Train 41 enters signalling block 2 at 07:07:13
# Train 42 enters signalling block 1 at 07:07:13
# Train 43 leaves London Old Oak  common at 07:07:13
# Train 38 is at Block number6 Block 07:11:33
# Train 43 arrives in Block0  at 07:12:13
# Train 43 leaves Block0 at 07:12:13
# Train 38 arrives in Birmingham  Interchange at 07:16:03
# Train 42 reaches end of signalling block 1 at 07:16:51
# Train 41 reaches end of signalling block 2 at 07:16:51
# Train 39 arrives in Block5 at 07:16:54
# Train 39 leaves Block5 at 07:16:54
# Train 40 reaches end of signalling block 3 at 07:17:36
# Train 40 enters signalling block 4 at 07:17:36
# Train 41 enters signalling block 3 at 07:17:36
# Train 42 enters signalling block 2 at 07:17:36
# Train 43 enters signalling block 1 at 07:17:36
# Train 44 leaves London Old Oak  common at 07:17:36
# Train 39 is at Block number6 Block 07:21:24
# Train 44 arrives in Block0  at 07:22:36
# Train 44 leaves Block0 at 07:22:36
# Train 39 arrives in Birmingham  Interchange at 07:25:54
# Train 40 arrives in Block5 at 07:26:26
# Train 40 leaves Block5 at 07:26:26
# Train 42 reaches end of signalling block 2 at 07:26:43
# Train 41 reaches end of signalling block 3 at 07:26:49
# Train 41 enters signalling block 4 at 07:26:49
# Train 42 enters signalling block 3 at 07:26:49
# Train 43 reaches end of signalling block 1 at 07:28:48
# Train 43 enters signalling block 2 at 07:28:48
# Train 44 enters signalling block 1 at 07:28:48
# Train 45 leaves London Old Oak  common at 07:28:48
# Train 40 is at Block number6 Block 07:30:56
# Train 45 arrives in Block0  at 07:33:48
# Train 45 leaves Block0 at 07:33:48
# Train 42 reaches end of signalling block 3 at 07:35:25
# Train 40 arrives in Birmingham  Interchange at 07:35:26
# Train 41 arrives in Block5 at 07:36:36
# Train 41 leaves Block5 at 07:36:36
# Train 42 enters signalling block 4 at 07:36:36
# Train 44 reaches end of signalling block 1 at 07:38:10
# Train 43 reaches end of signalling block 2 at 07:38:44
# Train 43 enters signalling block 3 at 07:38:44
# Train 44 enters signalling block 2 at 07:38:44
# Train 45 enters signalling block 1 at 07:38:44
# Train 46 leaves London Old Oak  common at 07:38:44
# Train 41 is at Block number6 Block 07:41:06
# Train 42 arrives in Block5 at 07:43:14
# Train 42 leaves Block5 at 07:43:14
# Train 46 arrives in Block0  at 07:43:44
# Train 46 leaves Block0 at 07:43:44
# Train 41 arrives in Birmingham  Interchange at 07:45:36
# Train 44 reaches end of signalling block 2 at 07:46:48
# Train 42 is at Block number6 Block 07:47:44
# Train 43 reaches end of signalling block 3 at 07:48:45
# Train 43 enters signalling block 4 at 07:48:45
# Train 44 enters signalling block 3 at 07:48:45
# Train 45 reaches end of signalling block 1 at 07:48:50
# Train 45 enters signalling block 2 at 07:48:50
# Train 46 enters signalling block 1 at 07:48:50
# Train 47 leaves London Old Oak  common at 07:48:50
# Train 42 arrives in Birmingham  Interchange at 07:52:14
# Train 47 arrives in Block0  at 07:53:50
# Train 47 leaves Block0 at 07:53:50
# Train 44 reaches end of signalling block 3 at 07:56:54
# Train 46 reaches end of signalling block 1 at 07:56:58
# Train 43 arrives in Block5 at 07:57:23
# Train 43 leaves Block5 at 07:57:23
# Train 44 enters signalling block 4 at 07:57:23
# Train 45 reaches end of signalling block 2 at 07:58:52
# Train 45 enters signalling block 3 at 07:58:52
# Train 46 enters signalling block 2 at 07:58:52
# Train 47 enters signalling block 1 at 07:58:52
# Train 48 leaves London Old Oak  common at 07:58:52
# Train 43 is at Block number6 Block 08:01:53
# Train 48 arrives in Block0  at 08:03:52
# Train 48 leaves Block0 at 08:03:52
# Train 43 arrives in Birmingham  Interchange at 08:06:23
# Train 44 arrives in Block5 at 08:06:31
# Train 44 leaves Block5 at 08:06:31
# Train 45 reaches end of signalling block 3 at 08:08:37
# Train 45 enters signalling block 4 at 08:08:37
# Train 46 reaches end of signalling block 2 at 08:09:00
# Train 46 enters signalling block 3 at 08:09:00
# Train 47 reaches end of signalling block 1 at 08:09:08
# Train 47 enters signalling block 2 at 08:09:08
# Train 48 enters signalling block 1 at 08:09:08
# Train 49 leaves London Old Oak  common at 08:09:08
# Train 44 is at Block number6 Block 08:11:01
# Train 49 arrives in Block0  at 08:14:08
# Train 49 leaves Block0 at 08:14:08
# Train 44 arrives in Birmingham  Interchange at 08:15:31
# Train 46 reaches end of signalling block 3 at 08:17:46
# Train 48 reaches end of signalling block 1 at 08:18:07
# Train 45 arrives in Block5 at 08:18:08
# Train 45 leaves Block5 at 08:18:08
# Train 46 enters signalling block 4 at 08:18:08
# Train 47 reaches end of signalling block 2 at 08:20:32
# Train 47 enters signalling block 3 at 08:20:32
# Train 48 enters signalling block 2 at 08:20:32
# Train 49 enters signalling block 1 at 08:20:32
# Train 50 leaves London Old Oak  common at 08:20:32
# Train 45 is at Block number6 Block 08:22:38
# Train 50 arrives in Block0  at 08:25:32
# Train 50 leaves Block0 at 08:25:32
# Train 45 arrives in Birmingham  Interchange at 08:27:08
# Train 46 arrives in Block5 at 08:29:25
# Train 46 leaves Block5 at 08:29:25
# Train 47 reaches end of signalling block 3 at 08:29:39
# Train 47 enters signalling block 4 at 08:29:39
# Train 49 reaches end of signalling block 1 at 08:31:06
# Train 48 reaches end of signalling block 2 at 08:31:12
# Train 48 enters signalling block 3 at 08:31:12
# Train 49 enters signalling block 2 at 08:31:12
# Train 50 enters signalling block 1 at 08:31:12
# Train 51 leaves London Old Oak  common at 08:31:12
# Train 46 is at Block number6 Block 08:33:55
# Train 51 arrives in Block0  at 08:36:12
# Train 51 leaves Block0 at 08:36:12
# Train 47 arrives in Block5 at 08:38:12
# Train 47 leaves Block5 at 08:38:12
# Train 46 arrives in Birmingham  Interchange at 08:38:25
# Train 48 reaches end of signalling block 3 at 08:41:05
# Train 48 enters signalling block 4 at 08:41:05
# Train 50 reaches end of signalling block 1 at 08:41:25
# Train 49 reaches end of signalling block 2 at 08:41:28
# Train 49 enters signalling block 3 at 08:41:28
# Train 50 enters signalling block 2 at 08:41:28
# Train 51 enters signalling block 1 at 08:41:28
# Train 52 leaves London Old Oak  common at 08:41:28
# Train 47 is at Block number6 Block 08:42:42
# Train 52 arrives in Block0  at 08:46:28
# Train 52 leaves Block0 at 08:46:28
# Train 47 arrives in Birmingham  Interchange at 08:47:12
# Train 51 reaches end of signalling block 1 at 08:49:54
# Train 48 arrives in Block5 at 08:50:27
# Train 48 leaves Block5 at 08:50:27
# Train 50 reaches end of signalling block 2 at 08:50:39
# Train 49 reaches end of signalling block 3 at 08:51:19
# Train 49 enters signalling block 4 at 08:51:19
# Train 50 enters signalling block 3 at 08:51:19
# Train 51 enters signalling block 2 at 08:51:19
# Train 52 enters signalling block 1 at 08:51:19
# Train 53 leaves London Old Oak  common at 08:51:19
# Train 48 is at Block number6 Block 08:54:57
# Train 53 arrives in Block0  at 08:56:19
# Train 53 leaves Block0 at 08:56:19
# Train 48 arrives in Birmingham  Interchange at 08:59:27
# Train 50 reaches end of signalling block 3 at 09:00:20
# Train 52 reaches end of signalling block 1 at 09:01:27
# Train 49 arrives in Block5 at 09:01:49
# Train 49 leaves Block5 at 09:01:49
# Train 50 enters signalling block 4 at 09:01:49
# Train 51 reaches end of signalling block 2 at 09:02:11
# Train 51 enters signalling block 3 at 09:02:11
# Train 52 enters signalling block 2 at 09:02:11
# Train 53 enters signalling block 1 at 09:02:11
# Train 54 leaves London Old Oak  common at 09:02:11
# Train 49 is at Block number6 Block 09:06:19
# Train 54 arrives in Block0  at 09:07:11
# Train 54 leaves Block0 at 09:07:11
# Train 50 arrives in Block5 at 09:10:31
# Train 50 leaves Block5 at 09:10:31
# Train 49 arrives in Birmingham  Interchange at 09:10:49
# Train 53 reaches end of signalling block 1 at 09:10:55
# Train 52 reaches end of signalling block 2 at 09:11:28
# Train 51 reaches end of signalling block 3 at 09:11:35
# Train 51 enters signalling block 4 at 09:11:35
# Train 52 enters signalling block 3 at 09:11:35
# Train 53 enters signalling block 2 at 09:11:35
# Train 54 enters signalling block 1 at 09:11:35
# Train 55 leaves London Old Oak  common at 09:11:35
# Train 50 is at Block number6 Block 09:15:01
# Train 55 arrives in Block0  at 09:16:35
# Train 55 leaves Block0 at 09:16:35
# Train 50 arrives in Birmingham  Interchange at 09:19:31
# Train 52 reaches end of signalling block 3 at 09:20:41
# Train 51 arrives in Block5 at 09:21:37
# Train 51 leaves Block5 at 09:21:37
# Train 52 enters signalling block 4 at 09:21:37
# Train 54 reaches end of signalling block 1 at 09:21:58
# Train 53 reaches end of signalling block 2 at 09:22:42
# Train 53 enters signalling block 3 at 09:22:42
# Train 54 enters signalling block 2 at 09:22:42
# Train 55 enters signalling block 1 at 09:22:42
# Train 56 leaves London Old Oak  common at 09:22:42
# Train 51 is at Block number6 Block 09:26:07
# Train 56 arrives in Block0  at 09:27:42
# Train 56 leaves Block0 at 09:27:42
# Train 52 arrives in Block5 at 09:30:20
# Train 52 leaves Block5 at 09:30:20
# Train 51 arrives in Birmingham  Interchange at 09:30:37
# Train 55 reaches end of signalling block 1 at 09:30:46
# Train 54 reaches end of signalling block 2 at 09:32:03
# Train 53 reaches end of signalling block 3 at 09:32:15
# Train 53 enters signalling block 4 at 09:32:15
# Train 54 enters signalling block 3 at 09:32:15
# Train 55 enters signalling block 2 at 09:32:15
# Train 56 enters signalling block 1 at 09:32:15
# Train 57 leaves London Old Oak  common at 09:32:15
# Train 52 is at Block number6 Block 09:34:50
# Train 57 arrives in Block0  at 09:37:15
# Train 57 leaves Block0 at 09:37:15
# Train 52 arrives in Birmingham  Interchange at 09:39:20
# Train 56 reaches end of signalling block 1 at 09:41:22
# Train 55 reaches end of signalling block 2 at 09:42:41
# Train 53 arrives in Block5 at 09:42:41
# Train 53 leaves Block5 at 09:42:41
# Train 54 reaches end of signalling block 3 at 09:42:42
# Train 54 enters signalling block 4 at 09:42:42
# Train 55 enters signalling block 3 at 09:42:42
# Train 56 enters signalling block 2 at 09:42:42
# Train 57 enters signalling block 1 at 09:42:42
# Train 58 leaves London Old Oak  common at 09:42:42
# Train 53 is at Block number6 Block 09:47:11
# Train 58 arrives in Block0  at 09:47:42
# Train 58 leaves Block0 at 09:47:42
# Train 53 arrives in Birmingham  Interchange at 09:51:41
# Train 55 reaches end of signalling block 3 at 09:52:04
# Train 56 reaches end of signalling block 2 at 09:53:09
# Train 54 arrives in Block5 at 09:53:17
# Train 54 leaves Block5 at 09:53:17
# Train 55 enters signalling block 4 at 09:53:17
# Train 56 enters signalling block 3 at 09:53:17
# Train 57 reaches end of signalling block 1 at 09:54:00
# Train 57 enters signalling block 2 at 09:54:00
# Train 58 enters signalling block 1 at 09:54:00
# Train 59 leaves London Old Oak  common at 09:54:00
# Train 54 is at Block number6 Block 09:57:47
# Train 59 arrives in Block0  at 09:59:00
# Train 59 leaves Block0 at 09:59:00
# Train 56 reaches end of signalling block 3 at 10:01:29
# Train 54 arrives in Birmingham  Interchange at 10:02:17
# Train 55 arrives in Block5 at 10:02:58
# Train 55 leaves Block5 at 10:02:58
# Train 56 enters signalling block 4 at 10:02:58
# Train 57 reaches end of signalling block 2 at 10:03:15
# Train 57 enters signalling block 3 at 10:03:15
# Train 58 reaches end of signalling block 1 at 10:04:10
# Train 58 enters signalling block 2 at 10:04:10
# Train 59 enters signalling block 1 at 10:04:10
# Train 60 leaves London Old Oak  common at 10:04:10
# Train 55 is at Block number6 Block 10:07:28
# Train 60 arrives in Block0  at 10:09:10
# Train 60 leaves Block0 at 10:09:10
# Train 57 reaches end of signalling block 3 at 10:11:43
# Train 55 arrives in Birmingham  Interchange at 10:11:58
# Train 58 reaches end of signalling block 2 at 10:13:32
# Train 56 arrives in Block5 at 10:13:42
# Train 56 leaves Block5 at 10:13:42
# Train 57 enters signalling block 4 at 10:13:42
# Train 58 enters signalling block 3 at 10:13:42
# Train 59 reaches end of signalling block 1 at 10:13:56
# Train 59 enters signalling block 2 at 10:13:56
# Train 60 enters signalling block 1 at 10:13:56
# Train 61 leaves London Old Oak  common at 10:13:56
# Train 56 is at Block number6 Block 10:18:12
# Train 61 arrives in Block0  at 10:18:56
# Train 61 leaves Block0 at 10:18:56
# Train 59 reaches end of signalling block 2 at 10:22:35
# Train 56 arrives in Birmingham  Interchange at 10:22:42
# Train 60 reaches end of signalling block 1 at 10:23:05
# Train 57 arrives in Block5 at 10:23:40
# Train 57 leaves Block5 at 10:23:40
# Train 58 reaches end of signalling block 3 at 10:24:07
# Train 58 enters signalling block 4 at 10:24:07
# Train 59 enters signalling block 3 at 10:24:07
# Train 60 enters signalling block 2 at 10:24:07
# Train 61 enters signalling block 1 at 10:24:07
# Train 62 leaves London Old Oak  common at 10:24:07
# Train 57 is at Block number6 Block 10:28:10
# Train 62 arrives in Block0  at 10:29:07
# Train 62 leaves Block0 at 10:29:07
# Train 57 arrives in Birmingham  Interchange at 10:32:40
# Train 59 reaches end of signalling block 3 at 10:34:03
# Train 60 reaches end of signalling block 2 at 10:34:06
# Train 58 arrives in Block5 at 10:34:38
# Train 58 leaves Block5 at 10:34:38
# Train 59 enters signalling block 4 at 10:34:38
# Train 60 enters signalling block 3 at 10:34:38
# Train 61 reaches end of signalling block 1 at 10:34:45
# Train 61 enters signalling block 2 at 10:34:45
# Train 62 enters signalling block 1 at 10:34:45
# Train 63 leaves London Old Oak  common at 10:34:45
# Train 58 is at Block number6 Block 10:39:08
# Train 63 arrives in Block0  at 10:39:45
# Train 63 leaves Block0 at 10:39:45
# Train 62 reaches end of signalling block 1 at 10:43:01
# Train 58 arrives in Birmingham  Interchange at 10:43:38
# Train 61 reaches end of signalling block 2 at 10:44:00
# Train 59 arrives in Block5 at 10:44:18
# Train 59 leaves Block5 at 10:44:18
# Train 60 reaches end of signalling block 3 at 10:44:42
# Train 60 enters signalling block 4 at 10:44:42
# Train 61 enters signalling block 3 at 10:44:42
# Train 62 enters signalling block 2 at 10:44:42
# Train 63 enters signalling block 1 at 10:44:42
# Train 64 leaves London Old Oak  common at 10:44:42
# Train 59 is at Block number6 Block 10:48:48
# Train 64 arrives in Block0  at 10:49:42
# Train 64 leaves Block0 at 10:49:42
# Train 60 arrives in Block5 at 10:53:01
# Train 60 leaves Block5 at 10:53:01
# Train 59 arrives in Birmingham  Interchange at 10:53:18
# Train 63 reaches end of signalling block 1 at 10:53:38
# Train 62 reaches end of signalling block 2 at 10:54:04
# Train 61 reaches end of signalling block 3 at 10:54:19
# Train 61 enters signalling block 4 at 10:54:19
# Train 62 enters signalling block 3 at 10:54:19
# Train 63 enters signalling block 2 at 10:54:19
# Train 64 enters signalling block 1 at 10:54:19
# Train 65 leaves London Old Oak  common at 10:54:19
# Train 60 is at Block number6 Block 10:57:31
# Train 65 arrives in Block0  at 10:59:19
# Train 65 leaves Block0 at 10:59:19
# Train 60 arrives in Birmingham  Interchange at 11:02:01
# Train 62 reaches end of signalling block 3 at 11:03:02
# Train 64 reaches end of signalling block 1 at 11:03:52
# Train 63 reaches end of signalling block 2 at 11:03:59
# Train 61 arrives in Block5 at 11:04:11
# Train 61 leaves Block5 at 11:04:11
# Train 62 enters signalling block 4 at 11:04:11
# Train 63 enters signalling block 3 at 11:04:11
# Train 64 enters signalling block 2 at 11:04:11
# Train 65 enters signalling block 1 at 11:04:11
# Train 66 leaves London Old Oak  common at 11:04:11
# Train 61 is at Block number6 Block 11:08:41
# Train 66 arrives in Block0  at 11:09:11
# Train 66 leaves Block0 at 11:09:11
# Train 63 reaches end of signalling block 3 at 11:11:33
# Train 62 arrives in Block5 at 11:12:56
# Train 62 leaves Block5 at 11:12:56
# Train 63 enters signalling block 4 at 11:12:56
# Train 61 arrives in Birmingham  Interchange at 11:13:11
# Train 65 reaches end of signalling block 1 at 11:14:02
# Train 64 reaches end of signalling block 2 at 11:15:08
# Train 64 enters signalling block 3 at 11:15:08
# Train 65 enters signalling block 2 at 11:15:08
# Train 66 enters signalling block 1 at 11:15:08
# Train 67 leaves London Old Oak  common at 11:15:08
# Train 62 is at Block number6 Block 11:17:26
# Train 63 arrives in Block5 at 11:19:57
# Train 63 leaves Block5 at 11:19:57
# Train 67 arrives in Block0  at 11:20:08
# Train 67 leaves Block0 at 11:20:08
# Train 62 arrives in Birmingham  Interchange at 11:21:56
# Train 64 reaches end of signalling block 3 at 11:24:17
# Train 64 enters signalling block 4 at 11:24:17
# Train 63 is at Block number6 Block 11:24:27
# Train 66 reaches end of signalling block 1 at 11:24:28
# Train 65 reaches end of signalling block 2 at 11:25:04
# Train 65 enters signalling block 3 at 11:25:04
# Train 66 enters signalling block 2 at 11:25:04
# Train 67 enters signalling block 1 at 11:25:04
# Train 68 leaves London Old Oak  common at 11:25:04
# Train 63 arrives in Birmingham  Interchange at 11:28:57
# Train 68 arrives in Block0  at 11:30:04
# Train 68 leaves Block0 at 11:30:04
# Train 65 reaches end of signalling block 3 at 11:33:41
# Train 64 arrives in Block5 at 11:34:23
# Train 64 leaves Block5 at 11:34:23
# Train 65 enters signalling block 4 at 11:34:23
# Train 67 reaches end of signalling block 1 at 11:34:34
# Train 66 reaches end of signalling block 2 at 11:34:47
# Train 66 enters signalling block 3 at 11:34:47
# Train 67 enters signalling block 2 at 11:34:47
# Train 68 enters signalling block 1 at 11:34:47
# Train 69 leaves London Old Oak  common at 11:34:47
# Train 64 is at Block number6 Block 11:38:53
# Train 69 arrives in Block0  at 11:39:47
# Train 69 leaves Block0 at 11:39:47
# Train 64 arrives in Birmingham  Interchange at 11:43:23
# Train 65 arrives in Block5 at 11:43:46
# Train 65 leaves Block5 at 11:43:46
# Train 66 reaches end of signalling block 3 at 11:44:08
# Train 66 enters signalling block 4 at 11:44:08
# Train 67 reaches end of signalling block 2 at 11:44:32
# Train 67 enters signalling block 3 at 11:44:32
# Train 68 reaches end of signalling block 1 at 11:45:14
# Train 68 enters signalling block 2 at 11:45:14
# Train 69 enters signalling block 1 at 11:45:14
# Train 70 leaves London Old Oak  common at 11:45:14
# Train 65 is at Block number6 Block 11:48:16
# Train 70 arrives in Block0  at 11:50:14
# Train 70 leaves Block0 at 11:50:14
# Train 65 arrives in Birmingham  Interchange at 11:52:46
# Train 66 arrives in Block5 at 11:53:11
# Train 66 leaves Block5 at 11:53:11
# Train 67 reaches end of signalling block 3 at 11:53:42
# Train 67 enters signalling block 4 at 11:53:42
# Train 69 reaches end of signalling block 1 at 11:54:40
# Train 68 reaches end of signalling block 2 at 11:54:56
# Train 68 enters signalling block 3 at 11:54:56
# Train 69 enters signalling block 2 at 11:54:56
# Train 70 enters signalling block 1 at 11:54:56
# Train 71 leaves London Old Oak  common at 11:54:56
# Train 66 is at Block number6 Block 11:57:41
# Train 71 arrives in Block0  at 11:59:56
# Train 71 leaves Block0 at 11:59:56
# Train 66 arrives in Birmingham  Interchange at 12:02:11
# Train 67 arrives in Block5 at 12:03:37
# Train 67 leaves Block5 at 12:03:37
# Train 70 reaches end of signalling block 1 at 12:04:23
# Train 68 reaches end of signalling block 3 at 12:05:11
# Train 68 enters signalling block 4 at 12:05:11
# Train 69 reaches end of signalling block 2 at 12:05:44
# Train 69 enters signalling block 3 at 12:05:44
# Train 70 enters signalling block 2 at 12:05:44
# Train 71 enters signalling block 1 at 12:05:44
# Train 72 leaves London Old Oak  common at 12:05:44
# Train 67 is at Block number6 Block 12:08:07
# Train 72 arrives in Block0  at 12:10:44
# Train 72 leaves Block0 at 12:10:44
# Train 68 arrives in Block5 at 12:12:34
# Train 68 leaves Block5 at 12:12:34
# Train 67 arrives in Birmingham  Interchange at 12:12:37
# Train 71 reaches end of signalling block 1 at 12:15:06
# Train 69 reaches end of signalling block 3 at 12:15:13
# Train 69 enters signalling block 4 at 12:15:13
# Train 70 reaches end of signalling block 2 at 12:15:37
# Train 70 enters signalling block 3 at 12:15:37
# Train 71 enters signalling block 2 at 12:15:37
# Train 72 enters signalling block 1 at 12:15:37
# Train 73 leaves London Old Oak  common at 12:15:37
# Train 68 is at Block number6 Block 12:17:04
# Train 73 arrives in Block0  at 12:20:37
# Train 73 leaves Block0 at 12:20:37
# Train 68 arrives in Birmingham  Interchange at 12:21:34
# Train 70 reaches end of signalling block 3 at 12:22:51
# Train 69 arrives in Block5 at 12:24:38
# Train 69 leaves Block5 at 12:24:38
# Train 70 enters signalling block 4 at 12:24:38
# Train 72 reaches end of signalling block 1 at 12:24:52
# Train 71 reaches end of signalling block 2 at 12:25:40
# Train 71 enters signalling block 3 at 12:25:40
# Train 72 enters signalling block 2 at 12:25:40
# Train 73 enters signalling block 1 at 12:25:40
# Train 74 leaves London Old Oak  common at 12:25:40
# Train 69 is at Block number6 Block 12:29:08
# Train 74 arrives in Block0  at 12:30:40
# Train 74 leaves Block0 at 12:30:40
# Train 70 arrives in Block5 at 12:32:44
# Train 70 leaves Block5 at 12:32:44
# Train 69 arrives in Birmingham  Interchange at 12:33:38
# Train 71 reaches end of signalling block 3 at 12:34:23
# Train 71 enters signalling block 4 at 12:34:23
# Train 72 reaches end of signalling block 2 at 12:34:24
# Train 72 enters signalling block 3 at 12:34:24
# Train 73 reaches end of signalling block 1 at 12:35:48
# Train 73 enters signalling block 2 at 12:35:48
# Train 74 enters signalling block 1 at 12:35:48
# Train 75 leaves London Old Oak  common at 12:35:48
# Train 70 is at Block number6 Block 12:37:14
# Train 75 arrives in Block0  at 12:40:48
# Train 75 leaves Block0 at 12:40:48
# Train 70 arrives in Birmingham  Interchange at 12:41:44
# Train 74 reaches end of signalling block 1 at 12:44:04
# Train 71 arrives in Block5 at 12:44:29
# Train 71 leaves Block5 at 12:44:29
# Train 72 reaches end of signalling block 3 at 12:45:24
# Train 72 enters signalling block 4 at 12:45:24
# Train 73 reaches end of signalling block 2 at 12:45:59
# Train 73 enters signalling block 3 at 12:45:59
# Train 74 enters signalling block 2 at 12:45:59
# Train 75 enters signalling block 1 at 12:45:59
# Train 76 leaves London Old Oak  common at 12:45:59
# Train 71 is at Block number6 Block 12:48:59
# Train 76 arrives in Block0  at 12:50:59
# Train 76 leaves Block0 at 12:50:59
# Train 71 arrives in Birmingham  Interchange at 12:53:29
# Train 72 arrives in Block5 at 12:53:36
# Train 72 leaves Block5 at 12:53:36
# Train 75 reaches end of signalling block 1 at 12:55:18
# Train 73 reaches end of signalling block 3 at 12:56:37
# Train 73 enters signalling block 4 at 12:56:37
# Train 74 reaches end of signalling block 2 at 12:57:02
# ...
# Train 105 leaves Block0 at 17:52:15
# Train 103 reaches end of signalling block 2 at 17:55:05
# Train 100 arrives in Birmingham  Interchange at 17:55:32
# Train 101 arrives in Block5 at 17:56:29
# Train 101 leaves Block5 at 17:56:29
# Train 104 reaches end of signalling block 1 at 17:56:37
# Train 102 reaches end of signalling block 3 at 17:56:40
# Train 102 enters signalling block 4 at 17:56:40
# Train 103 enters signalling block 3 at 17:56:40
# Train 104 enters signalling block 2 at 17:56:40
# Train 105 enters signalling block 1 at 17:56:40
# Train 106 leaves London Old Oak  common at 17:56:40
# Train 101 is at Block number6 Block 18:00:59
# Train 106 arrives in Block0  at 18:01:40
# Train 106 leaves Block0 at 18:01:40
# Train 101 arrives in Birmingham  Interchange at 18:05:29
# Train 105 reaches end of signalling block 1 at 18:05:48
# Train 103 reaches end of signalling block 3 at 18:06:16
# Train 104 reaches end of signalling block 2 at 18:06:30
# Train 102 arrives in Block5 at 18:08:22
# Train 102 leaves Block5 at 18:08:22
# Train 103 enters signalling block 4 at 18:08:22
# Train 104 enters signalling block 3 at 18:08:22
# Train 105 enters signalling block 2 at 18:08:22
# Train 106 enters signalling block 1 at 18:08:22
# Train 107 leaves London Old Oak  common at 18:08:22
# Train 102 is at Block number6 Block 18:12:52
# Train 107 arrives in Block0  at 18:13:22
# Train 107 leaves Block0 at 18:13:22
# Train 102 arrives in Birmingham  Interchange at 18:17:22
# Train 105 reaches end of signalling block 2 at 18:17:40
# Train 103 arrives in Block5 at 18:18:05
# Train 103 leaves Block5 at 18:18:05
# Train 104 reaches end of signalling block 3 at 18:18:05
# Train 104 enters signalling block 4 at 18:18:05
# Train 105 enters signalling block 3 at 18:18:05
# Train 106 reaches end of signalling block 1 at 18:18:44
# Train 106 enters signalling block 2 at 18:18:44
# Train 107 enters signalling block 1 at 18:18:44
# Train 108 leaves London Old Oak  common at 18:18:44
# Train 103 is at Block number6 Block 18:22:35
# Train 108 arrives in Block0  at 18:23:44
# Train 108 leaves Block0 at 18:23:44
# Train 104 arrives in Block5 at 18:26:46
# Train 104 leaves Block5 at 18:26:46
# Train 103 arrives in Birmingham  Interchange at 18:27:05
# Train 105 reaches end of signalling block 3 at 18:27:31
# Train 105 enters signalling block 4 at 18:27:31
# Train 107 reaches end of signalling block 1 at 18:28:03
# Train 106 reaches end of signalling block 2 at 18:28:47
# Train 106 enters signalling block 3 at 18:28:47
# Train 107 enters signalling block 2 at 18:28:47
# Train 108 enters signalling block 1 at 18:28:47
# Train 109 leaves London Old Oak  common at 18:28:47
# Train 104 is at Block number6 Block 18:31:16
# Train 109 arrives in Block0  at 18:33:47
# Train 109 leaves Block0 at 18:33:47
# Train 104 arrives in Birmingham  Interchange at 18:35:46
# Train 105 arrives in Block5 at 18:35:54
# Train 105 leaves Block5 at 18:35:54
# Train 107 reaches end of signalling block 2 at 18:37:24
# Train 108 reaches end of signalling block 1 at 18:37:54
# Train 106 reaches end of signalling block 3 at 18:38:52
# Train 106 enters signalling block 4 at 18:38:52
# Train 107 enters signalling block 3 at 18:38:52
# Train 108 enters signalling block 2 at 18:38:52
# Train 109 enters signalling block 1 at 18:38:52
# Train 110 leaves London Old Oak  common at 18:38:52
# Train 105 is at Block number6 Block 18:40:24
# Train 110 arrives in Block0  at 18:43:52
# Train 110 leaves Block0 at 18:43:52
# Train 105 arrives in Birmingham  Interchange at 18:44:54
# Train 106 arrives in Block5 at 18:47:38
# Train 106 leaves Block5 at 18:47:38
# Train 109 reaches end of signalling block 1 at 18:47:58
# Train 108 reaches end of signalling block 2 at 18:48:01
# Train 107 reaches end of signalling block 3 at 18:48:19
# Train 107 enters signalling block 4 at 18:48:19
# Train 108 enters signalling block 3 at 18:48:19
# Train 109 enters signalling block 2 at 18:48:19
# Train 110 enters signalling block 1 at 18:48:19
# Train 111 leaves London Old Oak  common at 18:48:19
# Train 106 is at Block number6 Block 18:52:08
# Train 111 arrives in Block0  at 18:53:19
# Train 111 leaves Block0 at 18:53:19
# Train 106 arrives in Birmingham  Interchange at 18:56:38
# Train 109 reaches end of signalling block 2 at 18:57:32
# Train 110 reaches end of signalling block 1 at 18:58:22
# Train 107 arrives in Block5 at 18:58:31
# Train 107 leaves Block5 at 18:58:31
# Train 108 reaches end of signalling block 3 at 18:59:34
# Train 108 enters signalling block 4 at 18:59:34
# Train 109 enters signalling block 3 at 18:59:34
# Train 110 enters signalling block 2 at 18:59:34
# Train 111 enters signalling block 1 at 18:59:34
# Train 112 leaves London Old Oak  common at 18:59:34
# Train 107 is at Block number6 Block 19:03:01
# Train 112 arrives in Block0  at 19:04:34
# Train 112 leaves Block0 at 19:04:34
# Train 107 arrives in Birmingham  Interchange at 19:07:31
# Train 108 arrives in Block5 at 19:08:46
# Train 108 leaves Block5 at 19:08:46
# Train 111 reaches end of signalling block 1 at 19:09:10
# Train 109 reaches end of signalling block 3 at 19:09:13
# Train 109 enters signalling block 4 at 19:09:13
# Train 110 reaches end of signalling block 2 at 19:10:11
# Train 110 enters signalling block 3 at 19:10:11
# Train 111 enters signalling block 2 at 19:10:11
# Train 112 enters signalling block 1 at 19:10:11
# Train 113 leaves London Old Oak  common at 19:10:11
# Train 108 is at Block number6 Block 19:13:16
# Train 113 arrives in Block0  at 19:15:11
# Train 113 leaves Block0 at 19:15:11
# Train 108 arrives in Birmingham  Interchange at 19:17:46
# Train 109 arrives in Block5 at 19:17:59
# Train 109 leaves Block5 at 19:17:59
# Train 110 reaches end of signalling block 3 at 19:19:03
# Train 110 enters signalling block 4 at 19:19:03
# Train 111 reaches end of signalling block 2 at 19:19:09
# Train 111 enters signalling block 3 at 19:19:09
# Train 112 reaches end of signalling block 1 at 19:19:44
# Train 112 enters signalling block 2 at 19:19:44
# Train 113 enters signalling block 1 at 19:19:44
# Train 114 leaves London Old Oak  common at 19:19:44
# Train 109 is at Block number6 Block 19:22:29
# Train 114 arrives in Block0  at 19:24:44
# Train 114 leaves Block0 at 19:24:44
# Train 109 arrives in Birmingham  Interchange at 19:26:59
# Train 111 reaches end of signalling block 3 at 19:27:25
# Train 112 reaches end of signalling block 2 at 19:28:18
# Train 113 reaches end of signalling block 1 at 19:28:24
# Train 110 arrives in Block5 at 19:29:26
# Train 110 leaves Block5 at 19:29:26
# Train 111 enters signalling block 4 at 19:29:26
# Train 112 enters signalling block 3 at 19:29:26
# Train 113 enters signalling block 2 at 19:29:26
# Train 114 enters signalling block 1 at 19:29:26
# Train 115 leaves London Old Oak  common at 19:29:26
# Train 110 is at Block number6 Block 19:33:56
# Train 115 arrives in Block0  at 19:34:26
# Train 115 leaves Block0 at 19:34:26
# Train 111 arrives in Block5 at 19:37:19
# Train 111 leaves Block5 at 19:37:19
# Train 110 arrives in Birmingham  Interchange at 19:38:26
# Train 113 reaches end of signalling block 2 at 19:38:57
# Train 112 reaches end of signalling block 3 at 19:40:15
# Train 112 enters signalling block 4 at 19:40:15
# Train 113 enters signalling block 3 at 19:40:15
# Train 114 reaches end of signalling block 1 at 19:40:48
# Train 114 enters signalling block 2 at 19:40:48
# Train 115 enters signalling block 1 at 19:40:48
# Train 116 leaves London Old Oak  common at 19:40:48
# Train 111 is at Block number6 Block 19:41:49
# Train 116 arrives in Block0  at 19:45:48
# Train 116 leaves Block0 at 19:45:48
# Train 111 arrives in Birmingham  Interchange at 19:46:19
# Train 112 arrives in Block5 at 19:48:27
# Train 112 leaves Block5 at 19:48:27
# Train 114 reaches end of signalling block 2 at 19:49:41
# Train 115 reaches end of signalling block 1 at 19:49:58
# Train 113 reaches end of signalling block 3 at 19:51:02
# Train 113 enters signalling block 4 at 19:51:02
# Train 114 enters signalling block 3 at 19:51:02
# Train 115 enters signalling block 2 at 19:51:02
# Train 116 enters signalling block 1 at 19:51:02
# Train 117 leaves London Old Oak  common at 19:51:02
# Train 112 is at Block number6 Block 19:52:57
# Train 117 arrives in Block0  at 19:56:02
# Train 117 leaves Block0 at 19:56:02
# Train 112 arrives in Birmingham  Interchange at 19:57:27
# Train 115 reaches end of signalling block 2 at 19:59:20
# Train 113 arrives in Block5 at 19:59:39
# Train 113 leaves Block5 at 19:59:39
# Train 114 reaches end of signalling block 3 at 19:59:41
# Train 114 enters signalling block 4 at 19:59:41
# Train 115 enters signalling block 3 at 19:59:41
# Train 116 reaches end of signalling block 1 at 20:00:48
# Train 116 enters signalling block 2 at 20:00:48
# Train 117 enters signalling block 1 at 20:00:48
# Train 118 leaves London Old Oak  common at 20:00:48
# Train 113 is at Block number6 Block 20:04:09
# Train 118 arrives in Block0  at 20:05:48
# Train 118 leaves Block0 at 20:05:48
# Train 114 arrives in Block5 at 20:07:59
# Train 114 leaves Block5 at 20:07:59
# Train 113 arrives in Birmingham  Interchange at 20:08:39
# Train 115 reaches end of signalling block 3 at 20:09:01
# Train 115 enters signalling block 4 at 20:09:01
# Train 116 reaches end of signalling block 2 at 20:10:21
# Train 116 enters signalling block 3 at 20:10:21
# Train 117 reaches end of signalling block 1 at 20:11:00
# Train 117 enters signalling block 2 at 20:11:00
# Train 118 enters signalling block 1 at 20:11:00
# Train 119 leaves London Old Oak  common at 20:11:00
# Train 114 is at Block number6 Block 20:12:29
# Train 119 arrives in Block0  at 20:16:00
# Train 119 leaves Block0 at 20:16:00
# Train 114 arrives in Birmingham  Interchange at 20:16:59
# Train 115 arrives in Block5 at 20:18:40
# Train 115 leaves Block5 at 20:18:40
# Train 116 reaches end of signalling block 3 at 20:20:13
# Train 116 enters signalling block 4 at 20:20:13
# Train 118 reaches end of signalling block 1 at 20:20:32
# Train 117 reaches end of signalling block 2 at 20:21:03
# Train 117 enters signalling block 3 at 20:21:03
# Train 118 enters signalling block 2 at 20:21:03
# Train 119 enters signalling block 1 at 20:21:03
# Train 120 leaves London Old Oak  common at 20:21:03
# Train 115 is at Block number6 Block 20:23:10
# Train 120 arrives in Block0  at 20:26:03
# Train 120 leaves Block0 at 20:26:03
# Train 115 arrives in Birmingham  Interchange at 20:27:40
# Train 117 reaches end of signalling block 3 at 20:29:40
# Train 118 reaches end of signalling block 2 at 20:29:51
# Train 116 arrives in Block5 at 20:30:07
# Train 116 leaves Block5 at 20:30:07
# Train 117 enters signalling block 4 at 20:30:07
# Train 118 enters signalling block 3 at 20:30:07
# Train 119 reaches end of signalling block 1 at 20:32:25
# Train 119 enters signalling block 2 at 20:32:25
# Train 120 enters signalling block 1 at 20:32:25
# Train 121 leaves London Old Oak  common at 20:32:25
# Train 116 is at Block number6 Block 20:34:37
# Train 121 arrives in Block0  at 20:37:25
# Train 121 leaves Block0 at 20:37:25
# Train 118 reaches end of signalling block 3 at 20:38:59
# Train 116 arrives in Birmingham  Interchange at 20:39:07
# Train 117 arrives in Block5 at 20:39:40
# Train 117 leaves Block5 at 20:39:40
# Train 118 enters signalling block 4 at 20:39:40
# Train 120 reaches end of signalling block 1 at 20:41:49
# Train 119 reaches end of signalling block 2 at 20:43:17
# Train 119 enters signalling block 3 at 20:43:17
# Train 120 enters signalling block 2 at 20:43:17
# Train 121 enters signalling block 1 at 20:43:17
# Train 122 leaves London Old Oak  common at 20:43:17
# Train 117 is at Block number6 Block 20:44:10
# Train 122 arrives in Block0  at 20:48:17
# Train 122 leaves Block0 at 20:48:17
# Train 118 arrives in Block5 at 20:48:36
# Train 118 leaves Block5 at 20:48:36
# Train 117 arrives in Birmingham  Interchange at 20:48:40
# Train 119 reaches end of signalling block 3 at 20:51:27
# Train 119 enters signalling block 4 at 20:51:27
# Train 121 reaches end of signalling block 1 at 20:51:48
# Train 118 is at Block number6 Block 20:53:06
# Train 120 reaches end of signalling block 2 at 20:53:35
# Train 120 enters signalling block 3 at 20:53:35
# Train 121 enters signalling block 2 at 20:53:35
# Train 122 enters signalling block 1 at 20:53:35
# Train 123 leaves London Old Oak  common at 20:53:35
# Train 118 arrives in Birmingham  Interchange at 20:57:36
# Train 123 arrives in Block0  at 20:58:35
# Train 123 leaves Block0 at 20:58:35
# Train 119 arrives in Block5 at 21:00:30
# Train 119 leaves Block5 at 21:00:30
# Train 122 reaches end of signalling block 1 at 21:03:04
# Train 121 reaches end of signalling block 2 at 21:03:19
# Train 120 reaches end of signalling block 3 at 21:03:45
# Train 120 enters signalling block 4 at 21:03:45
# Train 121 enters signalling block 3 at 21:03:45
# Train 122 enters signalling block 2 at 21:03:45
# Train 123 enters signalling block 1 at 21:03:45
# Train 124 leaves London Old Oak  common at 21:03:45
# Train 119 is at Block number6 Block 21:05:00
# Train 124 arrives in Block0  at 21:08:45
# Train 124 leaves Block0 at 21:08:45
# Train 119 arrives in Birmingham  Interchange at 21:09:30
# Train 123 reaches end of signalling block 1 at 21:12:47
# Train 120 arrives in Block5 at 21:13:06
# Train 120 leaves Block5 at 21:13:06
# Train 121 reaches end of signalling block 3 at 21:14:24
# Train 121 enters signalling block 4 at 21:14:24
# Train 122 reaches end of signalling block 2 at 21:15:27
# Train 122 enters signalling block 3 at 21:15:27
# Train 123 enters signalling block 2 at 21:15:27
# Train 124 enters signalling block 1 at 21:15:27
# Train 125 leaves London Old Oak  common at 21:15:27
# Train 120 is at Block number6 Block 21:17:36
# Train 125 arrives in Block0  at 21:20:27
# Train 125 leaves Block0 at 21:20:27
# Train 120 arrives in Birmingham  Interchange at 21:22:06
# Train 124 reaches end of signalling block 1 at 21:24:21
# Train 121 arrives in Block5 at 21:24:30
# Train 121 leaves Block5 at 21:24:30
# Train 123 reaches end of signalling block 2 at 21:26:02
# Train 122 reaches end of signalling block 3 at 21:26:51
# Train 122 enters signalling block 4 at 21:26:51
# Train 123 enters signalling block 3 at 21:26:51
# Train 124 enters signalling block 2 at 21:26:51
# Train 125 enters signalling block 1 at 21:26:51
# Train 126 leaves London Old Oak  common at 21:26:51
# Train 121 is at Block number6 Block 21:29:00
# Train 126 arrives in Block0  at 21:31:51
# Train 126 leaves Block0 at 21:31:51
# Train 121 arrives in Birmingham  Interchange at 21:33:30
# Train 124 reaches end of signalling block 2 at 21:35:31
# Train 125 reaches end of signalling block 1 at 21:35:48
# Train 123 reaches end of signalling block 3 at 21:35:50
# Train 122 arrives in Block5 at 21:35:59
# Train 122 leaves Block5 at 21:35:59
# Train 123 enters signalling block 4 at 21:35:59
# Train 124 enters signalling block 3 at 21:35:59
# Train 125 enters signalling block 2 at 21:35:59
# Train 126 enters signalling block 1 at 21:35:59
# Train 127 leaves London Old Oak  common at 21:35:59
# Train 122 is at Block number6 Block 21:40:29
# Train 127 arrives in Block0  at 21:40:59
# Train 127 leaves Block0 at 21:40:59
# Train 124 reaches end of signalling block 3 at 21:44:59
# Train 122 arrives in Birmingham  Interchange at 21:44:59
# Train 126 reaches end of signalling block 1 at 21:45:40
# Train 123 arrives in Block5 at 21:45:48
# Train 123 leaves Block5 at 21:45:48
# Train 124 enters signalling block 4 at 21:45:48
# Train 125 reaches end of signalling block 2 at 21:46:23
# Train 125 enters signalling block 3 at 21:46:23
# Train 126 enters signalling block 2 at 21:46:23
# Train 127 enters signalling block 1 at 21:46:23
# Train 128 leaves London Old Oak  common at 21:46:23
# Train 123 is at Block number6 Block 21:50:18
# Train 128 arrives in Block0  at 21:51:23
# Train 128 leaves Block0 at 21:51:23
# Train 123 arrives in Birmingham  Interchange at 21:54:48
# Train 124 arrives in Block5 at 21:54:58
# Train 124 leaves Block5 at 21:54:58
# Train 127 reaches end of signalling block 1 at 21:56:11
# Train 126 reaches end of signalling block 2 at 21:56:14
# Train 125 reaches end of signalling block 3 at 21:56:47
# Train 125 enters signalling block 4 at 21:56:47
# Train 126 enters signalling block 3 at 21:56:47
# Train 127 enters signalling block 2 at 21:56:47
# Train 128 enters signalling block 1 at 21:56:47
# Train 129 leaves London Old Oak  common at 21:56:47
# Train 124 is at Block number6 Block 21:59:28

# %%
# Merging all the separate dataframe into one dataframe
Simulation_Data = pd.concat([Sim_Data_1, Sim_Data_2, Sim_Data_3, Sim_Data_4], axis = 0, ignore_index=True)
Simulation_Data
# Out:
#      No_Blocks  Train_No Departure_Time Arrival_Time  Journey_Time  Day  \
# 0          3.0       1.0       00:00:00     00:44:39           NaN  1.0
# 1          3.0       2.0       00:10:00     01:04:11           NaN  1.0
# 2          3.0       3.0       00:20:00     01:15:47           NaN  1.0
# 3          3.0       4.0       00:30:00     01:29:20           NaN  1.0
# 4          3.0       5.0       00:41:13     01:39:55           NaN  1.0
# ..         ...       ...            ...          ...           ...  ...
# 324        4.0     119.0       20:11:00     21:09:30           NaN  1.0
# 325        4.0     120.0       20:21:03     21:22:06           NaN  1.0
# 326        4.0     121.0       20:32:25     21:33:30           NaN  1.0
# 327        4.0     122.0       20:43:17     21:44:59           NaN  1.0
# 328        4.0     123.0       20:53:35     21:54:48           NaN  1.0
#
#      Trains_PH  Delay  Train_Time_Interval
# 0          6.0    NaN            10.000000
# 1          6.0    NaN            10.000000
# 2          6.0    NaN            10.000000
# 3          6.0    NaN            10.000000
# 4          6.0    NaN            10.000000
# ..         ...    ...                  ...
# 324        9.0    NaN             6.666667
# 325        9.0    NaN             6.666667
# 326        9.0    NaN             6.666667
# 327        9.0    NaN             6.666667
# 328        9.0    NaN             6.666667
#
# [329 rows x 9 columns]

# %%
import datetime
format = '%H:%M:%S'
#expected_time=min(Sim_Data["Journey_Time"])


for i in range(len(Simulation_Data)):    
    startDateTime = datetime.datetime.strptime(Simulation_Data["Arrival_Time"][i], format)
    endDateTime = datetime.datetime.strptime(Simulation_Data["Departure_Time"][i], format)
    diff = abs(endDateTime - startDateTime)
    Simulation_Data["Journey_Time"][i] = str(diff)
    
    
     


Simulation_Data
# Out:
# C:\Users\harit\.conda\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\harit\.conda\envs\tensorflow\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      No_Blocks  Train_No Departure_Time Arrival_Time Journey_Time  Day  \
# 0          3.0       1.0       00:00:00     00:44:39      0:44:39  1.0
# 1          3.0       2.0       00:10:00     01:04:11      0:54:11  1.0
# 2          3.0       3.0       00:20:00     01:15:47      0:55:47  1.0
# 3          3.0       4.0       00:30:00     01:29:20      0:59:20  1.0
# 4          3.0       5.0       00:41:13     01:39:55      0:58:42  1.0
# ..         ...       ...            ...          ...          ...  ...
# 324        4.0     119.0       20:11:00     21:09:30      0:58:30  1.0
# 325        4.0     120.0       20:21:03     21:22:06      1:01:03  1.0
# 326        4.0     121.0       20:32:25     21:33:30      1:01:05  1.0
# 327        4.0     122.0       20:43:17     21:44:59      1:01:42  1.0
# 328        4.0     123.0       20:53:35     21:54:48      1:01:13  1.0
#
#      Trains_PH  Delay  Train_Time_Interval
# 0          6.0    NaN            10.000000
# 1          6.0    NaN            10.000000
# 2          6.0    NaN            10.000000
# 3          6.0    NaN            10.000000
# 4          6.0    NaN            10.000000
# ..         ...    ...                  ...
# 324        9.0    NaN             6.666667
# 325        9.0    NaN             6.666667
# 326        9.0    NaN             6.666667
# 327        9.0    NaN             6.666667
# 328        9.0    NaN             6.666667
#
# [329 rows x 9 columns]

# %%
expected_time=min(Simulation_Data["Journey_Time"])
for i in range(len(Simulation_Data)):        
    startDateTime = datetime.datetime.strptime(Simulation_Data["Journey_Time"][i], format)
    endDateTime = datetime.datetime.strptime(expected_time, format)
    Simulation_Data["Delay"][i] = abs(endDateTime - startDateTime)
print(expected_time)    
Simulation_Data
# Out:
# 0:40:26
# C:\Users\harit\.conda\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      No_Blocks  Train_No Departure_Time Arrival_Time Journey_Time  Day  \
# 0          3.0       1.0       00:00:00     00:44:39      0:44:39  1.0
# 1          3.0       2.0       00:10:00     01:04:11      0:54:11  1.0
# 2          3.0       3.0       00:20:00     01:15:47      0:55:47  1.0
# 3          3.0       4.0       00:30:00     01:29:20      0:59:20  1.0
# 4          3.0       5.0       00:41:13     01:39:55      0:58:42  1.0
# ..         ...       ...            ...          ...          ...  ...
# 324        4.0     119.0       20:11:00     21:09:30      0:58:30  1.0
# 325        4.0     120.0       20:21:03     21:22:06      1:01:03  1.0
# 326        4.0     121.0       20:32:25     21:33:30      1:01:05  1.0
# 327        4.0     122.0       20:43:17     21:44:59      1:01:42  1.0
# 328        4.0     123.0       20:53:35     21:54:48      1:01:13  1.0
#
#      Trains_PH    Delay  Train_Time_Interval
# 0          6.0  0:04:13            10.000000
# 1          6.0  0:13:45            10.000000
# 2          6.0  0:15:21            10.000000
# 3          6.0  0:18:54            10.000000
# 4          6.0  0:18:16            10.000000
# ..         ...      ...                  ...
# 324        9.0  0:18:04             6.666667
# 325        9.0  0:20:37             6.666667
# 326        9.0  0:20:39             6.666667
# 327        9.0  0:21:16             6.666667
# 328        9.0  0:20:47             6.666667
#
# [329 rows x 9 columns]

# %%
minimized_df = pd.DataFrame({'Trains_PH':Simulation_Data["Trains_PH"],"No_Blocks":Simulation_Data["No_Blocks"],"Delay":Simulation_Data["Delay"], "Train_Time_Interval": Simulation_Data["Train_Time_Interval"]  })

# %%
minimized_df
# Out:
#      Trains_PH  No_Blocks    Delay  Train_Time_Interval
# 0          6.0        3.0  0:04:13            10.000000
# 1          6.0        3.0  0:13:45            10.000000
# 2          6.0        3.0  0:15:21            10.000000
# 3          6.0        3.0  0:18:54            10.000000
# 4          6.0        3.0  0:18:16            10.000000
# ..         ...        ...      ...                  ...
# 324        9.0        4.0  0:18:04             6.666667
# 325        9.0        4.0  0:20:37             6.666667
# 326        9.0        4.0  0:20:39             6.666667
# 327        9.0        4.0  0:21:16             6.666667
# 328        9.0        4.0  0:20:47             6.666667
#
# [329 rows x 4 columns]

# %%
for i in range(len(minimized_df)):
    a_timedelta = minimized_df["Delay"][i]
    seconds = a_timedelta.total_seconds()
    minimized_df["Delay"][i] =seconds 

minimized_df
# Out:
# C:\Users\harit\.conda\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      Trains_PH  No_Blocks Delay  Train_Time_Interval
# 0          6.0        3.0   253            10.000000
# 1          6.0        3.0   825            10.000000
# 2          6.0        3.0   921            10.000000
# 3          6.0        3.0  1134            10.000000
# 4          6.0        3.0  1096            10.000000
# ..         ...        ...   ...                  ...
# 324        9.0        4.0  1084             6.666667
# 325        9.0        4.0  1237             6.666667
# 326        9.0        4.0  1239             6.666667
# 327        9.0        4.0  1276             6.666667
# 328        9.0        4.0  1247             6.666667
#
# [329 rows x 4 columns]

# %%
delay=minimized_df["Delay"]
delay.describe()
# Out:
# count      329.0
# unique     260.0
# top       1145.0
# freq         3.0
# Name: Delay, dtype: float64

# %% [markdown]
# # Delay distribution

# %%
σ = delay.std()
μ = delay.mean()
norm = stats.norm(loc=μ, scale=σ).pdf
plot(delay, pdf=norm, xmin=0, xmax=2000, bins=np.linspace(0, 2000, 41))
print(f"{max((μ-delay.min())/σ,  (delay.max()-μ)/σ):3.1f}σ")
# Out:
# 2.2σ

# %% [markdown]
# The delay graph of the final simulation has a mean of 857.29 seconds showing average delay in our process is around 14 mins the distribution also show highly platykurtic data indicating kurtosis coefficent below zero.
